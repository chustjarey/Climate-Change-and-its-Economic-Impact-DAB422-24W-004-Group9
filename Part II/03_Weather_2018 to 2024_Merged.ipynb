# %% [markdown]
# ## WEATHER (2018 - 2024) FOR 5 PROVINCES ##

# %%
import pandas as pd

# %%
# load data

AB = pd.read_csv('C:/Users/chust/OneDrive/Documents/GitHub/Climate-Change-and-its-Economic-Impact-DAB422-24W-004-Group9/Part II/weather_geography_merged_2018_to_2024_AB.csv')
BC = pd.read_csv('C:/Users/chust/OneDrive/Documents/GitHub/Climate-Change-and-its-Economic-Impact-DAB422-24W-004-Group9/Part II/weather_geography_merged_2018_to_2024_BC.csv')
ON = pd.read_csv('C:/Users/chust/OneDrive/Documents/GitHub/Climate-Change-and-its-Economic-Impact-DAB422-24W-004-Group9/Part II/weather_geography_merged_2018_to_2024_ON.csv')
QC = pd.read_csv('C:/Users/chust/OneDrive/Documents/GitHub/Climate-Change-and-its-Economic-Impact-DAB422-24W-004-Group9/Part II/weather_geography_merged_2018_to_2024_QC.csv')
SK_1 = pd.read_csv('C:/Users/chust/OneDrive/Documents/GitHub/Climate-Change-and-its-Economic-Impact-DAB422-24W-004-Group9/Part II/weather_geography_merged_2018_to_2024_SK.csv')
SK_2 = pd.read_csv('C:/Users/chust/OneDrive/Documents/GitHub/Climate-Change-and-its-Economic-Impact-DAB422-24W-004-Group9/Part II/weather_geography_merged_2007_to_2017_SK.csv')

# %%
AB
# Out:
#       Longitude  Latitude    Station Name Climate ID   Date/Time  Year  Month  \
# 0       -119.75     56.31  CLEARDALE AGDM    3074935  2018-01-01  2018      1
# 1       -119.75     56.31  CLEARDALE AGDM    3074935  2018-02-01  2018      2
# 2       -119.75     56.31  CLEARDALE AGDM    3074935  2018-03-01  2018      3
# 3       -119.75     56.31  CLEARDALE AGDM    3074935  2018-04-01  2018      4
# 4       -119.75     56.31  CLEARDALE AGDM    3074935  2018-05-01  2018      5
# ...         ...       ...             ...        ...         ...   ...    ...
# 4375    -110.07     53.31  LLOYDMINSTER A    3013961  2023-09-01  2023      9
# 4376    -110.07     53.31  LLOYDMINSTER A    3013961  2023-10-01  2023     10
# 4377    -110.07     53.31  LLOYDMINSTER A    3013961  2023-11-01  2023     11
# 4378    -110.07     53.31  LLOYDMINSTER A    3013961  2023-12-01  2023     12
# 4379    -110.07     53.31  LLOYDMINSTER A    3013961  2024-01-01  2024      1
#
# ...

# %%
BC
# Out:
#        Longitude  Latitude   Station Name Climate ID   Date/Time  Year  Month  \
# 0        -136.37     59.45  PLEASANT CAMP    1206197  2018-01-01  2018      1
# 1        -136.37     59.45  PLEASANT CAMP    1206197  2018-02-01  2018      2
# 2        -136.37     59.45  PLEASANT CAMP    1206197  2018-03-01  2018      3
# 3        -136.37     59.45  PLEASANT CAMP    1206197  2018-04-01  2018      4
# 4        -136.37     59.45  PLEASANT CAMP    1206197  2018-05-01  2018      5
# ...          ...       ...            ...        ...         ...   ...    ...
# 10726    -114.88     49.75    SPARWOOD CS    1157631  2023-09-01  2023      9
# 10727    -114.88     49.75    SPARWOOD CS    1157631  2023-10-01  2023     10
# 10728    -114.88     49.75    SPARWOOD CS    1157631  2023-11-01  2023     11
# 10729    -114.88     49.75    SPARWOOD CS    1157631  2023-12-01  2023     12
# 10730    -114.88     49.75    SPARWOOD CS    1157631  2024-01-01  2024      1
#
# ...

# %%
ON
# Out:
#       Longitude  Latitude Station Name Climate ID   Date/Time  Year  Month  \
# 0        -93.97     48.63      BARWICK    6020559  2018-01-01  2018      1
# 1        -93.97     48.63      BARWICK    6020559  2018-02-01  2018      2
# 2        -93.97     48.63      BARWICK    6020559  2018-03-01  2018      3
# 3        -93.97     48.63      BARWICK    6020559  2018-04-01  2018      4
# 4        -93.97     48.63      BARWICK    6020559  2018-05-01  2018      5
# ...         ...       ...          ...        ...         ...   ...    ...
# 4375     -74.75     45.02     CORNWALL    6101874  2023-09-01  2023      9
# 4376     -74.75     45.02     CORNWALL    6101874  2023-10-01  2023     10
# 4377     -74.75     45.02     CORNWALL    6101874  2023-11-01  2023     11
# 4378     -74.75     45.02     CORNWALL    6101874  2023-12-01  2023     12
# 4379     -74.75     45.02     CORNWALL    6101874  2024-01-01  2024      1
#
#       Mean Max Temp (°C)  Mean Min Temp (°C)  Mean Temp (°C)  ...  \
# ...

# %%
QC
# Out:
#       Longitude  Latitude     Station Name Climate ID   Date/Time  Year  \
# 0        -78.73     48.42        MONT BRUN    7085106  2018-01-01  2018
# 1        -78.73     48.42        MONT BRUN    7085106  2018-02-01  2018
# 2        -78.73     48.42        MONT BRUN    7085106  2018-03-01  2018
# 3        -78.73     48.42        MONT BRUN    7085106  2018-04-01  2018
# 4        -78.73     48.42        MONT BRUN    7085106  2018-05-01  2018
# ...         ...       ...              ...        ...         ...   ...
# 6334     -64.20     48.85  CAP DES ROSIERS    7051055  2023-09-01  2023
# 6335     -64.20     48.85  CAP DES ROSIERS    7051055  2023-10-01  2023
# 6336     -64.20     48.85  CAP DES ROSIERS    7051055  2023-11-01  2023
# 6337     -64.20     48.85  CAP DES ROSIERS    7051055  2023-12-01  2023
# 6338     -64.20     48.85  CAP DES ROSIERS    7051055  2024-01-01  2024
#
#       Month  Mean Max Temp (°C)  Mean Min Temp (°C)  Mean Temp (°C)  ...  \
# ...

# %%
SK_1
# Out:
#       Longitude  Latitude        Station Name Climate ID   Date/Time  Year  \
# 0       -109.51     49.64  CYPRESS HILLS PARK    4031999  2018-01-01  2018
# 1       -109.51     49.64  CYPRESS HILLS PARK    4031999  2018-02-01  2018
# 2       -109.51     49.64  CYPRESS HILLS PARK    4031999  2018-03-01  2018
# 3       -109.51     49.64  CYPRESS HILLS PARK    4031999  2018-04-01  2018
# 4       -109.51     49.64  CYPRESS HILLS PARK    4031999  2018-05-01  2018
# ...         ...       ...                 ...        ...         ...   ...
# 3645    -102.12     49.32               OXBOW    4015800  2023-09-01  2023
# 3646    -102.12     49.32               OXBOW    4015800  2023-10-01  2023
# 3647    -102.12     49.32               OXBOW    4015800  2023-11-01  2023
# 3648    -102.12     49.32               OXBOW    4015800  2023-12-01  2023
# 3649    -102.12     49.32               OXBOW    4015800  2024-01-01  2024
#
# ...

# %%
print(SK_1['Date/Time'].min())
print(SK_1['Date/Time'].max())
# Out:
# 2018-01-01
# 2024-01-01

# %%
SK_2
# Out:
#       Longitude  Latitude        Station Name Climate ID   Date/Time  Year  \
# 0       -109.51     49.64  CYPRESS HILLS PARK    4031999  2007-01-01  2007
# 1       -109.51     49.64  CYPRESS HILLS PARK    4031999  2007-02-01  2007
# 2       -109.51     49.64  CYPRESS HILLS PARK    4031999  2007-03-01  2007
# 3       -109.51     49.64  CYPRESS HILLS PARK    4031999  2007-04-01  2007
# 4       -109.51     49.64  CYPRESS HILLS PARK    4031999  2007-05-01  2007
# ...         ...       ...                 ...        ...         ...   ...
# 6469    -102.12     49.32               OXBOW    4015800  2017-08-01  2017
# 6470    -102.12     49.32               OXBOW    4015800  2017-09-01  2017
# 6471    -102.12     49.32               OXBOW    4015800  2017-10-01  2017
# 6472    -102.12     49.32               OXBOW    4015800  2017-11-01  2017
# 6473    -102.12     49.32               OXBOW    4015800  2017-12-01  2017
#
# ...

# %%
print(SK_2['Date/Time'].min())
print(SK_2['Date/Time'].max())
# Out:
# 2007-01-01
# 2017-12-01

# %%
final_merged_weather = pd.concat([AB, BC, ON, QC, SK_1, SK_2], axis = 0)

# %%
final_merged_weather
# Out:
#       Longitude  Latitude    Station Name Climate ID   Date/Time  Year  Month  \
# 0       -119.75     56.31  CLEARDALE AGDM    3074935  2018-01-01  2018      1
# 1       -119.75     56.31  CLEARDALE AGDM    3074935  2018-02-01  2018      2
# 2       -119.75     56.31  CLEARDALE AGDM    3074935  2018-03-01  2018      3
# 3       -119.75     56.31  CLEARDALE AGDM    3074935  2018-04-01  2018      4
# 4       -119.75     56.31  CLEARDALE AGDM    3074935  2018-05-01  2018      5
# ...         ...       ...             ...        ...         ...   ...    ...
# 6469    -102.12     49.32           OXBOW    4015800  2017-08-01  2017      8
# 6470    -102.12     49.32           OXBOW    4015800  2017-09-01  2017      9
# 6471    -102.12     49.32           OXBOW    4015800  2017-10-01  2017     10
# 6472    -102.12     49.32           OXBOW    4015800  2017-11-01  2017     11
# 6473    -102.12     49.32           OXBOW    4015800  2017-12-01  2017     12
#
# ...

# %%
csv_path = 'final_merged_weather_2018_2024.csv'
final_merged_weather.to_csv(csv_path,
                            index= False)
