# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

import statsmodels.api as sm
import pycaret.regression as pycr
import pycaret.utils as pycu
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %%
# load final clean dataset
df = pd.read_csv('merged_clean_data.csv')
for_prediction = df.copy()

# %%
# convert date/time to date time format
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
for_prediction['Date/Time'] = pd.to_datetime(df['Date/Time'])

# filter data to remove the rows that doesn't have productivity values
df = df[df['Date/Time'] <= '2021-12-31']

# set date/time as index
df.set_index('Date/Time', inplace = True)
for_prediction.set_index('Date/Time', inplace = True)


# drop unnecessary columns
sectors_todrop = ['Manufacturing', 'Utilities', 'Educational services', 'Accommodation and food services', 'Other services except public administration',
                  'Public administration', 'Finance and insurance, real estate and rental and leasing', 'Professional scientific and technical services',
                  'Information culture and recreation']

df.drop(columns = sectors_todrop, inplace = True)

# rename columns
df.rename(columns={'Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction': 'Agriculture'}, inplace=True)
for_prediction.rename(columns={'Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction': 'Agriculture'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85601 entries, 1998-01-01 to 2017-12-01
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   provincename                       85601 non-null  object
#  1   Longitude                          85601 non-null  float64
#  2   Latitude                           85601 non-null  float64
#  3   Region.Name                        85601 non-null  object
#  4   Construction                       85601 non-null  float64
#  5   Transportation and warehousing     85601 non-null  float64
#  6   Health care and social assistance  85601 non-null  float64
#  7   Agriculture                        85601 non-null  float64
#  8   Wholesale trade Retail trade       85601 non-null  float64
#  9   Population                         85601 non-null  float64
#  10  GeoUID                             85601 non-null  int64
#  11  Station Name                       85601 non-null  object
#  12  Climate ID                         85601 non-null  object
#  13  Mean Max Temp (°C)                 85601 non-null  float64
#  14  Mean Min Temp (°C)                 85601 non-null  float64
#  15  Mean Temp (°C)                     85601 non-null  float64
#  16  Extr Max Temp (°C)                 85601 non-null  float64
#  17  Extr Min Temp (°C)                 85601 non-null  float64
#  18  Total Rain (mm)                    85601 non-null  float64
#  19  Total Snow (cm)                    85601 non-null  float64
#  20  Total Precip (mm)                  85601 non-null  float64
#  21  Snow Grnd Last Day (cm)            85601 non-null  float64
#  22  Dir of Max Gust (10s deg)          85589 non-null  float64
#  23  Spd of Max Gust (km/h)             85589 non-null  float64
# dtypes: float64(19), int64(1), object(4)
# memory usage: 16.3+ MB

# %%
# filter for ontario
df = df[df['provincename'] == 'Ontario']

# %%
# RESAMPLING THE DATASET TO MONTHLY #

# split data into numeric and string
num_cols = df.select_dtypes(include = ['number'])

# resample numeric data
resampled = num_cols.resample("M").mean()

print(resampled.isnull().sum())
# Out:
# Longitude                            0
# Latitude                             0
# Construction                         0
# Transportation and warehousing       0
# Health care and social assistance    0
# Agriculture                          0
# Wholesale trade Retail trade         0
# Population                           0
# GeoUID                               0
# Mean Max Temp (°C)                   0
# Mean Min Temp (°C)                   0
# Mean Temp (°C)                       0
# Extr Max Temp (°C)                   0
# Extr Min Temp (°C)                   0
# Total Rain (mm)                      0
# Total Snow (cm)                      0
# Total Precip (mm)                    0
# Snow Grnd Last Day (cm)              0
# Dir of Max Gust (10s deg)            0
# Spd of Max Gust (km/h)               0
# dtype: int64

# %%
for_prediction = for_prediction[for_prediction['provincename'] == 'Ontario']
# RESAMPLING THE DATASET TO MONTHLY #

# split data into numeric and string
num_cols = for_prediction.select_dtypes(include = ['number'])

# resample numeric data
resampled_for_prediction = num_cols.resample("M").mean()

print(resampled_for_prediction.isnull().sum())
# Out:
# Longitude                                                     0
# Latitude                                                      0
# Utilities                                                    25
# Construction                                                 25
# Manufacturing                                                25
# Transportation and warehousing                               25
# Educational services                                         25
# Health care and social assistance                            25
# Accommodation and food services                              25
# Other services except public administration                  25
# Public administration                                        25
# Agriculture                                                  25
# Wholesale trade Retail trade                                 25
# Finance and insurance, real estate and rental and leasing    25
# Professional scientific and technical services               25
# Information culture and recreation                           25
# Population                                                   25
# GeoUID                                                        0
# Mean Max Temp (°C)                                            0
# Mean Min Temp (°C)                                            0
# Mean Temp (°C)                                                0
# Extr Max Temp (°C)                                            0
# Extr Min Temp (°C)                                            0
# Total Rain (mm)                                               0
# Total Snow (cm)                                               0
# Total Precip (mm)                                             0
# Snow Grnd Last Day (cm)                                       0
# Dir of Max Gust (10s deg)                                     0
# Spd of Max Gust (km/h)                                        0
# dtype: int64

# %%
# CORRELATION MATRIX for combination of all 5 provinces #

# numeric columns
num_df = resampled.select_dtypes(include = ['number'])

# columns to exclude
to_drop = ['Longitude', 'Latitude', 'GeoUID', 'Population']

num_df.drop(columns = to_drop, inplace = True)

# correlation matrix
corr_matrix = num_df.corr()

# to remove the upper portion of the matrix; contains the same information
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# correlation matrix heatmap
plt.figure(figsize= (15, 10))
sns.heatmap(corr_matrix, mask = mask, annot = True, fmt = '.2f', linewidths= 0.5)
# Out:
# <Axes: >

# %% [markdown]
# (1) Target Variable: Construction

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Transportation and warehousing', 'Health care and social assistance',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Construction', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_95329">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95329_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_95329_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95329_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95329_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_95329_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_95329_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_95329_row1_col1" class="data row1 col1" >Construction</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_95329_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_95329_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_95329_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_95329_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_95329_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_95329_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_95329_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_95329_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_95329_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_95329_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_95329_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_95329_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_95329_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T
row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_942c6_row4_col1" class="data row4 col1" >12.2048</td>
#       <td id="T_942c6_row4_col2" class="data row4 col2" >280.5538</td>
#       <td id="T_942c6_row4_col3" class="data row4 col3" >15.9909</td>
#       <td id="T_942c6_row4_col4" class="data row4 col4" >0.8794</td>
#       <td id="T_942c6_row4_col5" class="data row4 col5" >0.0938</td>
#       <td id="T_942c6_row4_col6" class="data row4 col6" >0.0752</td>
#       <td id="T_942c6_row4_col7" class="data row4 col7" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_942c6_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_942c6_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_942c6_row5_col1" class="data row5 col1" >13.2564</td>
#       <td id="T_942c6_row5_col2" class="data row5 col2" >286.1570</td>
#       <td id="T_942c6_row5_col3" class="data row5 col3" >16.1341</td>
#       <td id="T_942c6_row5_col4" class="data row5 col4" >0.8794</td>
#       <td id="T_942c6_row5_col5" class="data row5 col5" >0.1063</td>
#       <td id=

# %% [markdown]
# K Neighbors Regressor

# %%
# model creation using PyCaret
model = pycr.create_model('knn', fold = 5)

params = model.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_4fbbe_row5_col0, #T_4fbbe_row5_col1, #T_4fbbe_row5_col2, #T_4fbbe_row5_col3, #T_4fbbe_row5_col4, #T_4fbbe_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4fbbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fbbe_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4fbbe_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4fbbe_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4fbbe_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4fbbe_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4fbbe_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fbbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4fbbe_row0_col0" class="data row0 col0" >16.6031</td>
#       <td id="T_4fbbe_row0_col1" class="data row0 col1" >575.3788</td>
#       <td id="T_4fbbe_row0_col2" class="data row0 col2" >23.9871</td>
#       <td id="T_4fbbe_row0_col3" class="data row0 col3" >0.7771</td>
#       <td id="T_4fbbe_row0_col4" class="data row0 col4" >0.1386</td>
#       <td id="T_4fbbe_row0_col5" class="data row0 col5" >0.1045</td>
#     </tr>
#     <tr>
#       <th id="T_4fbbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4fbbe_row1_col0" class="data row1 col0" >8.7432</td>
#       <td id="T_4fbbe_row1_col1" class="data row1 col1" >123.2360</td>
#       <td id="T_4fbbe_row1_col2" class="data row1 col2" >11.1012</td>
#       <td id="T_4fbbe_row1_col3" class="data row1 col3" >0.9494</td>
#       <td id="T_4fbbe_row1_col4" class="data row1 col4" >0.0678</td>
#       <td id="T_4fbbe_row1_col5" class="data row1 col5" >0.0547</td>
#     </tr>
#     <tr>
#       <th id="T_4fbbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4fbbe_row2_col0" class="data row2 col0" >11.7844</td>
#       <td id="T_4fbbe_row2_col1" class="data row2 col1" >216.0861</td>
#       <td id="T_4fbbe_row2_col2" class="data row2 col2" >14.6999</td>
#       <td id="T_4fbbe_row2_col3" class="data row2 col3" >0.9049</td>
#       <td id="T_4fbbe_row2_col4" class="data row2 col4" >0.0853</td>
#       <td id="T_4fbbe_row2_col5" class="data row2 col5" >0.0735</td>
#     </tr>
#     <tr>
#       <th id="T_4fbbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4fbbe_row3_col0" class="data row3 col0" >11.9215</td>
#       <td id="T_4fbbe_row3_col1" class="data row3 col1" >207.9455</td>
#       <td id="T_4fbbe_row3_col2" class="data row3 col2" >14.4203</td>
#       <td id="T_4fbbe_row3_col3" class="data row3 col3" >0.9189</td>
#       <td id="T_4fbbe_row3_col4" class="data row3 col4" >0.0817</td>
#       <td id="T_4fbbe_row3_col5" class="data row3 col5" >0.0694</td>
#     </tr>
#     <tr>
#       <th id="T_4fbbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4fbbe_row4_col0" class="data row4 col0" >9.7138</td>
#       <td id="T_4fbbe_row4_col1" class="data row4 col1" >163.9745</td>
#       <td id="T_4fbbe_row4_col2" class="data row4 col2" >12.8053</td>
#       <td id="T_4fbbe_row4_col3" class="data row4 col3" >0.9331</td>
#       <td id="T_4fbbe_row4_col4" class="data row4 col4" >0.0770</td>
#       <td id="T_4fbbe_row4_col5" class="data row4 col5" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_4fbbe_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_4fbbe_row5_col0" class="data row5 col0" >11.7532</td>
#       <td id="T_4fbbe_row5_col1" class="data row5 col1" >257.3242</td>
#       <td id="T_4fbbe_row5_col2" class="data row5 col2" >15.4027</td>
#       <td id="T_4fbbe_row5_col3" class="data row5 col3" >0.8967</td>
#       <td id="T_4fbbe_row5_col4" class="data row5 col4" >0.0901</td>
#       <td id="T_4fbbe_row5_col5" class="data row5 col5" >0.0726</td>
#     </tr>
#     <tr>
#       <th id="T_4fbbe_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_4fbbe_row6_col0" class="data row6 col0" >2.7118</td>
#       <td id="T_4fbbe_row6_col1" class="data row6 col1" >162.4755</td>
#       <td id="T_4fbbe_row6_col2" class="data row6 col2" >4.4811</td>
#       <td id="T_4fbbe_row6_col3" class="data row6 col3" >0.0616</td>
#       <td id="T_4fbbe_row6_col4" class="data row6 col4" >0.0250</td>
#       <td id="T_4fbbe_row6_col5" class="data row6 col5" >0.0172</td>
#     </tr>
#   </tbody>
# </table>
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Construction (Training Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# R-squared (R2) Score: 0.9020201084197589

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)


# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Construction (Test Dataset)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# R-squared (R2) Score: -0.5592555620532993

# %%
# tuning the pycaret model

model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_9d4b1_row10_col0, #T_9d4b1_row10_col1, #T_9d4b1_row10_col2, #T_9d4b1_row10_col3, #T_9d4b1_row10_col4, #T_9d4b1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9d4b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d4b1_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9d4b1_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9d4b1_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9d4b1_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9d4b1_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9d4b1_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d4b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d4b1_row0_col0" class="data row0 col0" >13.2974</td>
#       <td id="T_9d4b1_row0_col1" class="data row0 col1" >274.6788</td>
#       <td id="T_9d4b1_row0_col2" class="data row0 col2" >16.5734</td>
#       <td id="T_9d4b1_row0_col3" class="data row0 col3" >0.8998</td>
#       <td id="T_9d4b1_row0_col4" class="data row0 col4" >0.0920</td>
#       <td id="T_9d4b1_row0_col5" class="data row0 col5" >0.0786</td>
#     </tr>
#     <tr>
#       <th id="T_9d4b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9
td>
#     </tr>
#     <tr>
#       <th id="T_9d4b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9d4b1_row9_col0" class="data row9 col0" >7.4436</td>
#       <td id="T_9d4b1_row9_col1" class="data row9 col1" >104.5477</td>
#       <td id="T_9d4b1_row9_col2" class="data row9 col2" >10.2249</td>
#       <td id="T_9d4b1_row9_col3" class="data row9 col3" >0.9494</td>
#       <td id="T_9d4b1_row9_col4" class="data row9 col4" >0.0684</td>
#       <td id="T_9d4b1_row9_col5" class="data row9 col5" >0.0519</td>
#     </tr>
#     <tr>
#       <th id="T_9d4b1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9d4b1_row10_col0" class="data row10 col0" >11.9188</td>
#       <td id="T_9d4b1_row10_col1" class="data row10 col1" >265.6446</td>
#       <td id="T_9d4b1_row10_col2" class="data row10 col2" >15.2707</td>
#       <td id="T_9d4b1_row10_col3" class="data row10 col3" >0.8884</td>
#       <td id="T_9d4b1_row10_col4" class="data row10 col4" >0.0900</td>
#       <td id="T_9d4b1_row10_col5" class="data row10 col5" >0.0740</td>
#     </tr>
#     <tr>
#       <th id="T_9d4b1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9d4b1_row11_col0" class="data row11 col0" >3.6728</td>
#       <td id="T_9d4b1_row11_col1" class="data row11 col1" >225.6722</td>
#       <td id="T_9d4b1_row11_col2" class="data row11 col2" >5.6964</td>
#       <td id="T_9d4b1_row11_col3" class="data row11 col3" >0.0968</td>
#       <td id="T_9d4b1_row11_col4" class="data row11 col4" >0.0321</td>
#       <td id="T_9d4b1_row11_col5" class="data row11 col5" >0.0241</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Construction (Training Dataset)',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_702bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_702bc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_702bc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_702bc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_702bc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_702bc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_702bc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_702bc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_702bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_702bc_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_702bc_row0_col1" class="data row0 col1" >10.9084</td>
#       <td id="T_702bc_row0_col2" class="data row0 col2" >262.6981</td>
#       <td id="T_702bc_row0_col3" class="data row0 col3" >16.2080</td>
#       <td id="T_702bc_row0_col4" class="data row0 col4" >0.8974</td>
#       <td id="T_702bc_row0_col5" class="data row0 col5" >0.0944</td>
#       <td id="T_702bc_row0_col6" class="data row0 col6" >0.0684</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.8974154417116312

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Construction (Test Dataset)',
                  title_font_size=15, title_y=0.95, 
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_38f8a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38f8a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_38f8a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_38f8a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_38f8a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_38f8a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_38f8a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_38f8a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38f8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38f8a_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_38f8a_row0_col1" class="data row0 col1" >81.5628</td>
#       <td id="T_38f8a_row0_col2" class="data row0 col2" >8068.0425</td>
#       <td id="T_38f8a_row0_col3" class="data row0 col3" >89.8223</td>
#       <td id="T_38f8a_row0_col4" class="data row0 col4" >-0.6132</td>
#       <td id="T_38f8a_row0_col5" class="data row0 col5" >0.3497</td>
#       <td id="T_38f8a_row0_col6" class="data row0 col6" >0.2741</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -0.6132241400162706

# %% [markdown]
# (2) Target Variable: Transportation and warehousing

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Health care and social assistance',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Transportation and warehousing', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8b8c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8b8c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c8b8c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8b8c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c8b8c_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8b8c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c8b8c_row1_col1" class="data row1 col1" >Transportation and warehousing</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8b8c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c8b8c_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8b8c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c8b8c_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8b8c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c8b8c_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8b8c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c8b8c_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8b8c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c8b8c_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_c8b8c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8b8c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c8b8c_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_13ef4 th {
#   text-align: left;
# }
# #T_13ef4_row0_col0, #T_13ef4_row0_col5, #T_13ef4_row0_col6, #T_13ef4_row1_col0, #T_13ef4_row1_col1, #T_13ef4_row1_col2, #T_13ef4_row1_col3, #T_13ef4_row1_col4, #T_13ef4_row2_col0, #T_13ef4_row2_col1, #T_13ef4_row2_col2, #T_13ef4_row2_col3, #T_13ef4_row2_col4, #T_13ef4_row2_col5, #T_13ef4_row2_col6, #T_13ef4_row3_col0, #T_13ef4_row3_col1, #T_13ef4_row3_col2, #T_13ef4_row3_col3, #T_13ef4_row3_col4, #T_13ef4_row3_col5, #T_13ef4_row3_col6, #T_13ef4_row4_col0, #T_13ef4_row4_col1, #T_13ef4_row4_col2, #T_13ef4_row4_col3, #T_13ef4_row4_col4, #T_13ef4_row4_col5, #T_13ef4_row4_col6, #T_13ef4_row5_col0, #T_13ef4_row5_col1, #T_13ef4_row5_col2, #T_13ef4_row5_col3, #T_13ef4_row5_col4, #T_13ef4_row5_col5, #T_13ef4_row5_col6, #T_13ef4_row6_col0, #T_13ef4_row6_col1, #T_13ef4_row6_col2, #T_13ef4_row6_col3, #T_13ef4_row6_col4, #T_13ef4_row6_col5, #T_13ef4_row6_col6, #T_13ef4_row7_col0, #T_13ef4_row7_col1, #T_13ef4_row7_col2, #T_13ef4_row7_col3, #T_13ef4_row7_col4, #T_13ef4_row7_col5, #T_13ef4_row7_col6, #T_13ef4_row8_col0, #T_13ef4_row8_col1, #T_13ef4_row8_col2, #T_13ef4_row8_col3, #T_13ef4_row8_col4, #T_13ef4_row8_col5, #T_13ef4_row8_col6, #T_13ef4_row9_col0, #T_13ef4_row9_col1, #T
col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_13ef4_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_13ef4_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_13ef4_row1_col1" class="data row1 col1" >5.7445</td>
#       <td id="T_13ef4_row1_col2" class="data row1 col2" >63.4541</td>
#       <td id="T_13ef4_row1_col3" class="data row1 col3" >7.4627</td>
#       <td id="T_13ef4_row1_col4" class="data row1 col4" >0.9308</td>
#       <td id="T_13ef4_row1_col5" class="data row1 col5" >0.0703</td>
#       <td id="T_13ef4_row1_col6" class="data row1 col6" >0.0548</td>
#       <td id="T_13ef4_row1_col7" class="data row1 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_13ef4_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_13ef4_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_13ef4_row2_col1" class="data row2 col1" >6.0507</td>
#       <td id="T_13ef4_row2_col2" class="data row2 col2" >67.7226</td>
#       <td id="T_13ef4_row2_col3" class="data row2 col3" >7.7576</td>
#       <td id="T_13ef4_row2_col4" class="data row2 col4" >0.9266</td>
#       <td id="T_13ef4_row2_col5" class="data row2 col5" >0.0729</td>
#       <td id="T_13ef4_row2_col6" class="data row2 col6" >0.0577</td>
#       <td id="T_13ef4_row2_col7" class="data row2 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_13ef4_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_13ef4_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_13ef4_row3_col1" class="data row3 col1" >6.2290</td>
#       <td id="T_13ef4_row3_col2" class="data row3 col2" >73.3617</td>
#       <td id="T_13ef4_row3_col3" class="data row3 col3" >8.1010</td>
#       <td id="T_13ef4_row3_col4" class="data row3 col4" >0.9201</td>
#       <td id="T_13ef4_row3_col5" class="data row3 col5" >0.0764</td>
#       <td id="T_13ef4_row3_col6" class="data row3 col6" >0.0597</td>
#       <td id="T_13ef4_row3_col7" class="data row3 col7" >0.0480</td>
#     </tr>
#     <tr>
#       <th id="T_13ef4_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_13ef4_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_13ef4_row4_col1" class="data row4 col1" >6.3295</td>
#       <td id="T_13ef4_row4_col2" class="data row4 col2" >78.8448</td>
#       <td id="T_13ef4_row4_col3" class="data row4 col3" >8.3263</td>
#       <td id="T_13ef4_row4_col4" class="data row4 col4" >0.9141</td>
#       <td id="T_13ef4_row4_col5" class="data row4 col5" >0.0778</td>
#       <td id="T_13ef4_row4_col6" class="data row4 col6" >0.0604</td>
#       <td id="T_13ef4_row4_col7" class="data row4 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_13ef4_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_13ef4_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_13ef4_row5_col1" class="data row5 col1" >6.4924</td>
#       <td id="T_13ef4_row5_col2" class="data row5 col2" >84.0286</td>
#       <td id="T_13ef4_row5_col3" class="data row5 col3" >8.6238</td>
#       <td id="T_13ef4_row5_col4" class="data row5 col4" >0.9093</td>
#       <td id="T_13ef4_row5_col5" class="data row5 col5" >0.0801</td>
#       <td id="

# %% [markdown]
# K Neighbors Regressor

# %%
# model creation using PyCaret
model = pycr.create_model('knn', fold = 5)

params = model.get_params()
print(params)
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Transportation and warehousing'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Transportation and warehousing (Training Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# R-squared (R2) Score: 0.9363612202025382

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Transportation and warehousing'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)


# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Transportation and warehousing (Test Dataset)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_4699d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4699d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4699d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4699d_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4699d_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4699d_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4699d_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4699d_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4699d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4699d_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_4699d_row0_col1" class="data row0 col1" >25.8240</td>
#       <td id="T_4699d_row0_col2" class="data row0 col2" >984.4333</td>
#       <td id="T_4699d_row0_col3" class="data row0 col3" >31.3757</td>
#       <td id="T_4699d_row0_col4" class="data row0 col4" >0.2128</td>
#       <td id="T_4699d_row0_col5" class="data row0 col5" >0.1966</td>
#       <td id="T_4699d_row0_col6" class="data row0 col6" >0.1542</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.2127651629082743

# %%
# tuning the pycaret model

model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'manhattan', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Transportation and warehousing'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Transportation and warehousing (Training Dataset)',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# R-squared (R2) Score: 0.9330676914299174

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Transportation and warehousing'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Transportation and warehousing (Test Dataset)',
                  title_font_size=15, title_y=0.95, 
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_01f41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01f41_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_01f41_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_01f41_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_01f41_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_01f41_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_01f41_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_01f41_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01f41_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_01f41_row0_col1" class="data row0 col1" >26.2390</td>
#       <td id="T_01f41_row0_col2" class="data row0 col2" >986.2932</td>
#       <td id="T_01f41_row0_col3" class="data row0 col3" >31.4053</td>
#       <td id="T_01f41_row0_col4" class="data row0 col4" >0.2113</td>
#       <td id="T_01f41_row0_col5" class="data row0 col5" >0.1981</td>
#       <td id="T_01f41_row0_col6" class="data row0 col6" >0.1578</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.21127776670478793

# %% [markdown]
# (3) Target Variable: Health care and social assistance

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
# train_data = train_data[['Mean Max Temp (°C)', 'Construction']]
test_data = resampled_con[resampled_con.index > train_end_date]
# test_data = train_data[['Mean Max Temp (°C)', 'Construction']]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Health care and social assistance', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f25fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f25fd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f25fd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f25fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f25fd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f25fd_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f25fd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f25fd_row1_col1" class="data row1 col1" >Health care and social assistance</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f25fd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f25fd_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f25fd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f25fd_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f25fd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f25fd_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f25fd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f25fd_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f25fd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f25fd_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_f25fd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f25fd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f25fd_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7e76e th {
#   text-align: left;
# }
# #T_7e76e_row0_col0, #T_7e76e_row1_col0, #T_7e76e_row1_col1, #T_7e76e_row1_col2, #T_7e76e_row1_col3, #T_7e76e_row1_col4, #T_7e76e_row1_col5, #T_7e76e_row1_col6, #T_7e76e_row2_col0, #T_7e76e_row2_col1, #T_7e76e_row2_col2, #T_7e76e_row2_col3, #T_7e76e_row2_col4, #T_7e76e_row2_col5, #T_7e76e_row2_col6, #T_7e76e_row3_col0, #T_7e76e_row3_col1, #T_7e76e_row3_col2, #T_7e76e_row3_col3, #T_7e76e_row3_col4, #T_7e76e_row3_col5, #T_7e76e_row3_col6, #T_7e76e_row4_col0, #T_7e76e_row4_col1, #T_7e76e_row4_col2, #T_7e76e_row4_col3, #T_7e76e_row4_col4, #T_7e76e_row4_col5, #T_7e76e_row4_col6, #T_7e76e_row5_col0, #T_7e76e_row5_col1, #T_7e76e_row5_col2, #T_7e76e_row5_col3, #T_7e76e_row5_col4, #T_7e76e_row5_col5, #T_7e76e_row5_col6, #T_7e76e_row6_col0, #T_7e76e_row6_col1, #T_7e76e_row6_col2, #T_7e76e_row6_col3, #T_7e76e_row6_col4, #T_7e76e_row6_col5, #T_7e76e_row6_col6, #T_7e76e_row7_col0, #T_7e76e_row7_col1, #T_7e76e_row7_col2, #T_7e76e_row7_col3, #T_7e76e_row7_col4, #T_7e76e_row7_col5, #T_7e76e_row7_col6, #T_7e76e_row8_col0, #T_7e76e_row8_col1, #T_7e76e_row8_col2, #T_7e76e_row8_col3, #T_7e76e_row8_col4, #T_7e76e_row8_col5, #T_7e76e_row8_col6, #T_7e76e_row9_col0, #T_7e76e_row9_col1, #T_7e76e_row9_col2, #T_7e76e_row9_col3, #T_7e76e_row9_col4, #T_7e76e_row9_col5, #T_7e76e_row9_col6, #T_7e76e_row10_col0, #T_7e76e_row10_col1, #T_7e76e_row10_col2, #T_7e76e_row10_col3, #T_7e76e_row10_col4, #T_7e76e_row10_col5, #T_7e76e_row10_col6, #T_7e76e_row11_col0, #T_7e76e_row11_col1, #T_7e76e_row11_col2, #T_7e76e_row11_col3, #T_7e76e_row11_col4, #T_7e76e_row11_col5, #T_7e76e_row11_col6, #T_7e76e_row12_col0, #T_7e76e_row12_col1, #T_7e76e_row12_col2, #T_7e76e_row12_col3, #T_7e76e_row12_col4, #T_7e76e_row12_col5, #T_7e76e_row12_col6, #T_7e76e_row13_col0, #T_7e76e_row13_col1, #T_7e76e_row13_col2, #T_7e76e_row13_col3, #T_7e76e_row13_col4, #T_7e76e_row13_col5, #T_7e76e_row13_col6, #T_7e76e_row14_col0, #T_7e76e_row14_col1, #T_7e76e_row14_col2, #T_7e76e_row14_col3, #T_7e76e_row14_col4, #T_7e76e_row14_col5, #T_7e76e_row14_col6, #T_7e76e_row15_col0, #T_7e76e_row15_col1, #T_7e76e_row15_col2, #T_7e76e_row15_col3, #T_7e76e_row15_col4, #T_7e76e_row15_col5, #T_7e76e_row15_col6, #T_7e76e_row16_col0, #T_7e76e_row16_col1, #T_7e76e_row16_col2, #T_7e76e_row16_col3, #T_7e76e_row16_col4, #T_7e76e_row16_col5, #T_7e76e_row16_col6, #T_7e76e_row17_col0, #T_7e76e_row17_col1, #T_7e76e_row17_col2, #T_7e76e_row17_col3, #T_7e76e_row17_col4, #T_7e76e_row17_col5, #T_7e76e_row17_col6, #T_7e76e_row18_col0, #T_7e76e_row18_col1, #T_7e76e_row18_col2, #T_7e76e_row18_col3, #T_7e76e_row18_col4, #T_7e76e_row18_col5, #T_7e76e_row18_col6 {
#   text-align: left;
# }
# #T_7e76e_row0_col1, #T_7e76e_row0_col2, #T_7e76e_row0_col3, #T_7e76e_row0_col4, #T_7e76e_row0_col5, #T_7e76e_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_7e76e_row0_col7, #T_7e76e_row1_col7, #T_7e76e_row2_col7, #T_7e76e_row3_col7, #T_7e76e_row4_col7, #T_7e76e_row5_col7, #T_7e76e_row7_col7, #T_7e76e_row8_col7, #T_7e76e_row9_col7, #T_7e76e_row12_col7, #T_7e76e_row13_col7, #T_7e76e_row14_col7, #T_7e76e_row15_col7, #T_7e76e_row16_col7, #T_7e76e_row17_col7, #T_7e76e_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_7e76e_row6_col7, #T_7e76e_row10_col7, #T_7e76e_row11_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_7e76e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e76e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7e76e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7e76e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7e76e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7e76e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7e76e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7e76e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_7e76e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e76e_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_7e76e_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_7e76e_row0_col1" class="data row0 col1" >6.6860</td>
#       <td id="T_7e76e_row0_col2" class="data row0 col2" >142.5356</td>
#       <td id="T_7e76e_row0_col3" class="data row0 col3" >9.8293</td>
#       <td id="T_7e76e_row0_col4" class="data row0 col4" >0.9601</td>
#       <td id="T_7e76e_row0_col5" class="data row0 col5" >0.0498</td>
#       <td id="T_7e76e_row0_col6" class="data row0 col6" >0.0363</td>
#       <td id="T_7e76e_row0_col7" class="data row0 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_7e76e_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_7e76e_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_7e76e_row1_col1" class="data row1 col1" >7.1227</td>
#       <td id="T_7e76e_row1_col2" class="data row1 col2" >147.6089</td>
#       <td id="T_7e76e_row1_col3" class="data row1 col3" >10.3485</td>
#       <td id="T_7e76e_row1_col4" class="data row1 col4" >0.9586</td>
#       <td id="T_7e76e_row1_col5" class="data row1 col5" >0.0537</td>
#       <td id="T_7e76e_row1_col6" class="data row1 col6" >0.0393</td>
#       <td id="T_7e76e_row1_col7" class="data row1 col7" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_7e76e_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_7e76e_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_7e76e_row2_col1" class="data row2 col1" >7.1291</td>
#       <td id="T_7e76e_row2_col2" class="data row2 col2" >160.4611</td>
#       <td id="T_7e76e_row2_col3" class="data row2 col3" >10.5783</td>
#       <td id="T_7e76e_row2_col4" class="data row2 col4" >0.9552</td>
#       <td id="T_7e76e_row2_col5" class="data row2 col5" >0.0561</td>
#       <td id="T_7e76e_row2_col6" class="data row2 col6" >0.0397</td>
#       <td id="T_7e76e_row2_col7" class="data row2 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_7e76e_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_7e76e_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_7e76e_row3_col1" class="data row3 col1" >7.2510</td>
#       <td id="T_7e76e_row3_col2" class="data row3 col2" >164.8406</td>
#       <td id="T_7e76e_row3_col3" class="data row3 col3" >10.8387</td>
#       <td id="T_7e76e_row3_col4" class="data row3 col4" >0.9539</td>
#       <td id="T_7e76e_row3_col5" class="data row3 col5" >0.0546</td>
#       <td id="T_7e76e_row3_col6" class="data row3 col6" >0.0389</td>
#       <td id="T_7e76e_row3_col7" class="data row3 col7" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_7e76e_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_7e76e_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_7e76e_row4_col1" class="data row4 col1" >7.6147</td>
#       <td id="T_7e76e_row4_col2" class="data row4 col2" >183.7423</td>
#       <td id="T_7e76e_row4_col3" class="data row4 col3" >11.5644</td>
#       <td id="T_7e76e_row4_col4" class="data row4 col4" >0.9486</td>
#       <td id="T_7e76e_row4_col5" class="data row4 col5" >0.0599</td>
#       <td id="T_7e76e_row4_col6" class="data row4 col6" >0.0419</td>
#       <td id="T_7e76e_row4_col7" class="data row4 col7" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_7e76e_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_7e76e_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_7e76e_row5_col1" class="data row5 col1" >7.6355</td>
#       <td id="T_7e76e_row5_col2" class="data row5 col2" >196.5264</td>
#       <td id="T_7e76e_row5_col3" class="data row5 col3" >11.7922</td>
#       <td id="T_7e76e_row5_col4" class="data row5 col4" >0.9456</td>
#       <td id="T_7e76e_row5_col5" class="data row5 col5" >0.0608</td>

# %% [markdown]
# K Neighbors Regressor

# %%
# model creation using PyCaret
model = pycr.create_model('knn', fold = 5)

params = model.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_46ae6_row5_col0, #T_46ae6_row5_col1, #T_46ae6_row5_col2, #T_46ae6_row5_col3, #T_46ae6_row5_col4, #T_46ae6_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_46ae6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46ae6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_46ae6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_46ae6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_46ae6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_46ae6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_46ae6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46ae6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46ae6_row0_col0" class="data row0 col0" >9.3311</td>
#       <td id="T_46ae6_row0_col1" class="data row0 col1" >471.4109</td>
#       <td id="T_46ae6_row0_col2" class="data row0 col2" >21.7120</td>
#       <td id="T_46ae6_row0_col3" class="data row0 col3" >0.8739</td>
#       <td id="T_46ae6_row0_col4" class="data row0 col4" >0.1124</td>
#       <td id="T_46ae6_row0_col5" class="data row0 col5" >0.0571</td>
#     </tr>
#     <tr>
#       <th id="T_46ae6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46ae6_row1_col0" class="data row1 col0" >4.5730</td>
#       <td id="T_46ae6_row1_col1" class="data row1 col1" >32.7143</td>
#       <td id="T_46ae6_row1_col2" class="data row1 col2" >5.7196</td>
#       <td id="T_46ae6_row1_col3" class="data row1 col3" >0.9908</td>
#       <td id="T_46ae6_row1_col4" class="data row1 col4" >0.0279</td>
#       <td id="T_46ae6_row1_col5" class="data row1 col5" >0.0232</td>
#     </tr>
#     <tr>
#       <th id="T_46ae6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46ae6_row2_col0" class="data row2 col0" >7.9067</td>
#       <td id="T_46ae6_row2_col1" class="data row2 col1" >86.2743</td>
#       <td id="T_46ae6_row2_col2" class="data row2 col2" >9.2884</td>
#       <td id="T_46ae6_row2_col3" class="data row2 col3" >0.9768</td>
#       <td id="T_46ae6_row2_col4" class="data row2 col4" >0.0482</td>
#       <td id="T_46ae6_row2_col5" class="data row2 col5" >0.0416</td>
#     </tr>
#     <tr>
#       <th id="T_46ae6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46ae6_row3_col0" class="data row3 col0" >5.7923</td>
#       <td id="T_46ae6_row3_col1" class="data row3 col1" >67.0761</td>
#       <td id="T_46ae6_row3_col2" class="data row3 col2" >8.1900</td>
#       <td id="T_46ae6_row3_col3" class="data row3 col3" >0.9819</td>
#       <td id="T_46ae6_row3_col4" class="data row3 col4" >0.0371</td>
#       <td id="T_46ae6_row3_col5" class="data row3 col5" >0.0274</td>
#     </tr>
#     <tr>
#       <th id="T_46ae6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46ae6_row4_col0" class="data row4 col0" >5.4885</td>
#       <td id="T_46ae6_row4_col1" class="data row4 col1" >46.7250</td>
#       <td id="T_46ae6_row4_col2" class="data row4 col2" >6.8356</td>
#       <td id="T_46ae6_row4_col3" class="data row4 col3" >0.9869</td>
#       <td id="T_46ae6_row4_col4" class="data row4 col4" >0.0379</td>
#       <td id="T_46ae6_row4_col5" class="data row4 col5" >0.0307</td>
#     </tr>
#     <tr>
#       <th id="T_46ae6_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_46ae6_row5_col0" class="data row5 col0" >6.6183</td>
#       <td id="T_46ae6_row5_col1" class="data row5 col1" >140.8401</td>
#       <td id="T_46ae6_row5_col2" class="data row5 col2" >10.3491</td>
#       <td id="T_46ae6_row5_col3" class="data row5 col3" >0.9621</td>
#       <td id="T_46ae6_row5_col4" class="data row5 col4" >0.0527</td>
#       <td id="T_46ae6_row5_col5" class="data row5 col5" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_46ae6_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_46ae6_row6_col0" class="data row6 col0" >1.7414</td>
#       <td id="T_46ae6_row6_col1" class="data row6 col1" >166.2796</td>
#       <td id="T_46ae6_row6_col2" class="data row6 col2" >5.8083</td>
#       <td id="T_46ae6_row6_col3" class="data row6 col3" >0.0443</td>
#       <td id="T_46ae6_row6_col4" class="data row6 col4" >0.0305</td>
#       <td id="T_46ae6_row6_col5" class="data row6 col5" >0.0122</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Health care and social assistance'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Health care and social assistance (Training Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_65a7e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65a7e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_65a7e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_65a7e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_65a7e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_65a7e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_65a7e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_65a7e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_65a7e_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_65a7e_row0_col1" class="data row0 col1" >6.0243</td>
#       <td id="T_65a7e_row0_col2" class="data row0 col2" >130.1758</td>
#       <td id="T_65a7e_row0_col3" class="data row0 col3" >11.4095</td>
#       <td id="T_65a7e_row0_col4" class="data row0 col4" >0.9651</td>
#       <td id="T_65a7e_row0_col5" class="data row0 col5" >0.0605</td>
#       <td id="T_65a7e_row0_col6" class="data row0 col6" >0.0334</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.9651220740861269

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Health care and social assistance'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)


# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Health care and social assistance (Test Dataset)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e870a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e870a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e870a_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e870a_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e870a_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e870a_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e870a_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e870a_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e870a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e870a_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_e870a_row0_col1" class="data row0 col1" >58.3091</td>
#       <td id="T_e870a_row0_col2" class="data row0 col2" >4245.9844</td>
#       <td id="T_e870a_row0_col3" class="data row0 col3" >65.1612</td>
#       <td id="T_e870a_row0_col4" class="data row0 col4" >0.2341</td>
#       <td id="T_e870a_row0_col5" class="data row0 col5" >0.2210</td>
#       <td id="T_e870a_row0_col6" class="data row0 col6" >0.1817</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.23407729968974733

# %%
# tuning the pycaret model

model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .               20:47:40
# Status     . . . . . . . . . . . . . . . . . .   Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .  K Neighbors Regressor
# <style type="text/css">
# #T_3d031_row10_col0, #T_3d031_row10_col1, #T_3d031_row10_col2, #T_3d031_row10_col3, #T_3d031_row10_col4, #T_3d031_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3d031">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d031_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3d031_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3d031_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3d031_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3d031_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3d031_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d031_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3d031_row0_col0" class="data row0 col0" >7.5296</td>
#       <td id="T_3d031_row0_col1" class="data row0 col1" >90.3043</td>
#       <td id="T_3d031_row0_col2" class="data row0 col2" >9.5029</td>
#       <td id="T_3d031_row0_col3" class="data row0 col3" >0.9767</td>
#       <td id="T_3d031_row0_col4" class="data row0 col4" >0.0503</td>
#       <td id="T_3d031_row0_col5" class="data row0 col5" >0.0419</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3d031_row1_col0" class="data row1 col0" >12.2675</td>
#       <td id="T_3d031_row1_col1" class="data row1 col1" >893.4462</td>
#       <td id="T_3d031_row1_col2" class="data row1 col2" >29.8906</td>
#       <td id="T_3d031_row1_col3" class="data row1 col3" >0.7465</td>
#       <td id="T_3d031_row1_col4" class="data row1 col4" >0.1540</td>
#       <td id="T_3d031_row1_col5" class="data row1 col5" >0.0788</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3d031_row2_col0" class="data row2 col0" >4.6703</td>
#       <td id="T_3d031_row2_col1" class="data row2 col1" >32.8445</td>
#       <td id="T_3d031_row2_col2" class="data row2 col2" >5.7310</td>
#       <td id="T_3d031_row2_col3" class="data row2 col3" >0.9908</td>
#       <td id="T_3d031_row2_col4" class="data row2 col4" >0.0289</td>
#       <td id="T_3d031_row2_col5" class="data row2 col5" >0.0237</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3d031_row3_col0" class="data row3 col0" >6.0612</td>
#       <td id="T_3d031_row3_col1" class="data row3 col1" >52.9420</td>
#       <td id="T_3d031_row3_col2" class="data row3 col2" >7.2761</td>
#       <td id="T_3d031_row3_col3" class="data row3 col3" >0.9849</td>
#       <td id="T_3d031_row3_col4" class="data row3 col4" >0.0381</td>
#       <td id="T_3d031_row3_col5" class="data row3 col5" >0.0324</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3d031_row4_col0" class="data row4 col0" >7.7050</td>
#       <td id="T_3d031_row4_col1" class="data row4 col1" >94.1363</td>
#       <td id="T_3d031_row4_col2" class="data row4 col2" >9.7024</td>
#       <td id="T_3d031_row4_col3" class="data row4 col3" >0.9764</td>
#       <td id="T_3d031_row4_col4" class="data row4 col4" >0.0431</td>
#       <td id="T_3d031_row4_col5" class="data row4 col5" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3d031_row5_col0" class="data row5 col0" >6.6831</td>
#       <td id="T_3d031_row5_col1" class="data row5 col1" >59.1109</td>
#       <td id="T_3d031_row5_col2" class="data row5 col2" >7.6884</td>
#       <td id="T_3d031_row5_col3" class="data row5 col3" >0.9827</td>
#       <td id="T_3d031_row5_col4" class="data row5 col4" >0.0443</td>
#       <td id="T_3d031_row5_col5" class="data row5 col5" >0.0371</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3d031_row6_col0" class="data row6 col0" >4.6409</td>
#       <td id="T_3d031_row6_col1" class="data row6 col1" >35.1564</td>
#       <td id="T_3d031_row6_col2" class="data row6 col2" >5.9293</td>
#       <td id="T_3d031_row6_col3" class="data row6 col3" >0.9893</td>
#       <td id="T_3d031_row6_col4" class="data row6 col4" >0.0309</td>
#       <td id="T_3d031_row6_col5" class="data row6 col5" >0.0226</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3d031_row7_col0" class="data row7 col0" >6.1197</td>
#       <td id="T_3d031_row7_col1" class="data row7 col1" >78.3940</td>
#       <td id="T_3d031_row7_col2" class="data row7 col2" >8.8540</td>
#       <td id="T_3d031_row7_col3" class="data row7 col3" >0.9793</td>
#       <td id="T_3d031_row7_col4" class="data row7 col4" >0.0367</td>
#       <td id="T_3d031_row7_col5" class="data row7 col5" >0.0279</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3d031_row8_col0" class="data row8 col0" >6.4989</td>
#       <td id="T_3d031_row8_col1" class="data row8 col1" >62.0747</td>
#       <td id="T_3d031_row8_col2" class="data row8 col2" >7.8788</td>
#       <td id="T_3d031_row8_col3" class="data row8 col3" >0.9838</td>
#       <td id="T_3d031_row8_col4" class="data row8 col4" >0.0435</td>
#       <td id="T_3d031_row8_col5" class="data row8 col5" >0.0368</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3d031_row9_col0" class="data row9 col0" >5.1821</td>
#       <td id="T_3d031_row9_col1" class="data row9 col1" >35.5266</td>
#       <td id="T_3d031_row9_col2" class="data row9 col2" >5.9604</td>
#       <td id="T_3d031_row9_col3" class="data row9 col3" >0.9890</td>
#       <td id="T_3d031_row9_col4" class="data row9 col4" >0.0362</td>
#       <td id="T_3d031_row9_col5" class="data row9 col5" >0.0312</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3d031_row10_col0" class="data row10 col0" >6.7358</td>
#       <td id="T_3d031_row10_col1" class="data row10 col1" >143.3936</td>
#       <td id="T_3d031_row10_col2" class="data row10 col2" >9.8414</td>
#       <td id="T_3d031_row10_col3" class="data row10 col3" >0.9599</td>
#       <td id="T_3d031_row10_col4" class="data row10 col4" >0.0506</td>
#       <td id="T_3d031_row10_col5" class="data row10 col5" >0.0369</td>
#     </tr>
#     <tr>
#       <th id="T_3d031_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3d031_row11_col0" class="data row11 col0" >2.1007</td>
#       <td id="T_3d031_row11_col1" class="data row11 col1" >250.9020</td>
#       <td id="T_3d031_row11_col2" class="data row11 col2" >6.8221</td>
#       <td id="T_3d031_row11_col3" class="data row11 col3" >0.0713</td>
#       <td id="T_3d031_row11_col4" class="data row11 col4" >0.0350</td>
#       <td id="T_3d031_row11_col5" class="data row11 col5" >0.0151</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Health care and social assistance'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Health care and social assistance (Training Dataset)',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# R-squared (R2) Score: 0.9651220740861269

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Health care and social assistance'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Health care and social assistance (Test Dataset)',
                  title_font_size=15, title_y=0.95, 
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_62955">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62955_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_62955_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_62955_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_62955_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_62955_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_62955_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_62955_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62955_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62955_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_62955_row0_col1" class="data row0 col1" >58.3091</td>
#       <td id="T_62955_row0_col2" class="data row0 col2" >4245.9844</td>
#       <td id="T_62955_row0_col3" class="data row0 col3" >65.1612</td>
#       <td id="T_62955_row0_col4" class="data row0 col4" >0.2341</td>
#       <td id="T_62955_row0_col5" class="data row0 col5" >0.2210</td>
#       <td id="T_62955_row0_col6" class="data row0 col6" >0.1817</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.23407729968974733

# %% [markdown]
# (4) Target Variable: Agriculture

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Health care and social assistance', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
# train_data = train_data[['Mean Max Temp (°C)', 'Construction']]
test_data = resampled_con[resampled_con.index > train_end_date]
# test_data = train_data[['Mean Max Temp (°C)', 'Construction']]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Agriculture', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_291d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_291d7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_291d7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_291d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_291d7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_291d7_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_291d7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_291d7_row1_col1" class="data row1 col1" >Agriculture</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_291d7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_291d7_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_291d7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_291d7_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_291d7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_291d7_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_291d7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_291d7_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_291d7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_291d7_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_291d7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_291d7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_291d7_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_
col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_2ba06_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_2ba06_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_2ba06_row4_col1" class="data row4 col1" >3.8033</td>
#       <td id="T_2ba06_row4_col2" class="data row4 col2" >24.7430</td>
#       <td id="T_2ba06_row4_col3" class="data row4 col3" >4.8799</td>
#       <td id="T_2ba06_row4_col4" class="data row4 col4" >0.5839</td>
#       <td id="T_2ba06_row4_col5" class="data row4 col5" >0.0992</td>
#       <td id="T_2ba06_row4_col6" class="data row4 col6" >0.0785</td>
#       <td id="T_2ba06_row4_col7" class="data row4 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_2ba06_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_2ba06_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_2ba06_row5_col1" class="data row5 col1" >3.8207</td>
#       <td id="T_2ba06_row5_col2" class="data row5 col2" >25.1223</td>
#       <td id="T_2ba06_row5_col3" class="data row5 col3" >4.9188</td>
#       <td id="T_2ba06_row5_col4" class="data row5 col4" >0.5784</td>
#       <td id="T_2ba06_row5_col5" class="data row5 col5" >0.1000</td>
#       <td id="T_2ba06_row5_col6" class="data row5 col6

# %% [markdown]
# Lasso Least Angle Regression

# %%
# model creation using PyCaret
model = pycr.create_model('llar', fold = 5)

params = model.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_b4a05_row5_col0, #T_b4a05_row5_col1, #T_b4a05_row5_col2, #T_b4a05_row5_col3, #T_b4a05_row5_col4, #T_b4a05_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b4a05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4a05_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b4a05_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b4a05_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b4a05_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b4a05_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b4a05_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4a05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4a05_row0_col0" class="data row0 col0" >4.2286</td>
#       <td id="T_b4a05_row0_col1" class="data row0 col1" >33.9766</td>
#       <td id="T_b4a05_row0_col2" class="data row0 col2" >5.8289</td>
#       <td id="T_b4a05_row0_col3" class="data row0 col3" >0.5877</td>
#       <td id="T_b4a05_row0_col4" class="data row0 col4" >0.1143</td>
#       <td id="T_b4a05_row0_col5" class="data row0 col5" >0.0858</td>
#     </tr>
#     <tr>
#       <th id="T_b4a05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4a05_row1_col0" class="data row1 col0" >3.9270</td>
#       <td id="T_b4a05_row1_col1" class="data row1 col1" >23.9218</td>
#       <td id="T_b4a05_row1_col2" class="data row1 col2" >4.8910</td>
#       <td id="T_b4a05_row1_col3" class="data row1 col3" >0.5070</td>
#       <td id="T_b4a05_row1_col4" class="data row1 col4" >0.0998</td>
#       <td id="T_b4a05_row1_col5" class="data row1 col5" >0.0786</td>
#     </tr>
#     <tr>
#       <th id="T_b4a05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4a05_row2_col0" class="data row2 col0" >3.3129</td>
#       <td id="T_b4a05_row2_col1" class="data row2 col1" >18.8634</td>
#       <td id="T_b4a05_row2_col2" class="data row2 col2" >4.3432</td>
#       <td id="T_b4a05_row2_col3" class="data row2 col3" >0.7092</td>
#       <td id="T_b4a05_row2_col4" class="data row2 col4" >0.0942</td>
#       <td id="T_b4a05_row2_col5" class="data row2 col5" >0.0732</td>
#     </tr>
#     <tr>
#       <th id="T_b4a05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4a05_row3_col0" class="data row3 col0" >3.7555</td>
#       <td id="T_b4a05_row3_col1" class="data row3 col1" >24.4180</td>
#       <td id="T_b4a05_row3_col2" class="data row3 col2" >4.9415</td>
#       <td id="T_b4a05_row3_col3" class="data row3 col3" >0.5284</td>
#       <td id="T_b4a05_row3_col4" class="data row3 col4" >0.1030</td>
#       <td id="T_b4a05_row3_col5" class="data row3 col5" >0.0789</td>
#     </tr>
#     <tr>
#       <th id="T_b4a05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4a05_row4_col0" class="data row4 col0" >3.8284</td>
#       <td id="T_b4a05_row4_col1" class="data row4 col1" >23.4713</td>
#       <td id="T_b4a05_row4_col2" class="data row4 col2" >4.8447</td>
#       <td id="T_b4a05_row4_col3" class="data row4 col3" >0.6517</td>
#       <td id="T_b4a05_row4_col4" class="data row4 col4" >0.0987</td>
#       <td id="T_b4a05_row4_col5" class="data row4 col5" >0.0779</td>
#     </tr>
#     <tr>
#       <th id="T_b4a05_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_b4a05_row5_col0" class="data row5 col0" >3.8105</td>
#       <td id="T_b4a05_row5_col1" class="data row5 col1" >24.9302</td>
#       <td id="T_b4a05_row5_col2" class="data row5 col2" >4.9699</td>
#       <td id="T_b4a05_row5_col3" class="data row5 col3" >0.5968</td>
#       <td id="T_b4a05_row5_col4" class="data row5 col4" >0.1020</td>
#       <td id="T_b4a05_row5_col5" class="data row5 col5" >0.0789</td>
#     </tr>
#     <tr>
#       <th id="T_b4a05_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b4a05_row6_col0" class="data row6 col0" >0.2964</td>
#       <td id="T_b4a05_row6_col1" class="data row6 col1" >4.9407</td>
#       <td id="T_b4a05_row6_col2" class="data row6 col2" >0.4803</td>
#       <td id="T_b4a05_row6_col3" class="data row6 col3" >0.0755</td>
#       <td id="T_b4a05_row6_col4" class="data row6 col4" >0.0068</td>
#       <td id="T_b4a05_row6_col5" class="data row6 col5" >0.0040</td>
#     </tr>
#   </tbody>
# </table>
# {'alpha': 1.0, 'copy_X': True, 'eps': 2.220446049250313e-16, 'fit_intercept': True, 'fit_path': True, 'jitter': None, 'max_iter': 500, 'positive': False, 'precompute': 'auto', 'random_state': 1234, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_35c5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35c5f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_35c5f_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_35c5f_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_35c5f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_35c5f_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_35c5f_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_35c5f_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35c5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35c5f_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_35c5f_row0_col1" class="data row0 col1" >3.7772</td>
#       <td id="T_35c5f_row0_col2" class="data row0 col2" >24.1478</td>
#       <td id="T_35c5f_row0_col3" class="data row0 col3" >4.9140</td>
#       <td id="T_35c5f_row0_col4" class="data row0 col4" >0.6186</td>
#       <td id="T_35c5f_row0_col5" class="data row0 col5" >0.1000</td>
#       <td id="T_35c5f_row0_col6" class="data row0 col6" >0.0782</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.6185663205781131

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture (Training data)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_438ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_438ce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_438ce_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_438ce_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_438ce_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_438ce_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_438ce_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_438ce_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_438ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_438ce_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_438ce_row0_col1" class="data row0 col1" >12.0502</td>
#       <td id="T_438ce_row0_col2" class="data row0 col2" >171.9096</td>
#       <td id="T_438ce_row0_col3" class="data row0 col3" >13.1114</td>
#       <td id="T_438ce_row0_col4" class="data row0 col4" >-1.1617</td>
#       <td id="T_438ce_row0_col5" class="data row0 col5" >0.2043</td>
#       <td id="T_438ce_row0_col6" class="data row0 col6" >0.1745</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -1.1616594958561919

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture (Test data)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_d35db_row10_col0, #T_d35db_row10_col1, #T_d35db_row10_col2, #T_d35db_row10_col3, #T_d35db_row10_col4, #T_d35db_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d35db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d35db_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d35db_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d35db_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d35db_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d35db_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d35db_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d35db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d35db_row0_col0" class="data row0 col0" >5.0582</td>
#       <td id="T_d35db_row0_col1" class="data row0 col1" >46.6202</td>
#       <td id="T_d35db_row0_col2" class="data row0 col2" >6.8279</td>
#       <td id="T_d35db_row0_col3" class="data row0 col3" >0.5330</td>
#       <td id="T_d35db_row0_col4" class="data row0 col4" >0.1353</td>
#       <td id="T_d35db_row0_col5" class="data row0 col5" >0.1031</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d35db_row1_col0" class="data row1 col0" >3.3143</td>
#       <td id="T_d35db_row1_col1" class="data row1 col1" >20.8997</td>
#       <td id="T_d35db_row1_col2" class="data row1 col2" >4.5716</td>
#       <td id="T_d35db_row1_col3" class="data row1 col3" >0.6675</td>
#       <td id="T_d35db_row1_col4" class="data row1 col4" >0.0877</td>
#       <td id="T_d35db_row1_col5" class="data row1 col5" >0.0664</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d35db_row2_col0" class="data row2 col0" >3.8218</td>
#       <td id="T_d35db_row2_col1" class="data row2 col1" >21.2943</td>
#       <td id="T_d35db_row2_col2" class="data row2 col2" >4.6146</td>
#       <td id="T_d35db_row2_col3" class="data row2 col3" >0.5176</td>
#       <td id="T_d35db_row2_col4" class="data row2 col4" >0.0850</td>
#       <td id="T_d35db_row2_col5" class="data row2 col5" >0.0697</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d35db_row3_col0" class="data row3 col0" >3.3054</td>
#       <td id="T_d35db_row3_col1" class="data row3 col1" >20.2339</td>
#       <td id="T_d35db_row3_col2" class="data row3 col2" >4.4982</td>
#       <td id="T_d35db_row3_col3" class="data row3 col3" >0.5773</td>
#       <td id="T_d35db_row3_col4" class="data row3 col4" >0.0989</td>
#       <td id="T_d35db_row3_col5" class="data row3 col5" >0.0729</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d35db_row4_col0" class="data row4 col0" >3.2635</td>
#       <td id="T_d35db_row4_col1" class="data row4 col1" >16.1002</td>
#       <td id="T_d35db_row4_col2" class="data row4 col2" >4.0125</td>
#       <td id="T_d35db_row4_col3" class="data row4 col3" >0.7941</td>
#       <td id="T_d35db_row4_col4" class="data row4 col4" >0.0873</td>
#       <td id="T_d35db_row4_col5" class="data row4 col5" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d35db_row5_col0" class="data row5 col0" >3.2457</td>
#       <td id="T_d35db_row5_col1" class="data row5 col1" >18.7225</td>
#       <td id="T_d35db_row5_col2" class="data row5 col2" >4.3270</td>
#       <td id="T_d35db_row5_col3" class="data row5 col3" >0.6351</td>
#       <td id="T_d35db_row5_col4" class="data row5 col4" >0.0931</td>
#       <td id="T_d35db_row5_col5" class="data row5 col5" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d35db_row6_col0" class="data row6 col0" >3.1233</td>
#       <td id="T_d35db_row6_col1" class="data row6 col1" >14.5641</td>
#       <td id="T_d35db_row6_col2" class="data row6 col2" >3.8163</td>
#       <td id="T_d35db_row6_col3" class="data row6 col3" >0.4502</td>
#       <td id="T_d35db_row6_col4" class="data row6 col4" >0.0703</td>
#       <td id="T_d35db_row6_col5" class="data row6 col5" >0.0589</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d35db_row7_col0" class="data row7 col0" >4.6087</td>
#       <td id="T_d35db_row7_col1" class="data row7 col1" >36.3242</td>
#       <td id="T_d35db_row7_col2" class="data row7 col2" >6.0270</td>
#       <td id="T_d35db_row7_col3" class="data row7 col3" >0.4650</td>
#       <td id="T_d35db_row7_col4" class="data row7 col4" >0.1304</td>
#       <td id="T_d35db_row7_col5" class="data row7 col5" >0.1033</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d35db_row8_col0" class="data row8 col0" >4.7937</td>
#       <td id="T_d35db_row8_col1" class="data row8 col1" >32.3738</td>
#       <td id="T_d35db_row8_col2" class="data row8 col2" >5.6898</td>
#       <td id="T_d35db_row8_col3" class="data row8 col3" >0.5725</td>
#       <td id="T_d35db_row8_col4" class="data row8 col4" >0.1164</td>
#       <td id="T_d35db_row8_col5" class="data row8 col5" >0.0965</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d35db_row9_col0" class="data row9 col0" >3.1344</td>
#       <td id="T_d35db_row9_col1" class="data row9 col1" >15.8091</td>
#       <td id="T_d35db_row9_col2" class="data row9 col2" >3.9761</td>
#       <td id="T_d35db_row9_col3" class="data row9 col3" >0.7018</td>
#       <td id="T_d35db_row9_col4" class="data row9 col4" >0.0801</td>
#       <td id="T_d35db_row9_col5" class="data row9 col5" >0.0647</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d35db_row10_col0" class="data row10 col0" >3.7669</td>
#       <td id="T_d35db_row10_col1" class="data row10 col1" >24.2942</td>
#       <td id="T_d35db_row10_col2" class="data row10 col2" >4.8361</td>
#       <td id="T_d35db_row10_col3" class="data row10 col3" >0.5914</td>
#       <td id="T_d35db_row10_col4" class="data row10 col4" >0.0984</td>
#       <td id="T_d35db_row10_col5" class="data row10 col5" >0.0778</td>
#     </tr>
#     <tr>
#       <th id="T_d35db_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d35db_row11_col0" class="data row11 col0" >0.7204</td>
#       <td id="T_d35db_row11_col1" class="data row11 col1" >10.0514</td>
#       <td id="T_d35db_row11_col2" class="data row11 col2" >0.9521</td>
#       <td id="T_d35db_row11_col3" class="data row11 col3" >0.1031</td>
#       <td id="T_d35db_row11_col4" class="data row11 col4" >0.0207</td>
#       <td id="T_d35db_row11_col5" class="data row11 col5" >0.0157</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# {'alpha': 1.0, 'copy_X': True, 'eps': 2.220446049250313e-16, 'fit_intercept': True, 'fit_path': True, 'jitter': None, 'max_iter': 500, 'positive': False, 'precompute': 'auto', 'random_state': 1234, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture (Training Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a97a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a97a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a97a7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a97a7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a97a7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a97a7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a97a7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a97a7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a97a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a97a7_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_a97a7_row0_col1" class="data row0 col1" >3.7772</td>
#       <td id="T_a97a7_row0_col2" class="data row0 col2" >24.1478</td>
#       <td id="T_a97a7_row0_col3" class="data row0 col3" >4.9140</td>
#       <td id="T_a97a7_row0_col4" class="data row0 col4" >0.6186</td>
#       <td id="T_a97a7_row0_col5" class="data row0 col5" >0.1000</td>
#       <td id="T_a97a7_row0_col6" class="data row0 col6" >0.0782</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.6185663205781131

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)


# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture (Test Dataset)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8ba37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ba37_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8ba37_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_8ba37_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_8ba37_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_8ba37_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_8ba37_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_8ba37_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ba37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ba37_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_8ba37_row0_col1" class="data row0 col1" >12.0502</td>
#       <td id="T_8ba37_row0_col2" class="data row0 col2" >171.9096</td>
#       <td id="T_8ba37_row0_col3" class="data row0 col3" >13.1114</td>
#       <td id="T_8ba37_row0_col4" class="data row0 col4" >-1.1617</td>
#       <td id="T_8ba37_row0_col5" class="data row0 col5" >0.2043</td>
#       <td id="T_8ba37_row0_col6" class="data row0 col6" >0.1745</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -1.1616594958561919

# %% [markdown]
# (5) Target Variable: Wholesale trade Retail trade

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Health care and social assistance', 'Agriculture']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
# train_data = train_data[['Mean Max Temp (°C)', 'Construction']]
test_data = resampled_con[resampled_con.index > train_end_date]
# test_data = train_data[['Mean Max Temp (°C)', 'Construction']]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Wholesale trade Retail trade', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_49462">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49462_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_49462_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49462_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49462_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_49462_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_49462_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49462_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_49462_row1_col1" class="data row1 col1" >Wholesale trade Retail trade</td>
#     </tr>
#     <tr>
#       <th id="T_49462_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49462_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_49462_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_49462_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49462_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_49462_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_49462_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_49462_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_49462_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_49462_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_49462_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T
f144_row16_col3, #T_bf144_row16_col4, #T_bf144_row16_col5, #T_bf144_row16_col6, #T_bf144_row17_col0, #T_bf144_row17_col1, #T_bf144_row17_col2, #T_bf144_row17_col3, #T_bf144_row17_col4, #T_bf144_row17_col5, #T_bf144_row17_col6, #T_bf144_row18_col0, #T_bf144_row18_col1, #T_bf144_row18_col2, #T_bf144_row18_col3, #T_bf144_row18_col4, #T_bf144_row18_col5, #T_bf144_row18_col6 {
#   text-align: left;
# }
# #T_bf144_row0_col1, #T_bf144_row0_col2, #T_bf144_row0_col3, #T_bf144_row0_col4, #T_bf144_row4_col5, #T_bf144_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_bf144_row0_col7, #T_bf144_row1_col7, #T_bf144_row5_col7, #T_bf144_row6_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_bf144_row2_col7, #T_bf144_row3_col7, #T_bf144_row4_col7, #T_bf144_row7_col7, #T_bf144_row8_col7, #T_bf144_row9_col7, #T_bf144_row10_col7, #T_bf144_row11_col7, #T_bf144_row12_col7, #T_bf144_row13_col7, #T_bf144_row14_col7, #T_bf144_row15_col7, #T_bf144_row16_col7, #T_bf144_row17_col7, #T_bf144_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_bf144">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf144_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bf144_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bf144_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bf144_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bf144_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bf144_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bf144_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_bf144_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf144_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_bf144_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_bf144_row0_col1" class="data row0 col1" >20.2673</td>
#       <td id="T_bf144_row0_col2" class="data row0 col2" >734.2625</td>
#       <td id="T_bf144_row0_col3" class="data row0 col3" >25.7327</td>
#       <td id="T_bf144_row0_col4" class="data row0 col4" >0.9004</td>
#       <td id="T_bf144_row0_col5" class="data row0 col5" >0.1002</td>
#       <td id="T_bf144_row0_col6" class="data row0 col6" >0.0781</td>
#       <td id="T_bf144_row0_col7" class="data row0 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_bf144_level0_row1" class="row_heading level0 row1" >en</th>
#       <td id="T_bf144_row1_col0" class="data row1 col0" >Elastic Net</td>
#       <td id="T_bf144_row1_col1" class="data row1 col1" >20.3095</td>
#       <td id="T_bf144_row1_col2" class="data row1 col2" >735.5080</td>
#       <td id="T_bf144_row1_col3" class="data row1 col3" >25.7823</td>
#       <td id="T_bf144_row1_col4" class="data row1 col4" >0.9002</td>
#       <td id="T_bf144_row1_col5" class="data row1 col5" >0.1006</td>
#       <td id="T_bf144_row1_col6" class="data row1 col6" >0.0783</td>
#       <td id="T_bf144_row1_col7" class="data row1 col7" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_bf144_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_bf144_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_bf144_row2_col1" class="data row2 col1" >20.3424</td>
#       <td id="T_bf144_row2_col2" class="data row2 col2" >737.6558</td>
#       <td id="T_bf144_row2_col3" class="data row2 col3" >25.8382</td>
#       <td id="T_bf144_row2_col4" class="data row2 col4" >0.8999</td>
#       <td id="T_bf144_row2_col5" class="data row2 col5" >0.1010</td>
#       <td id="T_bf144_row2_col6" class="data row2 col6" >0.0784</td>
#       <td id="T_bf144_row2_col7" class="data row2 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_bf144_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_bf144_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_bf144_row3_col1" class="data row3 col1" >20.3429</td>
#       <td id="T_bf144_row3_col2" class="data row3 col2" >737.6480</td>
#       <td id="T_bf144_row3_col3" class="data row3 col3" >25.8387</td>
#       <td id="T_bf144_row3_col4" class="data row3 col4" >0.8999</td>
#       <td id="T_bf144_row3_col5" class="data row3 col5" >0.1010</td>
#       <td id="T_bf144_row3_col6" class="data row3 col6" >0.0784</td>
#       <td id="T_bf144_row3_col7" class="data row3 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_bf144_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_bf144_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_bf144_row4_col1" class="data row4 col1" >20.5304</td>
#       <td id="T_bf144_row4_col2" class="data row4 col2" >745.4951</td>
#       <td id="T_bf144_row4_col3" class="data row4 col3" >25.9227</td>
#       <td id="T_bf144_row4_col4" class="data row4 col4" >0.8988</td>
#       <td id="T_bf144_row4_col5" class="data row4 col5" >0.0843</td>
#       <td id="T_bf144_row4_col6" class="data row4 col6" >0.0706</td>
#       <td id="T_bf144_row4_col7" class="data row4 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_bf144_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_bf144_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_bf144_row5_col1" class="data row5 col1" >20.5820</td>
#       <td id="T_bf144_row5_col2" class="data row5 col2" >754.6105</td>
#       <td id="T_bf144_row5_col3" class="data row5 col3" >26.1772</td>
#       <td id="T_bf144_row5_col4" class="data row5 col4" >0.8975</td>
#       <td id="T_bf144_row5_col5" class="data row5 col5" >0.1026</td>
#       <td id="T_bf144_row5_col6

# %% [markdown]
# Bayesian Ridge

# %%
# model creation using PyCaret
model = pycr.create_model('br', fold = 5)

params = model.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_2fe3d_row5_col0, #T_2fe3d_row5_col1, #T_2fe3d_row5_col2, #T_2fe3d_row5_col3, #T_2fe3d_row5_col4, #T_2fe3d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_2fe3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fe3d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2fe3d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2fe3d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2fe3d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2fe3d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_2fe3d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fe3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fe3d_row0_col0" class="data row0 col0" >26.8983</td>
#       <td id="T_2fe3d_row0_col1" class="data row0 col1" >1335.3774</td>
#       <td id="T_2fe3d_row0_col2" class="data row0 col2" >36.5428</td>
#       <td id="T_2fe3d_row0_col3" class="data row0 col3" >0.8289</td>
#       <td id="T_2fe3d_row0_col4" class="data row0 col4" >0.1379</td>
#       <td id="T_2fe3d_row0_col5" class="data row0 col5" >0.1062</td>
#     </tr>
#     <tr>
#       <th id="T_2fe3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2fe3d_row1_col0" class="data row1 col0" >16.4352</td>
#       <td id="T_2fe3d_row1_col1" class="data row1 col1" >404.2619</td>
#       <td id="T_2fe3d_row1_col2" class="data row1 col2" >20.1063</td>
#       <td id="T_2fe3d_row1_col3" class="data row1 col3" >0.9399</td>
#       <td id="T_2fe3d_row1_col4" class="data row1 col4" >0.0822</td>
#       <td id="T_2fe3d_row1_col5" class="data row1 col5" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_2fe3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2fe3d_row2_col0" class="data row2 col0" >21.6485</td>
#       <td id="T_2fe3d_row2_col1" class="data row2 col1" >725.6819</td>
#       <td id="T_2fe3d_row2_col2" class="data row2 col2" >26.9385</td>
#       <td id="T_2fe3d_row2_col3" class="data row2 col3" >0.9093</td>
#       <td id="T_2fe3d_row2_col4" class="data row2 col4" >0.0968</td>
#       <td id="T_2fe3d_row2_col5" class="data row2 col5" >0.0787</td>
#     </tr>
#     <tr>
#       <th id="T_2fe3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2fe3d_row3_col0" class="data row3 col0" >22.1658</td>
#       <td id="T_2fe3d_row3_col1" class="data row3 col1" >893.1039</td>
#       <td id="T_2fe3d_row3_col2" class="data row3 col2" >29.8848</td>
#       <td id="T_2fe3d_row3_col3" class="data row3 col3" >0.8819</td>
#       <td id="T_2fe3d_row3_col4" class="data row3 col4" >0.1102</td>
#       <td id="T_2fe3d_row3_col5" class="data row3 col5" >0.0819</td>
#     </tr>
#     <tr>
#       <th id="T_2fe3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2fe3d_row4_col0" class="data row4 col0" >14.4171</td>
#       <td id="T_2fe3d_row4_col1" class="data row4 col1" >337.2895</td>
#       <td id="T_2fe3d_row4_col2" class="data row4 col2" >18.3654</td>
#       <td id="T_2fe3d_row4_col3" class="data row4 col3" >0.9493</td>
#       <td id="T_2fe3d_row4_col4" class="data row4 col4" >0.0832</td>
#       <td id="T_2fe3d_row4_col5" class="data row4 col5" >0.0616</td>
#     </tr>
#     <tr>
#       <th id="T_2fe3d_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_2fe3d_row5_col0" class="data row5 col0" >20.3130</td>
#       <td id="T_2fe3d_row5_col1" class="data row5 col1" >739.1429</td>
#       <td id="T_2fe3d_row5_col2" class="data row5 col2" >26.3676</td>
#       <td id="T_2fe3d_row5_col3" class="data row5 col3" >0.9019</td>
#       <td id="T_2fe3d_row5_col4" class="data row5 col4" >0.1020</td>
#       <td id="T_2fe3d_row5_col5" class="data row5 col5" >0.0781</td>
#     </tr>
#     <tr>
#       <th id="T_2fe3d_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_2fe3d_row6_col0" class="data row6 col0" >4.4358</td>
#       <td id="T_2fe3d_row6_col1" class="data row6 col1" >361.3896</td>
#       <td id="T_2fe3d_row6_col2" class="data row6 col2" >6.6253</td>
#       <td id="T_2fe3d_row6_col3" class="data row6 col3" >0.0435</td>
#       <td id="T_2fe3d_row6_col4" class="data row6 col4" >0.0206</td>
#       <td id="T_2fe3d_row6_col5" class="data row6 col5" >0.0164</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# {'alpha_1': 1e-06, 'alpha_2': 1e-06, 'alpha_init': None, 'compute_score': False, 'copy_X': True, 'fit_intercept': True, 'lambda_1': 1e-06, 'lambda_2': 1e-06, 'lambda_init': None, 'max_iter': None, 'n_iter': 'deprecated', 'tol': 0.001, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd079">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd079_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_bd079_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_bd079_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_bd079_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_bd079_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_bd079_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_bd079_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd079_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd079_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_bd079_row0_col1" class="data row0 col1" >20.0218</td>
#       <td id="T_bd079_row0_col2" class="data row0 col2" >737.2156</td>
#       <td id="T_bd079_row0_col3" class="data row0 col3" >27.1517</td>
#       <td id="T_bd079_row0_col4" class="data row0 col4" >0.9024</td>
#       <td id="T_bd079_row0_col5" class="data row0 col5" >0.1054</td>
#       <td id="T_bd079_row0_col6" class="data row0 col6" >0.0786</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.9023790905330784

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade (Training data)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# R-squared (R2) Score: -0.8981616711460569

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade (Test data)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   20:49:02
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .             Bayesian Ridge
# <style type="text/css">
# #T_9e5a7_row10_col0, #T_9e5a7_row10_col1, #T_9e5a7_row10_col2, #T_9e5a7_row10_col3, #T_9e5a7_row10_col4, #T_9e5a7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9e5a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e5a7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9e5a7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9e5a7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9e5a7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9e5a7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9e5a7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e5a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e5a7_row0_col0" class="data row0 col0" >26.4154</td>
#       <td id="T_9e5a7_row0_col1" class="data row0 col1" >973.3542</td>
#       <td id="T_9e5a7_row0_col2" class="data row0 col2" >31.1986</td>
#       <td id="T_9e5a7_row0_col3" class="data row0 col3" >0.8846</td>
#       <td id="T_9e5a7_row0_col4" class="data row0 col4" >0.1230</td>
#       <td id="T_9e5a7_row0_col5" class="data row0 col5" >0.1027</td>
#     </tr>
#     <tr>
#       <th id="T_9e5a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e5a7_row1_col0" class="data row1 col0" >26.8471</td>
#       <td id="T_9e5a7_row1_col1" class="data row1 col1" >1674.4937</td>
#       <td id="T_9e5a7_row1_col2" class="data row1 col2" >40.9206</td>
#       <td id="T_9e5a7_row1_col3" class="data row1 col3" >0.7635</td>
#       <td id="T_9e5a7_row1_col4" class="data row1 col4" >0.1489</td>
#       <td id="T_9e5a7_row1_col5" class="data row1 col5" >0.1065</td>
#     </tr>
#     <tr>
#       <th id="T_9e5a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9e5a7_row2_col0" class="data row2 col0" >11.4543</td>
#       <td id="T_9e5a7_row2_col1" class="data row2 col1" >203.4781</td>
#       <td id="T_9e5a7_row2_col2" class="data row2 col2" >14.2646</td>
#       <td id="T_9e5a7_row2_col3" class="data row2 col3" >0.9678</td>
#       <td id="T_9e5a7_row2_col4" class="data row2 col4" >0.0623</td>
#       <td id="T_9e5a7_row2_col5" class="data row2 col5" >0.0449</td>
#     </tr>
#     <tr>
#       <th id="T_9e5a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9e5a7_row3_col0" class="data row3 col0" >20.7391</td>
#       <td id="T_9e5a7_row3_col1" class="data row3 col1" >582.9948</td>
#       <td id="T_9e5a7_row3_col2" class="data row3 col2" >24.1453</td>
#       <td id="T_9e5a7_row3_col3" class="data row3 col3" >0.9172</td>
#       <td id="T_9e5a7_row3_col4" class="data row3 col4" >0.0981</td>
#       <td id="T_9e5a7_row3_col5" class="data row3 col5" >0.0781</td>
#     </tr>
#     <tr>
#       <th id="T_9e5a7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9e5a7_row4_col0" class="data row4 col0" >19.7204</td>
#       <td id="T_9e5a7_row4_col1" class="data row4 col1" >672.8457</td>
#       <td id="T_9e5a7_row4_col2" class="data row4 col2" >25.9393</td>
#       <td id="T_9e5a7_row4_col3" class="data row4 col3" >0.9257</td>
#       <td id="T_9e5a7_row4_col4" class="data row4 col4" >0.0919</td>
#       <td id="T_9e5a7_row4_col5" class="data row4 col5" >0.0723</td>
#     </tr>
#     <tr>
#       <th id="T_9e5a7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9
td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'alpha_1': 0.1, 'alpha_2': 0.15, 'alpha_init': None, 'compute_score': True, 'copy_X': True, 'fit_intercept': True, 'lambda_1': 0.3, 'lambda_2': 0.1, 'lambda_init': None, 'max_iter': None, 'n_iter': 'deprecated', 'tol': 0.001, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f29f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f29f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f29f6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f29f6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f29f6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f29f6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f29f6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f29f6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f29f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f29f6_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_f29f6_row0_col1" class="data row0 col1" >20.0301</td>
#       <td id="T_f29f6_row0_col2" class="data row0 col2" >738.0011</td>
#       <td id="T_f29f6_row0_col3" class="data row0 col3" >27.1662</td>
#       <td id="T_f29f6_row0_col4" class="data row0 col4" >0.9023</td>
#       <td id="T_f29f6_row0_col5" class="data row0 col5" >0.1055</td>
#       <td id="T_f29f6_row0_col6" class="data row0 col6" >0.0786</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.9022750865926519

# %%
# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade (Training data)',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# R-squared (R2) Score: -0.9008819207816627

# %%
# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade (Test data)',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
