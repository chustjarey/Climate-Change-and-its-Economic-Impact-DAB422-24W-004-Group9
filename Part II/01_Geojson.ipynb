# %% [markdown]
# ## GEOJSON ##

# %%
# import libraries

import pandas as pd
import geopandas as gpd

# %%
# import geojson files

geography = gpd.read_file('combined_geographies_geojson.geojson') # output from CP-part1

# %%
# to split the multipolygon into individual polygons | results to more rows

geography_clean = geography.explode()
geography_clean = geography_clean.reset_index(drop = True)
geography_clean.head()
# Out:
# C:\Users\chust\AppData\Local\Temp\ipykernel_59356\1392617380.py:3: FutureWarning: Currently, index_parts defaults to True, but in the future, it will default to False to be consistent with Pandas. Use `index_parts=True` to keep the current behavior and True/False to silence the warning.
#   geography_clean = geography.explode()
#     GeoUID                   Region.Name provincename  \
# 0  4801003           Cypress County (MD)      Alberta
# 1  4801006             Medicine Hat (CY)      Alberta
# 2  4801008  Forty Mile County No. 8 (MD)      Alberta
# 3  4801009                 Foremost (VL)      Alberta
# 4  4801014                Bow Island (T)      Alberta
#
#                                             geometry
# 0  POLYGON ((-110.00300 50.83380, -110.00330 50.8...
# 1  POLYGON ((-110.80100 50.05270, -110.79930 50.0...
# 2  POLYGON ((-110.67380 48.99870, -110.75010 48.9...
# 3  POLYGON ((-111.43600 49.46490, -111.43760 49.4...
# 4  POLYGON ((-111.36920 49.88710, -111.36920 49.8...

# %%
# to get the minimun and maximum values of longitude and latitude from the geometry column

geojson_bound_coordinates = geography_clean['geometry']
min_max_xy = geojson_bound_coordinates.bounds

min_max_xy
# Out:
#            minx     miny      maxx     maxy
# 0     -111.6984  48.9987 -110.0030  50.8338
# 1     -110.8010  49.9893 -110.6177  50.1132
# 2     -111.9016  48.9972 -110.5424  50.0692
# 3     -111.4631  49.4649 -111.4358  49.4846
# 4     -111.3930  49.8588 -111.3295  49.8874
# ...         ...      ...       ...      ...
# 32802 -136.0258  60.7660 -135.2729  60.8963
# 32803 -132.8086  60.1903 -132.7264  60.2672
# 32804 -134.7041  60.2764 -133.8828  60.6793
# 32805 -135.9887  60.7496 -134.9649  61.2700
# 32806 -135.9410  60.0000 -134.2056  61.2490
#
# [32807 rows x 4 columns]

# %%
# to append the min and max values of longitude and latitude to the clean df

geography_clean['min_longitude'] = min_max_xy['minx']
geography_clean['min_latitude'] = min_max_xy['miny']
geography_clean['max_longitude'] = min_max_xy['maxx']
geography_clean['max_latitude'] = min_max_xy['maxy']

# to check updated dataset
geography_clean
# Out:
#         GeoUID                     Region.Name provincename  \
# 0      4801003             Cypress County (MD)      Alberta
# 1      4801006               Medicine Hat (CY)      Alberta
# 2      4801008    Forty Mile County No. 8 (MD)      Alberta
# 3      4801009                   Foremost (VL)      Alberta
# 4      4801014                  Bow Island (T)      Alberta
# ...        ...                             ...          ...
# 32802  6001055               Ibex Valley (HAM)        Yukon
# 32803  6001057                     Teslin (TL)        Yukon
# 32804  6001058                 Marsh Lake (NO)        Yukon
# 32805  6001059  Macpherson-Grizzly Valley (NO)        Yukon
# 32806  6001060    Whitehorse, Unorganized (NO)        Yukon
#
#                                                 geometry  min_longitude  \
# 0      POLYGON ((-110.00300 50.83380, -110.00330 50.8...      -111.6984
# 1      POLYGON ((-110.80100 50.05270, -110.79930 50.0...      -110.8010
# 2      POLYGON ((-110.67380 48.99870, -110.75010 48.9...      -111.9016
# 3      POLYGON ((-111.43600 49.46490, -111.43760 49.4...      -111.4631
# 4      POLYGON ((-111.36920 49.88710, -111.36920 49.8...      -111.3930
# ...                                                  ...            ...
# 32802  POLYGON ((-135.98870 60.82550, -135.95770 60.8...      -136.0258
# 32803  POLYGON ((-132.73940 60.23410, -132.73740 60.2...      -132.8086
# 32804  POLYGON ((-134.20560 60.67930, -134.11920 60.6...      -134.7041
# 32805  POLYGON ((-134.96490 60.74960, -135.00170 60.7...      -135.9887
# 32806  POLYGON ((-134.20560 60.67930, -134.22340 60.6...      -135.9410
#
#        min_latitude  max_longitude  max_latitude
# 0           48.9987      -110.0030       50.8338
# 1           49.9893      -110.6177       50.1132
# 2           48.9972      -110.5424       50.0692
# 3           49.4649      -111.4358       49.4846
# 4           49.8588      -111.3295       49.8874
# ...             ...            ...           ...
# 32802       60.7660      -135.2729       60.8963
# 32803       60.1903      -132.7264       60.2672
# 32804       60.2764      -133.8828       60.6793
# 32805       60.7496      -134.9649       61.2700
# 32806       60.0000      -134.2056       61.2490
#
# [32807 rows x 8 columns]

# %%
# to drop "geometry" column 

geography_clean.drop(columns = ['geometry'],
                             inplace = True)
geography_clean
# Out:
#         GeoUID                     Region.Name provincename  min_longitude  \
# 0      4801003             Cypress County (MD)      Alberta      -111.6984
# 1      4801006               Medicine Hat (CY)      Alberta      -110.8010
# 2      4801008    Forty Mile County No. 8 (MD)      Alberta      -111.9016
# 3      4801009                   Foremost (VL)      Alberta      -111.4631
# 4      4801014                  Bow Island (T)      Alberta      -111.3930
# ...        ...                             ...          ...            ...
# 32802  6001055               Ibex Valley (HAM)        Yukon      -136.0258
# 32803  6001057                     Teslin (TL)        Yukon      -132.8086
# 32804  6001058                 Marsh Lake (NO)        Yukon      -134.7041
# 32805  6001059  Macpherson-Grizzly Valley (NO)        Yukon      -135.9887
# 32806  6001060    Whitehorse, Unorganized (NO)        Yukon      -135.9410
#
#        min_latitude  max_longitude  max_latitude
# 0           48.9987      -110.0030       50.8338
# 1           49.9893      -110.6177       50.1132
# 2           48.9972      -110.5424       50.0692
# 3           49.4649      -111.4358       49.4846
# 4           49.8588      -111.3295       49.8874
# ...             ...            ...           ...
# 32802       60.7660      -135.2729       60.8963
# 32803       60.1903      -132.7264       60.2672
# 32804       60.2764      -133.8828       60.6793
# 32805       60.7496      -134.9649       61.2700
# 32806       60.0000      -134.2056       61.2490
#
# [32807 rows x 7 columns]

# %%
# to get the min and max values from the duplicated rows

geography_clean = geography_clean.groupby(['GeoUID', 
                                            'Region.Name', 
                                            'provincename']).agg(min_longitude = ('min_longitude', 'min'),
                                                                 max_longitude = ('max_longitude', 'max'),
                                                                 min_latitude = ('min_latitude', 'min'),
                                                                 max_latitude = ('max_latitude', 'max')).reset_index()

# %%
# to check data

geography_clean
# Out:
#        GeoUID                     Region.Name               provincename  \
# 0     1001101  Division No.  1, Subd. V (SNO)  Newfoundland and Labrador
# 1     1001105         Portugal Cove South (T)  Newfoundland and Labrador
# 2     1001113                   Trepassey (T)  Newfoundland and Labrador
# 3     1001120                 St. Shott's (T)  Newfoundland and Labrador
# 4     1001124  Division No.  1, Subd. U (SNO)  Newfoundland and Labrador
# ...       ...                             ...                        ...
# 5157  6208068               Umingmaktok (SET)                    Nunavut
# 5158  6208073             Cambridge Bay (HAM)                    Nunavut
# 5159  6208081                Gjoa Haven (HAM)                    Nunavut
# 5160  6208087                  Taloyoak (HAM)                    Nunavut
# 5161  6208098     Kitikmeot, Unorganized (NO)                    Nunavut
#
#       min_longitude  max_longitude  min_latitude  max_latitude
# 0          -53.6508       -53.0045       46.6111       46.9979
# 1          -53.2618       -53.2498       46.7011       46.7170
# 2          -53.4166       -53.3158       46.6885       46.7835
# 3          -53.5952       -53.5755       46.6289       46.6392
# 4          -53.2651       -52.7789       46.7561       47.2894
# ...             ...            ...           ...           ...
# 5157      -108.0283      -107.7360       67.6027       67.7568
# 5158      -105.4180      -104.9311       69.0557       69.2229
# 5159       -95.9975       -95.8105       68.6050       68.6769
# 5160       -93.6245       -93.3805       69.5070       69.5977
# 5161      -120.7249       -88.9851       64.4774       73.7378
#
# [5162 rows x 7 columns]

# %%
# to output the file into a csv format

csv_path = 'geography_clean.csv'
geography_clean.to_csv(csv_path, 
                        index = False)
