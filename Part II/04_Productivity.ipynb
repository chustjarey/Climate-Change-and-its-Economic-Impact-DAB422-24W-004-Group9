# %% [markdown]
# ## PRODUCTIVITY FOR 5 PROVINCES ##

# %%
# import libraries

import pandas as pd

# ignore all warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# to load productivity data

productivity = pd.read_csv('combined_productivity_clean.csv') # 

productivity.head()
# Out:
#          Date provincename  Utilities  Construction  Manufacturing  \
# 0  1997-01-01      Alberta   1.485804     17.399965      18.590137
# 1  1997-02-01      Alberta   1.471049     17.695034      19.034434
# 2  1997-03-01      Alberta   1.411428     16.630237      19.274297
# 3  1997-04-01      Alberta   1.465141     16.642340      19.578348
# 4  1997-05-01      Alberta   1.623730     18.062713      19.621579
#
#    Transportation and warehousing  Educational services  \
# 0                       13.340542             11.588955
# 1                       13.617536             11.890582
# 2                       14.453078             11.962199
# 3                       13.256295             12.456337
# 4                       13.355093             12.027437
#
#    Health care and social assistance  Accommodation and food services  \
# 0                          13.343328                         3.872117
# 1                          13.739512                         3.734915
# 2                          13.321957                         3.790906
# 3                          14.011986                         4.100418
# 4                          13.889241                         4.119427
#
#    Other services except public administration  ...  \
# 0                                     5.368650  ...
# 1                                     5.496880  ...
# 2                                     5.773114  ...
# 3                                     5.658535  ...
# 4                                     5.613666  ...
#
#    Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction  \
# 0                                         362.713936
# 1                                         368.185093
# 2                                         385.806995
# 3                                         393.425984
# 4                                         385.021311
#
#    Wholesale trade Retail trade  \
# 0                     17.907676
# 1                     17.586050
# 2                     17.377787
# 3                     17.690151
# 4                     16.922974
#
#    Finance and insurance, real estate and rental and leasing  \
# 0                                          24.135310
# 1                                          23.488937
# 2                                          22.444308
# 3                                          22.302734
# 4                                          24.040353
#
#    Professional scientific and technical services  \
# 0                                       15.578428
# 1                                       16.206769
# 2                                       15.380479
# 3                                       15.873826
# 4                                       15.534059
#
#    Information culture and recreation  Population   GeoUID  census_year_ref  \
# 0                            7.600796      7662.0  4801003             CA16
# 1                            7.283954      7662.0  4801003             CA16
# 2                            7.683184      7662.0  4801003             CA16
# 3                            7.369425      7662.0  4801003             CA16
# 4                            7.534485      7662.0  4801003             CA16
#
#                                       Dominant_NAICS colourval
# 0  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 1  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 2  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 3  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
# 4  X11.Agriculture.forestry.fishing.hunting.21.Mi...   #8DA0CB
#
# [5 rows x 21 columns]

# %%
productivity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1342800 entries, 0 to 1342799
# Data columns (total 21 columns):
#  #   Column                                                                             Non-Null Count    Dtype
# ---  ------                                                                             --------------    -----
#  0   Date                                                                               1342800 non-null  object
#  1   provincename                                                                       1342800 non-null  object
#  2   Utilities                                                                          1342800 non-null  float64
#  3   Construction                                                                       1342800 non-null  float64
#  4   Manufacturing                                                                      1342800 non-null  float64
#  5   Transportation and warehousing                                                     1342800 non-null  float64
#  6   Educational services                                                               1342800 non-null  float64
#  7   Health care and social assistance                                                  1342800 non-null  float64
#  8   Accommodation and food services                                                    1342800 non-null  float64
#  9   Other services except public administration                                        1342800 non-null  float64
#  10  Public administration                                                              1342800 non-null  float64
#  11  Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction  1342800 non-null  float64
#  12  Wholesale trade Retail trade                                                       1342800 non-null  float64
#  13  Finance and insurance, real estate and rental and leasing                          1342800 non-null  float64
#  14  Professional scientific and technical services                                     1342800 non-null  float64
#  15  Information culture and recreation                                                 1342800 non-null  float64
#  16  Population                                                                         1342800 non-null  float64
#  17  GeoUID                                                                             1342800 non-null  int64
#  18  census_year_ref                                                                    1342800 non-null  object
#  19  Dominant_NAICS                                                                     1342800 non-null  object
#  20  colourval                                                                          1342800 non-null  object
# dtypes: float64(15), int64(1), object(5)
# memory usage: 215.1+ MB

# %%
#checking for missing values
productivity.isnull().sum()
# Out:
# Date                                                                                 0
# provincename                                                                         0
# Utilities                                                                            0
# Construction                                                                         0
# Manufacturing                                                                        0
# Transportation and warehousing                                                       0
# Educational services                                                                 0
# Health care and social assistance                                                    0
# Accommodation and food services                                                      0
# Other services except public administration                                          0
# Public administration                                                                0
# Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction    0
# Wholesale trade Retail trade                                                         0
# Finance and insurance, real estate and rental and leasing                            0
# Professional scientific and technical services                                       0
# Information culture and recreation                                                   0
# Population                                                                           0
# GeoUID                                                                               0
# census_year_ref                                                                      0
# Dominant_NAICS                                                                       0
# colourval                                                                            0
# dtype: int64

# %%
# update data column to datatime format
productivity['Date/Time'] = pd.to_datetime(productivity['Date'])
productivity
# Out:
#                Date  provincename  Utilities  Construction  Manufacturing  \
# 0        1997-01-01       Alberta   1.485804     17.399965      18.590137
# 1        1997-02-01       Alberta   1.471049     17.695034      19.034434
# 2        1997-03-01       Alberta   1.411428     16.630237      19.274297
# 3        1997-04-01       Alberta   1.465141     16.642340      19.578348
# 4        1997-05-01       Alberta   1.623730     18.062713      19.621579
# ...             ...           ...        ...           ...            ...
# 1342795  2021-08-01  Saskatchewan   2.829359      0.909181       1.765590
# 1342796  2021-09-01  Saskatchewan   3.860524      0.861926       1.813471
# 1342797  2021-10-01  Saskatchewan   3.350091      0.890384       1.686692
# 1342798  2021-11-01  Saskatchewan   3.166056      0.886212       1.862323
# 1342799  2021-12-01  Saskatchewan   3.617298      0.904056       1.806240
#
#          Transportation and warehousing  Educational services  \
# 0                             13.340542             11.588955
# 1                             13.617536             11.890582
# 2                             14.453078             11.962199
# 3                             13.256295             12.456337
# 4                             13.355093             12.027437
# ...                                 ...                   ...
# 1342795                        0.000000              2.069695
# 1342796                        0.000000              2.696269
# 1342797                        0.000000              2.679829
# 1342798                        0.000000              2.630175
# 1342799                        0.000000              2.707189
#
#          Health care and social assistance  Accommodation and food services  \
# 0                                13.343328                         3.872117
# 1                                13.739512                         3.734915
# 2                                13.321957                         3.790906
# 3                                14.011986                         4.100418
# 4                                13.889241                         4.119427
# ...                                    ...                              ...
# 1342795                           2.977844                         0.000000
# 1342796                           3.098698                         0.000000
# 1342797                           3.119581                         0.000000
# 1342798                           3.122140                         0.000000
# 1342799                           3.093373                         0.000000
#
#          Other services except public administration  ...  \
# 0                                           5.368650  ...
# 1                                           5.496880  ...
# 2                                           5.773114  ...
# 3                                           5.658535  ...
# 4                                           5.613666  ...
# ...                                              ...  ...
# 1342795                                     0.000000  ...
# 1342796                                     0.000000  ...
# 1342797                                     0.000000  ...
# 1342798                                     0.000000  ...
# 1342799                                     0.000000  ...
#
#          Wholesale trade Retail trade  \
# 0                           17.907676
# 1                           17.586050
# 2                           17.377787
# 3                           17.690151
# 4                           16.922974
# ...                               ...
# 1342795                      0.000000
# 1342796                      0.000000
# 1342797                      0.000000
# 1342798                      0.000000
# 1342799                      0.000000
#
#          Finance and insurance, real estate and rental and leasing  \
# 0                                                24.135310
# 1                                                23.488937
# 2                                                22.444308
# 3                                                22.302734
# 4                                                24.040353
# ...                                                    ...
# 1342795                                           0.000000
# 1342796                                           0.000000
# 1342797                                           0.000000
# 1342798                                           0.000000
# 1342799                                           0.000000
#
#          Professional scientific and technical services  \
# 0                                             15.578428
# 1                                             16.206769
# 2                                             15.380479
# 3                                             15.873826
# 4                                             15.534059
# ...                                                 ...
# 1342795                                        0.000000
# 1342796                                        0.000000
# 1342797                                        0.000000
# 1342798                                        0.000000
# 1342799                                        0.000000
#
#          Information culture and recreation  Population   GeoUID  \
# 0                                  7.600796      7662.0  4801003
# 1                                  7.283954      7662.0  4801003
# 2                                  7.683184      7662.0  4801003
# 3                                  7.369425      7662.0  4801003
# 4                                  7.534485      7662.0  4801003
# ...                                     ...         ...      ...
# 1342795                            0.000000      1061.0  4718852
# 1342796                            0.000000      1061.0  4718852
# 1342797                            0.000000      1061.0  4718852
# 1342798                            0.000000      1061.0  4718852
# 1342799                            0.000000      1061.0  4718852
#
#          census_year_ref                                     Dominant_NAICS  \
# 0                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 1                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 2                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 3                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# 4                   CA16  X11.Agriculture.forestry.fishing.hunting.21.Mi...
# ...                  ...                                                ...
# 1342795             CA16                          X91.Public.administration
# 1342796             CA16                          X91.Public.administration
# 1342797             CA16                          X91.Public.administration
# 1342798             CA16                          X91.Public.administration
# 1342799             CA16                          X91.Public.administration
#
#         colourval  Date/Time
# 0         #8DA0CB 1997-01-01
# 1         #8DA0CB 1997-02-01
# 2         #8DA0CB 1997-03-01
# 3         #8DA0CB 1997-04-01
# 4         #8DA0CB 1997-05-01
# ...           ...        ...
# 1342795   #FC8D62 2021-08-01
# 1342796   #FC8D62 2021-09-01
# 1342797   #FC8D62 2021-10-01
# 1342798   #FC8D62 2021-11-01
# 1342799   #FC8D62 2021-12-01
#
# [1342800 rows x 22 columns]

# %%
# to check  productivity date range
print(productivity['Date/Time'].min())
print(productivity['Date/Time'].max())
# Out:
# 1997-01-01 00:00:00
# 2021-12-01 00:00:00

# %%
# to remove 1997 data to be consistent with the weather dataset
prod_clean = productivity[productivity['Date/Time'] >= '1998-01-01']
print(prod_clean['Date/Time'].min())
print(prod_clean['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2021-12-01 00:00:00

# %%
# to filter 5 provinces
filter = ['Quebec', 'Ontario', 'British Columbia', 'Alberta', 'Saskatchewan']
prod_clean = prod_clean[prod_clean['provincename'].isin(filter)]
prod_clean['provincename'].unique()
# Out:
# array(['Alberta', 'British Columbia', 'Ontario', 'Quebec', 'Saskatchewan'],
#       dtype=object)

# %%
# to load weather_geography_merged data

weather_1998_2018Feb = pd.read_csv('weather_geography_merged_1998_to_2018Feb.csv')
weather_2018_2024 = pd.read_csv('final_merged_weather_2018_2024.csv')

# %%
# to convert the "Date/Time" column to date format
weather_1998_2018Feb['Date/Time'] = pd.to_datetime(weather_1998_2018Feb['Date/Time'])
weather_2018_2024['Date/Time'] = pd.to_datetime(weather_2018_2024['Date/Time'])

# to remove overlapping data (2018 Jan and Feb data)
weather_1998_2018Feb = weather_1998_2018Feb[weather_1998_2018Feb['Date/Time'] <= '2017-12-01']

# # to filter the 5 provinces
filter = ['Quebec', 'Ontario', 'British Columbia', 'Alberta', 'Saskatchewan']
weather_1998_2018Feb = weather_1998_2018Feb[weather_1998_2018Feb['provincename'].isin(filter)]
print(weather_1998_2018Feb['provincename'].unique())

# # to remove data from Feb 2024
weather_2018_2024 = weather_2018_2024[weather_2018_2024['Date/Time'] <= '2024-01-01']
# Out:
# ['Quebec' 'Ontario' 'Saskatchewan' 'Alberta' 'British Columbia']

# %%
# to check date range of productivity

print(prod_clean['Date/Time'].min())
print(prod_clean['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2021-12-01 00:00:00

# %%
# to check date range of final weather

print(weather_1998_2018Feb['Date/Time'].min())
print(weather_1998_2018Feb['Date/Time'].max())

print(weather_2018_2024['Date/Time'].min())
print(weather_2018_2024['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2017-12-01 00:00:00
# 2018-01-01 00:00:00
# 2024-01-01 00:00:00

# %%
# to merge the 2 weather datasets
merged_weather = pd.concat([weather_1998_2018Feb, weather_2018_2024])
merged_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79154 entries, 3599 to 24271
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Longitude                  79154 non-null  float64
#  1   Latitude                   79154 non-null  float64
#  2   Station Name               79154 non-null  object
#  3   Climate ID                 79154 non-null  object
#  4   Date/Time                  79154 non-null  datetime64[ns]
#  5   Year                       79154 non-null  int64
#  6   Month                      79154 non-null  int64
#  7   Mean Max Temp (°C)         76760 non-null  float64
#  8   Mean Max Temp Flag         54882 non-null  object
#  9   Mean Min Temp (°C)         76775 non-null  float64
#  10  Mean Min Temp Flag         54882 non-null  object
#  11  Mean Temp (°C)             75863 non-null  float64
#  12  Mean Temp Flag             54882 non-null  object
#  13  Extr Max Temp (°C)         76760 non-null  float64
#  14  Extr Max Temp Flag         54882 non-null  object
#  15  Extr Min Temp (°C)         76775 non-null  float64
#  16  Extr Min Temp Flag         54882 non-null  object
#  17  Total Rain (mm)            79154 non-null  float64
#  18  Total Rain Flag            54882 non-null  object
#  19  Total Snow (cm)            79154 non-null  float64
#  20  Total Snow Flag            54882 non-null  object
#  21  Total Precip (mm)          79154 non-null  float64
#  22  Total Precip Flag          54882 non-null  object
#  23  Snow Grnd Last Day (cm)    68447 non-null  float64
#  24  Snow Grnd Last Day Flag    54882 non-null  object
#  25  Dir of Max Gust (10s deg)  79154 non-null  float64
#  26  Dir of Max Gust Flag       54882 non-null  object
#  27  Spd of Max Gust (km/h)     79154 non-null  float64
#  28  Spd of Max Gust Flag       54882 non-null  object
#  29  GeoUID                     79154 non-null  int64
#  30  Region.Name                79154 non-null  object
#  31  provincename               79154 non-null  object
# dtypes: datetime64[ns](1), float64(13), int64(3), object(15)
# memory usage: 19.9+ MB

# %%
# to check shape of the datasets
print(prod_clean.shape)
print(merged_weather.shape)
# Out:
# (993600, 22)
# (79154, 32)

# %%
# to merge data:

merged_data = pd.merge(prod_clean, 
                       merged_weather,
                       on = ['GeoUID', 'Date/Time', 'provincename'],
                       how = 'right'
)

    # used 'right' to only get productivity data that have weather data
    # not all GeoUID have weather data; we won't be able to forecast productivity for those GeoUID without the weather data

# %%
# to check shape of the datasets
print(merged_weather.shape)
print(merged_data.shape)
# Out:
# (79154, 32)
# (79154, 51)

# %%
# to check date range
print(merged_data['Date/Time'].min())
print(merged_data['Date/Time'].max())
# Out:
# 1998-01-01 00:00:00
# 2024-01-01 00:00:00

# %%
# to remove unnecessary columns

merged_data.drop(columns = ['Date', 'Year', 'Month',
                            'census_year_ref', 'Dominant_NAICS',
                            'colourval'],
                 inplace = True)

# %%
# to arrange columns

columns_to_move = ['provincename', 'Longitude', 'Latitude', 'Region.Name', 'Date/Time']
remaining_columns = [col for col in merged_data.columns if col not in columns_to_move]
new_order = columns_to_move + remaining_columns
merged_data = merged_data[new_order]

# %%
# remove flag columns
flag_columns = [col for col in merged_data.columns if 'Flag' in col]
merged_data = merged_data.drop(columns = flag_columns)

# %%
# columns
columns_list = [
    'provincename',
    'Longitude',
    'Latitude',
    'Region.Name',
    'Date/Time',
    'Population',
    'GeoUID',
    'Station Name',
    'Climate ID',
    'Mean Max Temp (°C)',
    'Mean Min Temp (°C)',
    'Mean Temp (°C)',
    'Extr Max Temp (°C)',
    'Extr Min Temp (°C)',
    'Total Rain (mm)',
    'Total Snow (cm)',
    'Total Precip (mm)',
    'Snow Grnd Last Day (cm)',
    'Dir of Max Gust (10s deg)',
    'Spd of Max Gust (km/h)'
]

#melting the DataFrame to convert "Productivity areas" columns into rows
merged_data = pd.melt(merged_data, id_vars=columns_list, var_name='productivity_sector', value_name='GDP_Value')

#checking changes
merged_data
# Out:
#          provincename  Longitude  Latitude              Region.Name  \
# 0              Quebec     -78.28     48.80               Berry (MÉ)
# 1              Quebec     -78.28     48.80               Berry (MÉ)
# 2              Quebec     -78.28     48.80               Berry (MÉ)
# 3              Quebec     -78.28     48.80               Berry (MÉ)
# 4              Quebec     -78.28     48.80               Berry (MÉ)
# ...               ...        ...       ...                      ...
# 1108151  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1108152  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1108153  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1108154  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
# 1108155  Saskatchewan    -102.12     49.32  Moose Creek No. 33 (RM)
#
#          Date/Time  Population   GeoUID Station Name Climate ID  \
# 0       1998-01-01       538.0  2488070    LAC BERRY    709CEE9
# 1       1998-02-01       538.0  2488070    LAC BERRY    709CEE9
# 2       1998-03-01       538.0  2488070    LAC BERRY    709CEE9
# 3       1998-04-01       538.0  2488070    LAC BERRY    709CEE9
# 4       1998-05-01       538.0  2488070    LAC BERRY    709CEE9
# ...            ...         ...      ...          ...        ...
# 1108151 2023-09-01         NaN  4701036        OXBOW    4015800
# 1108152 2023-10-01         NaN  4701036        OXBOW    4015800
# 1108153 2023-11-01         NaN  4701036        OXBOW    4015800
# 1108154 2023-12-01         NaN  4701036        OXBOW    4015800
# 1108155 2024-01-01         NaN  4701036        OXBOW    4015800
#
#          Mean Max Temp (°C)  ...  Extr Max Temp (°C)  Extr Min Temp (°C)  \
# 0                 -8.400000  ...                 4.0               -39.0
# 1                 -1.100000  ...                 8.0               -37.0
# 2                  0.800000  ...                16.0               -35.0
# 3                 11.000000  ...                23.0               -12.0
# 4                 20.800000  ...                32.0                -5.0
# ...                     ...  ...                 ...                 ...
# 1108151           22.783333  ...                33.5                 1.0
# 1108152            9.250000  ...                21.0               -18.0
# 1108153            2.611111  ...                13.5               -17.5
# 1108154            0.648148  ...                11.5               -20.0
# 1108155           -9.428571  ...                 9.5               -36.0
#
#          Total Rain (mm)  Total Snow (cm)  Total Precip (mm)  \
# 0                    1.0             42.0               43.0
# 1                    0.0             24.0               24.0
# 2                   62.4             31.0               93.4
# 3                   23.0              2.0               25.0
# 4                   33.3              0.0               33.3
# ...                  ...              ...                ...
# 1108151             21.4              0.0               21.4
# 1108152             42.8             25.0               67.8
# 1108153              4.0              6.0               10.0
# 1108154              9.6             11.0               20.6
# 1108155              0.0              3.0                3.0
#
#          Snow Grnd Last Day (cm)  Dir of Max Gust (10s deg)  \
# 0                           52.0                        0.0
# 1                           52.0                        0.0
# 2                           22.0                        0.0
# 3                            0.0                        0.0
# 4                            0.0                        0.0
# ...                          ...                        ...
# 1108151                      0.0                        0.0
# 1108152                     16.0                        0.0
# 1108153                      0.0                        0.0
# 1108154                      5.0                        0.0
# 1108155                      9.0                        0.0
#
#          Spd of Max Gust (km/h)                 productivity_sector  GDP_Value
# 0                           0.0                           Utilities        0.0
# 1                           0.0                           Utilities        0.0
# 2                           0.0                           Utilities        0.0
# 3                           0.0                           Utilities        0.0
# 4                           0.0                           Utilities        0.0
# ...                         ...                                 ...        ...
# 1108151                     0.0  Information culture and recreation        NaN
# 1108152                     0.0  Information culture and recreation        NaN
# 1108153                     0.0  Information culture and recreation        NaN
# 1108154                     0.0  Information culture and recreation        NaN
# 1108155                     0.0  Information culture and recreation        NaN
#
# [1108156 rows x 22 columns]

# %%
merged_data.shape
# Out:
# (1108156, 22)

# %%
merged_data.info()

    # null values under production columns is due to the missing data after year 2021
    # null values under weather data might be from different season changes, or....
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108156 entries, 0 to 1108155
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   provincename               1108156 non-null  object
#  1   Longitude                  1108156 non-null  float64
#  2   Latitude                   1108156 non-null  float64
#  3   Region.Name                1108156 non-null  object
#  4   Date/Time                  1108156 non-null  datetime64[ns]
#  5   Population                 982772 non-null   float64
#  6   GeoUID                     1108156 non-null  int64
#  7   Station Name               1108156 non-null  object
#  8   Climate ID                 1108156 non-null  object
#  9   Mean Max Temp (°C)         1074640 non-null  float64
#  10  Mean Min Temp (°C)         1074850 non-null  float64
#  11  Mean Temp (°C)             1062082 non-null  float64
#  12  Extr Max Temp (°C)         1074640 non-null  float64
#  13  Extr Min Temp (°C)         1074850 non-null  float64
#  14  Total Rain (mm)            1108156 non-null  float64
#  15  Total Snow (cm)            1108156 non-null  float64
#  16  Total Precip (mm)          1108156 non-null  float64
#  17  Snow Grnd Last Day (cm)    958258 non-null   float64
#  18  Dir of Max Gust (10s deg)  1108156 non-null  float64
#  19  Spd of Max Gust (km/h)     1108156 non-null  float64
#  20  productivity_sector        1108156 non-null  object
#  21  GDP_Value                  982772 non-null   float64
# dtypes: datetime64[ns](1), float64(15), int64(1), object(5)
# memory usage: 186.0+ MB

# %%
# to ouput data

csv_path = 'merged_clean_data.csv'
merged_data.to_csv(csv_path,
                   index = False)

# this data contains the geojson, weather, and productivity
