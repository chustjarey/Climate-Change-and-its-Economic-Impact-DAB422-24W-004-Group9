# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

import statsmodels.api as sm
import pycaret.regression as pycr
import pycaret.utils as pycu
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %%
# load final clean dataset
df = pd.read_csv('merged_clean_data.csv')
for_prediction = df.copy()

# %%
# convert date/time to date time format
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
for_prediction['Date/Time'] = pd.to_datetime(df['Date/Time'])

# filter data to remove the rows that doesn't have productivity values
df = df[df['Date/Time'] <= '2021-12-31']

# set date/time as index
df.set_index('Date/Time', inplace = True)
for_prediction.set_index('Date/Time', inplace = True)


# drop unnecessary columns
sectors_todrop = ['Manufacturing', 'Utilities', 'Educational services', 'Accommodation and food services', 'Other services except public administration',
                  'Public administration', 'Finance and insurance, real estate and rental and leasing', 'Professional scientific and technical services',
                  'Information culture and recreation']

df.drop(columns = sectors_todrop, inplace = True)

# rename columns
df.rename(columns={'Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction': 'Agriculture'}, inplace=True)
for_prediction.rename(columns={'Agriculture forestry fishing hunting, Mining quarrying and oil and gas extraction': 'Agriculture'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 85601 entries, 1998-01-01 to 2017-12-01
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   provincename                       85601 non-null  object
#  1   Longitude                          85601 non-null  float64
#  2   Latitude                           85601 non-null  float64
#  3   Region.Name                        85601 non-null  object
#  4   Construction                       85601 non-null  float64
#  5   Transportation and warehousing     85601 non-null  float64
#  6   Health care and social assistance  85601 non-null  float64
#  7   Agriculture                        85601 non-null  float64
#  8   Wholesale trade Retail trade       85601 non-null  float64
#  9   Population                         85601 non-null  float64
#  10  GeoUID                             85601 non-null  int64
#  11  Station Name                       85601 non-null  object
#  12  Climate ID                         85601 non-null  object
#  13  Mean Max Temp (°C)                 85601 non-null  float64
#  14  Mean Min Temp (°C)                 85601 non-null  float64
#  15  Mean Temp (°C)                     85601 non-null  float64
#  16  Extr Max Temp (°C)                 85601 non-null  float64
#  17  Extr Min Temp (°C)                 85601 non-null  float64
#  18  Total Rain (mm)                    85601 non-null  float64
#  19  Total Snow (cm)                    85601 non-null  float64
#  20  Total Precip (mm)                  85601 non-null  float64
#  21  Snow Grnd Last Day (cm)            85601 non-null  float64
#  22  Dir of Max Gust (10s deg)          85589 non-null  float64
#  23  Spd of Max Gust (km/h)             85589 non-null  float64
# dtypes: float64(19), int64(1), object(4)
# memory usage: 16.3+ MB

# %%
# filter for ontario
df = df[df['provincename'] == 'Alberta']

# %%
# RESAMPLING THE DATASET TO MONTHLY #

# split data into numeric and string
num_cols = df.select_dtypes(include = ['number'])

# resample numeric data
resampled = num_cols.resample("M").mean()

print(resampled.isnull().sum())
# Out:
# Longitude                            0
# Latitude                             0
# Construction                         0
# Transportation and warehousing       0
# Health care and social assistance    0
# Agriculture                          0
# Wholesale trade Retail trade         0
# Population                           0
# GeoUID                               0
# Mean Max Temp (°C)                   0
# Mean Min Temp (°C)                   0
# Mean Temp (°C)                       0
# Extr Max Temp (°C)                   0
# Extr Min Temp (°C)                   0
# Total Rain (mm)                      0
# Total Snow (cm)                      0
# Total Precip (mm)                    0
# Snow Grnd Last Day (cm)              0
# Dir of Max Gust (10s deg)            0
# Spd of Max Gust (km/h)               0
# dtype: int64

# %%
for_prediction = for_prediction[for_prediction['provincename'] == 'Ontario']
# RESAMPLING THE DATASET TO MONTHLY #

# split data into numeric and string
num_cols = for_prediction.select_dtypes(include = ['number'])

# resample numeric data
resampled_for_prediction = num_cols.resample("M").mean()

print(resampled_for_prediction.isnull().sum())
# Out:
# Longitude                                                     0
# Latitude                                                      0
# Utilities                                                    25
# Construction                                                 25
# Manufacturing                                                25
# Transportation and warehousing                               25
# Educational services                                         25
# Health care and social assistance                            25
# Accommodation and food services                              25
# Other services except public administration                  25
# Public administration                                        25
# Agriculture                                                  25
# Wholesale trade Retail trade                                 25
# Finance and insurance, real estate and rental and leasing    25
# Professional scientific and technical services               25
# Information culture and recreation                           25
# Population                                                   25
# GeoUID                                                        0
# Mean Max Temp (°C)                                            0
# Mean Min Temp (°C)                                            0
# Mean Temp (°C)                                                0
# Extr Max Temp (°C)                                            0
# Extr Min Temp (°C)                                            0
# Total Rain (mm)                                               0
# Total Snow (cm)                                               0
# Total Precip (mm)                                             0
# Snow Grnd Last Day (cm)                                       0
# Dir of Max Gust (10s deg)                                     0
# Spd of Max Gust (km/h)                                        0
# dtype: int64

# %%
# CORRELATION MATRIX for combination of all 5 provinces #

# numeric columns
num_df = resampled.select_dtypes(include = ['number'])

# columns to exclude
to_drop = ['Longitude', 'Latitude', 'GeoUID', 'Population']

num_df.drop(columns = to_drop, inplace = True)

# correlation matrix
corr_matrix = num_df.corr()

# to remove the upper portion of the matrix; contains the same information
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# correlation matrix heatmap
plt.figure(figsize= (15, 10))
sns.heatmap(corr_matrix, mask = mask, annot = True, fmt = '.2f', linewidths= 0.5)
# Out:
# <Axes: >

# %% [markdown]
# (1) Target Variable: Construction

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Transportation and warehousing', 'Health care and social assistance',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Construction', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8231">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8231_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b8231_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8231_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8231_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b8231_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b8231_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b8231_row1_col1" class="data row1 col1" >Construction</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b8231_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b8231_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b8231_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b8231_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b8231_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b8231_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b8231_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b8231_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b8231_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b8231_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_b8231_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b8231_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b8231_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e21a6 th {
#   text-align: left;
# }
# #T_e21a6_row0_col0, #T_e21a6_row0_col1, #T_e21a6_row0_col5, #T_e21a6_row0_col6, #T_e21a6_row1_col0, #T_e21a6_row1_col1, #T_e21a6_row1_col2, #T_e21a6_row1_col3, #T_e21a6_row1_col4, #T_e21a6_row1_col5, #T_e21a6_row1_col6, #T_e21a6_row2_col0, #T_e21a6_row2_col1, #T_e21a6_row2_col2, #T_e21a6_row2_col3, #T_e21a6_row2_col4, #T_e21a6_row2_col5, #T_e21a6_row2_col6, #T_e21a6_row3_col0, #T_e21a6_row3_col1, #T_e21a6_row3_col2, #T_e21a6_row3_col3, #T_e21a6_row3_col4, #T_e21a6_row3_col5, #T_e21a6_row3_col6, #T_e21a6_row4_col0, #T_e21a6_row4_col1, #T_e21a6_row4_col2, #T_e21a6_row4_col3, #T_e21a6_row4_col4, #T_e21a6_row4_col5, #T_e21a6_row4_col6, #T_e21a6_row5_col0, #T_e21a6_row5_col1, #T_e21a6_row5_col2, #T_e21a6_row5_col3, #T_e21a6_row5_col4, #T_e21a6_row5_col5, #T_e21a6_row5_col6, #T_e21a6_row6_col0, #T_e21a6_row6_col2, #T_e21a6_row6_col3, #T_e21a6_row6_col4, #T_e21a6_row7_col0, #T_e21a6_row7_col1, #T_e21a6_row7_col2, #T_e21a6_row7_col3, #T_e21a6_row7_col4, #T_e21a6_row7_col5, #T_e21a6_row7_col6, #T_e21a6_row8_col0, #T_e21a6_row8_col1, #T_e21a6_row8_col2, #T_e21a6_row8_col3, #T_e21a6_row8_col4, #T_e21a6_row8_col5, #T_e21a6_row8_col6, #T_e21a6_row9_col0, #T_e21a6_row9_col1, #T_e21a6_row9_col2, #T_e21a6_row9_col3, #T_e21a6_row9_col4, #T_e21a6_row9_col5, #T_e21a6_row9_col6, #T_e21a6_row10_col0, #T_e21a6_row10_col1, #T_e21a6_row10_col2, #T_e21a6_row10_col3, #T_e21a6_row10_col4, #T_e21a6_row10_col5, #T_e21a6_row10_col6, #T_e21a6_row11_col0, #T_e21a6_row11_col1, #T_e21a6_row11_col2, #T_e21a6_row11_col3, #T_e21a6_row11_col4, #T_e21a6_row11_col5, #T_e21a6_row11_col6, #T_e21a6_row12_col0, #T_e21a6_row12_col1, #T_e21a6_row12_col2, #T_e21a6_row12_col3, #T_e21a6_row12_col4, #T_e21a6_row12_col5, #T_e21a6_row12_col6, #T_e21a6_row13_col0, #T_e21a6_row13_col1, #T_e21a6_row13_col2, #T_e21a6_row13_col3, #T_e21a6_row13_col4, #T_e21a6_row13_col5, #T_e21a6_row13_col6, #T_e21a6_row14_col0, #T_e21a6_row14_col1, #T_e21a6_row14_col2, #T_e21a6_row14_col3, #T_e21a6_row14_col4, #T_e21a6_row14_col5, #T_e21a6_row14_col6, #T_e21a6_row15_col0, #T_e21a6_row15_col1, #T_e21a6_row15_col2, #T_e21a6_row15_col3, #T_e21a6_row15_col4, #T_e21a6_row15_col5, #T_e21a6_row15_col6, #T_e21a6_row16_col0, #T_e21a6_row16_col1, #T_e21a6_row16_col2, #T_e21a6_row16_col3, #T_e21a6_row16_col4, #T_e21a6_row16_col5, #T_e21a6_row16_col6, #T_e21a6_row17_col0, #T_e21a6_row17_col1, #T_e21a6_row17_col2, #T_e21a6_row17_col3, #T_e21a6_row17_col4, #T_e21a6_row17_col5, #T_e21a6_row17_col6, #T_e21a6_row18_col0, #T_e21a6_row18_col1, #T_e21a6_row18_col2, #T_e21a6_row18_col3, #T_e21a6_row18_col4, #T_e21a6_row18_col5, #T_e21a6_row18_col6 {
#   text-align: left;
# }
# #T_e21a6_row0_col2, #T_e21a6_row0_col3, #T_e21a6_row0_col4, #T_e21a6_row6_col1, #T_e21a6_row6_col5, #T_e21a6_row6_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e21a6_row0_col7, #T_e21a6_row1_col7, #T_e21a6_row2_col7, #T_e21a6_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_e21a6_row3_col7, #T_e21a6_row4_col7, #T_e21a6_row5_col7, #T_e21a6_row6_col7, #T_e21a6_row7_col7, #T_e21a6_row8_col7, #T_e21a6_row9_col7, #T_e21a6_row10_col7, #T_e21a6_row11_col7, #T_e21a6_row12_col7, #T_e21a6_row13_col7, #T_e21a6_row14_col7, #T_e21a6_row15_col7, #T_e21a6_row17_col7, #T_e21a6_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e21a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e21a6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e21a6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e21a6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e21a6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e21a6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e21a6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e21a6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e21a6_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e21a6_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_e21a6_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_e21a6_row0_col1" class="data row0 col1" >31.8054</td>
#       <td id="T_e21a6_row0_col2" class="data row0 col2" >1627.6001</td>
#       <td id="T_e21a6_row0_col3" class="data row0 col3" >40.0142</td>
#       <td id="T_e21a6_row0_col4" class="data row0 col4" >0.6285</td>
#       <td id="T_e21a6_row0_col5" class="data row0 col5" >0.2053</td>
#       <td id="T_e21a6_row0_col6" class="data row0 col6" >0.1746</td>
#       <td id="T_e21a6_row0_col7" class="data row0 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_e21a6_level0_row1" class="row_heading level0 row1" >br</th>
#       <td id="T_e21a6_row1_col0" class="data row1 col0" >Bayesian Ridge</td>
#       <td id="T_e21a6_row1_col1" class="data row1 col1" >31.7051</td>
#       <td id="T_e21a6_row1_col2" class="data row1 col2" >1661.3016</td>
#       <td id="T_e21a6_row1_col3" class="data row1 col3" >40.2963</td>
#       <td id="T_e21a6_row1_col4" class="data row1 col4" >0.6279</td>
#       <td id="T_e21a6_row1_col5" class="data row1 col5" >0.2028</td>
#       <td id="T_e21a6_row1_col6" class="data row1 col6" >0.1725</td>
#       <td id="T_e21a6_row1_col7" class="data row1 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_e21a6_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_e21a6_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_e21a6_row2_col1" class="data row2 col1" >31.6375</td>
#       <td id="T_e21a6_row2_col2" class="data row2 col2" >1665.2445</td>
#       <td id="T_e21a6_row2_col3" class="data row2 col3" >40.3341</td>
#       <td id="T_e21a6_row2_col4" class="data row2 col4" >0.6275</td>
#       <td id="T_e21a6_row2_col5" class="data row2 col5" >0.2010</td>
#       <td id="T_e21a6_row2_col6" class="data row2 col6" >0.1707</td>
#       <td id="T_e21a6_row2_col7" class="data row2 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_e21a6_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_e21a6_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_e21a6_row3_col1" class="data row3 col1" >31.6292</td>
#       <td id="T_e21a6_row3_col2" class="data row3 col2" >1666.9903</td>
#       <td id="T_e21a6_row3_col3" class="data row3 col3" >40.3474</td>
#       <td id="T_e21a6_row3_col4" class="data row3 col4" >0.6272</td>
#       <td id="T_e21a6_row3_col5" class="data row3 col5" >0.2009</td>
#       <td id="T_e21a6_row3_col6" class="data row3 col6" >0.1704</td>
#       <td id="T_e21a6_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_e21a6_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_e21a6_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_e21a6_row4_col1" class="data row4 col1" >31.6316</td>
#       <td id="T_e21a6_row4_col2" class="data row4 col2" >1667.5493</td>
#       <td id="T_e21a6_row4_col3" class="data row4 col3" >40.3539</td>
#       <td id="T_e21a6_row4_col4" class="data row4 col4" >0.6271</td>
#       <td id="T_e21a6_row4_col5" class="data row4 col5" >0.2009</td>
#       <td id="T_e21a6_row4_col6" class="data row4 col6" >0.1704</td>
#       <td id="T_e21a6_row4_col7" class="data row4 col7" >0.8220</td>
#     </tr>
#     <tr>
#       <th id="T_e21a6_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_e21a6_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_e21a6_row5_col1" class="data row5 col1" >31.9275</td>
#       <td id="T_e21a6_row5_col2" class="data row5 col2" >1705.8493</td>
#       <td id="T_e21a6_row5_col3" class="data row5 col3" >40.8005</td>
#       <td id="T_e21a6_row5_col4" class="data row5 col4" >0.6193</td>
#       <td id="T_e21a6_row5_col5" class="data row5 col5" >0.2028</td>
#       <td id="T_e21

# %% [markdown]
# K Neighbors Regressor

# %%
# model creation using PyCaret
model = pycr.create_model('knn', fold = 5)

params = model.get_params()
print(params)
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'minkowski', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Construction (Training Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ff96b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff96b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ff96b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ff96b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ff96b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ff96b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ff96b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ff96b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff96b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff96b_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_ff96b_row0_col1" class="data row0 col1" >27.1493</td>
#       <td id="T_ff96b_row0_col2" class="data row0 col2" >1246.8668</td>
#       <td id="T_ff96b_row0_col3" class="data row0 col3" >35.3110</td>
#       <td id="T_ff96b_row0_col4" class="data row0 col4" >0.7324</td>
#       <td id="T_ff96b_row0_col5" class="data row0 col5" >0.1731</td>
#       <td id="T_ff96b_row0_col6" class="data row0 col6" >0.1455</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.7324228258488705

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)


# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Construction (Test Dataset)',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e9792">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9792_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e9792_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e9792_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e9792_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e9792_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e9792_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e9792_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9792_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9792_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_e9792_row0_col1" class="data row0 col1" >97.2575</td>
#       <td id="T_e9792_row0_col2" class="data row0 col2" >11181.4541</td>
#       <td id="T_e9792_row0_col3" class="data row0 col3" >105.7424</td>
#       <td id="T_e9792_row0_col4" class="data row0 col4" >-11.8957</td>
#       <td id="T_e9792_row0_col5" class="data row0 col5" >0.5032</td>
#       <td id="T_e9792_row0_col6" class="data row0 col6" >0.6195</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -11.895739143411665

# %%
# tuning the pycaret model

model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_e31f2_row10_col0, #T_e31f2_row10_col1, #T_e31f2_row10_col2, #T_e31f2_row10_col3, #T_e31f2_row10_col4, #T_e31f2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e31f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e31f2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e31f2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e31f2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e31f2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e31f2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e31f2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e31f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e31f2_row0_col0" class="data row0 col0" >30.8951</td>
#       <td id="T_e31f2_row0_col1" class="data row0 col1" >1539.2685</td>
#       <td id="T_e31f2_row0_col2" class="data row0 col2" >39.2335</td>
#       <td id="T_e31f2_row0_col3" class="data row0 col3" >0.5491</td>
#       <td id="T_e31f2_row0_col4" class="data row0 col4" >0.2009</td>
#       <td id="T_e31f2_row0_col5" class="data row0 col5" >0.1696</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e31f2_row1_col0" class="data row1 col0" >45.4457</td>
#       <td id="T_e31f2_row1_col1" class="data row1 col1" >3242.4270</td>
#       <td id="T_e31f2_row1_col2" class="data row1 col2" >56.9423</td>
#       <td id="T_e31f2_row1_col3" class="data row1 col3" >0.4852</td>
#       <td id="T_e31f2_row1_col4" class="data row1 col4" >0.2354</td>
#       <td id="T_e31f2_row1_col5" class="data row1 col5" >0.1753</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e31f2_row2_col0" class="data row2 col0" >43.2270</td>
#       <td id="T_e31f2_row2_col1" class="data row2 col1" >3401.8705</td>
#       <td id="T_e31f2_row2_col2" class="data row2 col2" >58.3256</td>
#       <td id="T_e31f2_row2_col3" class="data row2 col3" >0.5542</td>
#       <td id="T_e31f2_row2_col4" class="data row2 col4" >0.2455</td>
#       <td id="T_e31f2_row2_col5" class="data row2 col5" >0.1882</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e31f2_row3_col0" class="data row3 col0" >30.8279</td>
#       <td id="T_e31f2_row3_col1" class="data row3 col1" >1297.4815</td>
#       <td id="T_e31f2_row3_col2" class="data row3 col2" >36.0206</td>
#       <td id="T_e31f2_row3_col3" class="data row3 col3" >0.7428</td>
#       <td id="T_e31f2_row3_col4" class="data row3 col4" >0.1976</td>
#       <td id="T_e31f2_row3_col5" class="data row3 col5" >0.1828</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e31f2_row4_col0" class="data row4 col0" >28.0206</td>
#       <td id="T_e31f2_row4_col1" class="data row4 col1" >1106.7205</td>
#       <td id="T_e31f2_row4_col2" class="data row4 col2" >33.2674</td>
#       <td id="T_e31f2_row4_col3" class="data row4 col3" >0.6492</td>
#       <td id="T_e31f2_row4_col4" class="data row4 col4" >0.1918</td>
#       <td id="T_e31f2_row4_col5" class="data row4 col5" >0.1637</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e31f2_row5_col0" class="data row5 col0" >38.8238</td>
#       <td id="T_e31f2_row5_col1" class="data row5 col1" >2502.8350</td>
#       <td id="T_e31f2_row5_col2" class="data row5 col2" >50.0283</td>
#       <td id="T_e31f2_row5_col3" class="data row5 col3" >0.4153</td>
#       <td id="T_e31f2_row5_col4" class="data row5 col4" >0.2590</td>
#       <td id="T_e31f2_row5_col5" class="data row5 col5" >0.2242</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e31f2_row6_col0" class="data row6 col0" >27.8895</td>
#       <td id="T_e31f2_row6_col1" class="data row6 col1" >1296.2031</td>
#       <td id="T_e31f2_row6_col2" class="data row6 col2" >36.0028</td>
#       <td id="T_e31f2_row6_col3" class="data row6 col3" >0.5463</td>
#       <td id="T_e31f2_row6_col4" class="data row6 col4" >0.2045</td>
#       <td id="T_e31f2_row6_col5" class="data row6 col5" >0.1812</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e31f2_row7_col0" class="data row7 col0" >34.2796</td>
#       <td id="T_e31f2_row7_col1" class="data row7 col1" >1512.0656</td>
#       <td id="T_e31f2_row7_col2" class="data row7 col2" >38.8853</td>
#       <td id="T_e31f2_row7_col3" class="data row7 col3" >0.6390</td>
#       <td id="T_e31f2_row7_col4" class="data row7 col4" >0.2142</td>
#       <td id="T_e31f2_row7_col5" class="data row7 col5" >0.2015</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e31f2_row8_col0" class="data row8 col0" >37.4380</td>
#       <td id="T_e31f2_row8_col1" class="data row8 col1" >2669.7388</td>
#       <td id="T_e31f2_row8_col2" class="data row8 col2" >51.6695</td>
#       <td id="T_e31f2_row8_col3" class="data row8 col3" >0.5246</td>
#       <td id="T_e31f2_row8_col4" class="data row8 col4" >0.2284</td>
#       <td id="T_e31f2_row8_col5" class="data row8 col5" >0.1629</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e31f2_row9_col0" class="data row9 col0" >28.7531</td>
#       <td id="T_e31f2_row9_col1" class="data row9 col1" >1159.3828</td>
#       <td id="T_e31f2_row9_col2" class="data row9 col2" >34.0497</td>
#       <td id="T_e31f2_row9_col3" class="data row9 col3" >0.6531</td>
#       <td id="T_e31f2_row9_col4" class="data row9 col4" >0.1728</td>
#       <td id="T_e31f2_row9_col5" class="data row9 col5" >0.1499</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e31f2_row10_col0" class="data row10 col0" >34.5600</td>
#       <td id="T_e31f2_row10_col1" class="data row10 col1" >1972.7993</td>
#       <td id="T_e31f2_row10_col2" class="data row10 col2" >43.4425</td>
#       <td id="T_e31f2_row10_col3" class="data row10 col3" >0.5759</td>
#       <td id="T_e31f2_row10_col4" class="data row10 col4" >0.2150</td>
#       <td id="T_e31f2_row10_col5" class="data row10 col5" >0.1799</td>
#     </tr>
#     <tr>
#       <th id="T_e31f2_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e31f2_row11_col0" class="data row11 col0" >6.0704</td>
#       <td id="T_e31f2_row11_col1" class="data row11 col1" >845.3793</td>
#       <td id="T_e31f2_row11_col2" class="data row11 col2" >9.2492</td>
#       <td id="T_e31f2_row11_col3" class="data row11 col3" >0.0905</td>
#       <td id="T_e31f2_row11_col4" class="data row11 col4" >0.0253</td>
#       <td id="T_e31f2_row11_col5" class="data row11 col5" >0.0202</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'algorithm': 'auto', 'leaf_size': 30, 'metric': 'euclidean', 'metric_params': None, 'n_jobs': -1, 'n_neighbors': 22, 'p': 2, 'weights': 'distance'}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbor Regressor: Actual vs Predicted Construction (Training Dataset)',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_1bc9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bc9e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1bc9e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1bc9e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1bc9e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1bc9e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1bc9e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1bc9e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bc9e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bc9e_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_1bc9e_row0_col1" class="data row0 col1" >8.2594</td>
#       <td id="T_1bc9e_row0_col2" class="data row0 col2" >440.3818</td>
#       <td id="T_1bc9e_row0_col3" class="data row0 col3" >20.9853</td>
#       <td id="T_1bc9e_row0_col4" class="data row0 col4" >0.9055</td>
#       <td id="T_1bc9e_row0_col5" class="data row0 col5" >0.1029</td>
#       <td id="T_1bc9e_row0_col6" class="data row0 col6" >0.0452</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.9054942162337472

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Construction'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='K Neighbors Regressor: Actual vs Predicted Construction (Test Dataset)',
                  title_font_size=15, title_y=0.95, 
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# R-squared (R2) Score: -8.950468310089986

# %%
# SPLIT DATA to TRAIN, VALIDATION AND TEST DATA #

# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Transportation and warehousing', 'Health care and social assistance',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# select feature and target variables
X_train = train_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_train = train_data['Construction']

X_test = test_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_test = test_data['Construction']

# further split into train and val
train_end_date = '2012-12-31'

# Filter the data based on the date range
X_val_data = X_train[X_train.index > train_end_date]
X_train_data = X_train[X_train.index < train_end_date]


y_val_data = y_train[y_train.index > train_end_date]
y_train_data = y_train[y_train.index < train_end_date]

# %%
# Initialize and train the KNeighborsRegressor model
model = KNeighborsRegressor(algorithm = 'auto',
                            leaf_size = 30,
                            metric = 'minkowski',
                            metric_params = None,
                            n_jobs = -1,
                            n_neighbors = 5,
                            p = 2,
                            weights = 'uniform')

model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %%
# Make predictions on the train data
y_pred = model.predict(X_train_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_train_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_train_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Construction': y_train_data, 'prediction_label': y_pred}, index=X_train_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Construction (Training Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 808.6227497025471
# Root Mean Squared Error (RMSE): 28.436292826290614
# R-squared (R2): 0.668991139222882

# %%
# Make predictions on the validation data
y_pred = model.predict(X_val_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_val_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Construction': y_val_data, 'prediction_label': y_pred}, index=X_val_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Construction (Validation Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 2408.6639753116137
# Root Mean Squared Error (RMSE): 49.07814152259245
# R-squared (R2): -0.3870895485658574

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Construction': y_test, 'prediction_label': y_pred}, index=X_test.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Construction (Test Data)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 9111.679455792006
# Root Mean Squared Error (RMSE): 95.45511749399299
# R-squared (R2): -9.50863533119204

# %%
# select feature and target variables
X = resampled_for_prediction[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y = resampled_for_prediction['Construction']

# Make predictions on the whole data
y_pred = model.predict(X)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Construction': y, 'prediction_label': y_pred}, index=X.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True)

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Construction'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Construction (Entire Dataset)',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Construction',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %% [markdown]
# (2) Target Variable: Transportation and warehousing

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Health care and social assistance',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Transportation and warehousing', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4c2d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c2d5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4c2d5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c2d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c2d5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4c2d5_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c2d5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4c2d5_row1_col1" class="data row1 col1" >Transportation and warehousing</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4c2d5_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4c2d5_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4c2d5_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4c2d5_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4c2d5_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4c2d5_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4c2d5_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4c2d5_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4c2d5_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4c2d5_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_4c2d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4c2d5_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4c2d5_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3467e th {
#   text-align: left;
# }
# #T_3467e_row0_col0, #T_3467e_row0_col1, #T_3467e_row0_col2, #T_3467e_row0_col3, #T_3467e_row0_col5, #T_3467e_row0_col6, #T_3467e_row1_col0, #T_3467e_row1_col4, #T_3467e_row2_col0, #T_3467e_row2_col1, #T_3467e_row2_col2, #T_3467e_row2_col3, #T_3467e_row2_col4, #T_3467e_row2_col5, #T_3467e_row2_col6, #T_3467e_row3_col0, #T_3467e_row3_col1, #T_3467e_row3_col2, #T_3467e_row3_col3, #T_3467e_row3_col4, #T_3467e_row3_col5, #T_3467e_row3_col6, #T_3467e_row4_col0, #T_3467e_row4_col1, #T_3467e_row4_col2, #T_3467e_row4_col3, #T_3467e_row4_col4, #T_3467e_row4_col5, #T_3467e_row4_col6, #T_3467e_row5_col0, #T_3467e_row5_col1, #T_3467e_row5_col2, #T_3467e_row5_col3, #T_3467e_row5_col4, #T_3467e_row5_col5, #T_3467e_row5_col6, #T_3467e_row6_col0, #T_3467e_row6_col1, #T_3467e_row6_col2, #T_3467e_row6_col3, #T_3467e_row6_col4, #T_3467e_row6_col5, #T_3467e_row6_col6, #T_3467e_row7_col0, #T_3467e_row7_col1, #T_3467e_row7_col2, #T_3467e_row7_col3, #T_3467e_row7_col4, #T_3467e_row7_col5, #T_3467e_row7_col6, #T_3467e_row8_col0, #T_3467e_row8_col1, #T_3467e_row8_col2, #T_3467e_row8_col3, #T_3467e_row8_col4, #T_3467e_row8_col5, #T_3467e_row8_col6, #T_3467e_row9_col0, #T_3467e_row9_col1, #T_3467e_row9_col2, #T_3467e_row9_col3, #T_3467e_row9_col4, #T_3467e_row9_col5, #T_3467e_row9_col6, #T_3467e_row10_col0, #T_3467e_row10_col1, #T_3467e_row10_col2, #T_3467e_row10_col3, #T_3467e_row10_col4, #T_3467e_row10_col5, #T_3467e_row10_col6, #T_3467e_row11_col0, #T_3467e_row11_col1, #T_3467e_row11_col2, #T_3467e_row11_col3, #T_3467e_row11_col4, #T_3467e_row11_col5, #T_3467e_row11_col6, #T_3467e_row12_col0, #T_3467e_row12_col1, #T_3467e_row12_col2, #T_3467e_row12_col3, #T_3467e_row12_col4, #T_3467e_row12_col5, #T_3467e_row12_col6, #T_3467e_row13_col0, #T_3467e_row13_col1, #T_3467e_row13_col2, #T_3467e_row13_col3, #T_3467e_row13_col4, #T_3467e_row13_col5, #T_3467e_row13_col6, #T_3467e_row14_col0, #T_3467e_row14_col1, #T_3467e_row14_col2, #T_3467e_row14_col3, #T_3467e_row14_col4, #T_3467e_row14_col5, #T_3467e_row14_col6, #T_3467e_row15_col0, #T_3467e_row15_col1, #T_3467e_row15_col2, #T_3467e_row15_col3, #T_3467e_row15_col4, #T_3467e_row15_col5, #T_3467e_row15_col6, #T_3467e_row16_col0, #T_3467e_row16_col1, #T_3467e_row16_col2, #T_3467e_row16_col3, #T_3467e_row16_col4, #T_3467e_row16_col5, #T_3467e_row16_col6, #T_3467e_row17_col0, #T_3467e_row17_col1, #T_3467e_row17_col2, #T_3467e_row17_col3, #T_3467e_row17_col4, #T_3467e_row17_col5, #T_3467e_row17_col6, #T_3467e_row18_col0, #T_3467e_row18_col1, #T_3467e_row18_col2, #T_3467e_row18_col3, #T_3467e_row18_col4, #T_3467e_row18_col5, #T_3467e_row18_col6 {
#   text-align: left;
# }
# #T_3467e_row0_col4, #T_3467e_row1_col1, #T_3467e_row1_col2, #T_3467e_row1_col3, #T_3467e_row1_col5, #T_3467e_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3467e_row0_col7, #T_3467e_row1_col7, #T_3467e_row2_col7, #T_3467e_row3_col7, #T_3467e_row4_col7, #T_3467e_row5_col7, #T_3467e_row6_col7, #T_3467e_row7_col7, #T_3467e_row8_col7, #T_3467e_row9_col7, #T_3467e_row10_col7, #T_3467e_row11_col7, #T_3467e_row12_col7, #T_3467e_row13_col7, #T_3467e_row15_col7, #T_3467e_row17_col7, #T_3467e_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3467e_row14_col7, #T_3467e_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3467e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3467e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3467e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3467e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3467e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3467e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3467e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3467e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_3467e_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3467e_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_3467e_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_3467e_row0_col1" class="data row0 col1" >5.9483</td>
#       <td id="T_3467e_row0_col2" class="data row0 col2" >54.1321</td>
#       <td id="T_3467e_row0_col3" class="data row0 col3" >7.2784</td>
#       <td id="T_3467e_row0_col4" class="data row0 col4" >0.1961</td>
#       <td id="T_3467e_row0_col5" class="data row0 col5" >0.0987</td>
#       <td id="T_3467e_row0_col6" class="data row0 col6" >0.0829</td>
#       <td id="T_3467e_row0_col7" class="data row0 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_3467e_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_3467e_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_3467e_row1_col1" class="data row1 col1" >5.6957</td>
#       <td id="T_3467e_row1_col2" class="data row1 col2" >53.3011</td>
#       <td id="T_3467e_row1_col3" class="data row1 col3" >7.2116</td>
#       <td id="T_3467e_row1_col4" class="data row1 col4" >0.1898</td>
#       <td id="T_3467e_row1_col5" class="data row1 col5" >0.0967</td>
#       <td id="T_3467e_row1_col6" class="data row1 col6" >0.0790</td>
#       <td id="T_3467e_row1_col7" class="data row1 col7" >0.0410</td>
#     </tr>
#     <tr>
#       <th id="T_3467e_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_3467e_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_3467e_row2_col1" class="data row2 col1" >6.1346</td>
#       <td id="T_3467e_row2_col2" class="data row2 col2" >56.0670</td>
#       <td id="T_3467e_row2_col3" class="data row2 col3" >7.4121</td>
#       <td id="T_3467e_row2_col4" class="data row2 col4" >0.1683</td>
#       <td id="T_3467e_row2_col5" class="data row2 col5" >0.1006</td>
#       <td id="T_3467e_row2_col6" class="data row2 col6" >0.0855</td>
#       <td id="T_3467e_row2_col7" class="data row2 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_3467e_level0_row3" class="row_heading level0 row3" >en</th>
#       <td id="T_3467e_row3_col0" class="data row3 col0" >Elastic Net</td>
#       <td id="T_3467e_row3_col1" class="data row3 col1" >6.0860</td>
#       <td id="T_3467e_row3_col2" class="data row3 col2" >55.9103</td>
#       <td id="T_3467e_row3_col3" class="data row3 col3" >7.4036</td>
#       <td id="T_3467e_row3_col4" class="data row3 col4" >0.1629</td>
#       <td id="T_3467e_row3_col5" class="data row3 col5" >0.1004</td>
#       <td id="T_3467e_row3_col6" class="data row3 col6" >0.0848</td>
#       <td id="T_3467e_row3_col7" class="data row3 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_3467e_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_3467e_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_3467e_row4_col1" class="data row4 col1" >6.1218</td>
#       <td id="T_3467e_row4_col2" class="data row4 col2" >56.3747</td>
#       <td id="T_3467e_row4_col3" class="data row4 col3" >7.4324</td>
#       <td id="T_3467e_row4_col4" class="data row4 col4" >0.1607</td>
#       <td id="T_3467e_row4_col5" class="data row4 col5" >0.1008</td>
#       <td id="T_3467e_row4_col6" class="data row4 col6" >0.0853</td>
#       <td id="T_3467e_row4_col7" class="data row4 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_3467e_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_3467e_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_3467e_row5_col1" class="data row5 col1" >6.1217</td>
#       <td id="T_3467e_row5_col2" class="data row5 col2" >56.3746</td>
#       <td id="T_3467e_row5_col3" class="data row5 col3" >7.4324</td>
#       <td id="T_3467e_row5_col4" class="data row5 col4" >0.1607</td>
#       <td id="T_3467e_row5_col5" class="data row5 col5" >0.1008</td>
#       <td id="T_3467e_row5_col6" class="d

# %% [markdown]
# K Neighbors Regressor

# %%
# SPLIT DATA to TRAIN, VALIDATION AND TEST DATA #

# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Health care and social assistance',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# select feature and target variables
X_train = train_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_train = train_data['Transportation and warehousing']

X_test = test_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_test = test_data['Transportation and warehousing']

# further split into train and val
train_end_date = '2012-12-31'

# Filter the data based on the date range
X_val_data = X_train[X_train.index > train_end_date]
X_train_data = X_train[X_train.index < train_end_date]


y_val_data = y_train[y_train.index > train_end_date]
y_train_data = y_train[y_train.index < train_end_date]

# %%
# Initialize and train the KNeighborsRegressor model
model = KNeighborsRegressor(algorithm='auto',
                            leaf_size=30,
                            metric='minkowski',
                            metric_params=None,
                            n_jobs=-1,
                            n_neighbors=5,
                            p=2,
                            weights='uniform')

model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %%
# Make predictions on the train data
y_pred = model.predict(X_train_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_train_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_train_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Transportation and warehousing': y_train_data, 'prediction_label': y_pred}, index=X_train_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Transportation and warehousing'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Transportation and warehousing\n Training dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 36.909231738225216
# Root Mean Squared Error (RMSE): 6.075296843630377
# R-squared (R2): 0.07070584181665418

# %%
# Make predictions on the validation data
y_pred = model.predict(X_val_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_val_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Transportation and warehousing': y_val_data, 'prediction_label': y_pred}, index=X_val_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Transportation and warehousing'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Transportation and warehousing\n Validation data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 53.49425500674252
# Root Mean Squared Error (RMSE): 7.313976688966306
# R-squared (R2): -1.3808476568894212

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Transportation and warehousing': y_test, 'prediction_label': y_pred}, index=X_test.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Transportation and warehousing'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Transportation and warehousing\n Test Data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 135.03312150819175
# Root Mean Squared Error (RMSE): 11.62037527398284
# R-squared (R2): -1.2161129907045045

# %%
# select feature and target variables
X = resampled_for_prediction[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y = resampled_for_prediction['Transportation and warehousing']

# Make predictions on the test data
y_pred = model.predict(X)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Transportation and warehousing': y, 'prediction_label': y_pred}, index=X.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Transportation and warehousing'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Transportation and warehousing'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Transportation and warehousing\n Whole Dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Transportation and warehousing',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %% [markdown]
# (3) Target Variable: Health care and social assistance

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
# train_data = train_data[['Mean Max Temp (°C)', 'Construction']]
test_data = resampled_con[resampled_con.index > train_end_date]
# test_data = train_data[['Mean Max Temp (°C)', 'Construction']]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Health care and social assistance', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed189">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed189_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ed189_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed189_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed189_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ed189_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed189_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ed189_row1_col1" class="data row1 col1" >Health care and social assistance</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed189_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ed189_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed189_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ed189_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed189_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ed189_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed189_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ed189_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed189_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ed189_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ed189_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed189_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ed189_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b467c th {
#   text-align: left;
# }
# #T_b467c_row0_col0, #T_b467c_row0_col1, #T_b467c_row0_col2, #T_b467c_row0_col3, #T_b467c_row0_col5, #T_b467c_row0_col6, #T_b467c_row1_col0, #T_b467c_row1_col1, #T_b467c_row1_col2, #T_b467c_row1_col3, #T_b467c_row1_col4, #T_b467c_row1_col5, #T_b467c_row1_col6, #T_b467c_row2_col0, #T_b467c_row2_col4, #T_b467c_row3_col0, #T_b467c_row3_col1, #T_b467c_row3_col2, #T_b467c_row3_col4, #T_b467c_row4_col0, #T_b467c_row4_col1, #T_b467c_row4_col2, #T_b467c_row4_col3, #T_b467c_row4_col4, #T_b467c_row4_col5, #T_b467c_row4_col6, #T_b467c_row5_col0, #T_b467c_row5_col1, #T_b467c_row5_col2, #T_b467c_row5_col3, #T_b467c_row5_col4, #T_b467c_row5_col5, #T_b467c_row5_col6, #T_b467c_row6_col0, #T_b467c_row6_col1, #T_b467c_row6_col2, #T_b467c_row6_col3, #T_b467c_row6_col4, #T_b467c_row6_col5, #T_b467c_row6_col6, #T_b467c_row7_col0, #T_b467c_row7_col1, #T_b467c_row7_col2, #T_b467c_row7_col3, #T_b467c_row7_col4, #T_b467c_row7_col5, #T_b467c_row7_col6, #T_b467c_row8_col0, #T_b467c_row8_col1, #T_b467c_row8_col2, #T_b467c_row8_col3, #T_b467c_row8_col4, #T_b467c_row8_col5, #T_b467c_row8_col6, #T_b467c_row9_col0, #T_b467c_row9_col1, #T_b467c_row9_col2, #T_b467c_row9_col3, #T_b467c_row9_col4, #T_b467c_row9_col5, #T_b467c_row9_col6, #T_b467c_row10_col0, #T_b467c_row10_col1, #T_b467c_row10_col2, #T_b467c_row10_col3, #T_b467c_row10_col4, #T_b467c_row10_col5, #T_b467c_row10_col6, #T_b467c_row11_col0, #T_b467c_row11_col1, #T_b467c_row11_col2, #T_b467c_row11_col3, #T_b467c_row11_col4, #T_b467c_row11_col5, #T_b467c_row11_col6, #T_b467c_row12_col0, #T_b467c_row12_col1, #T_b467c_row12_col2, #T_b467c_row12_col3, #T_b467c_row12_col4, #T_b467c_row12_col5, #T_b467c_row12_col6, #T_b467c_row13_col0, #T_b467c_row13_col1, #T_b467c_row13_col2, #T_b467c_row13_col3, #T_b467c_row13_col4, #T_b467c_row13_col5, #T_b467c_row13_col6, #T_b467c_row14_col0, #T_b467c_row14_col1, #T_b467c_row14_col2, #T_b467c_row14_col3, #T_b467c_row14_col4, #T_b467c_row14_col5, #T_b467c_row14_col6, #T_b467c_row15_col0, #T_b467c_row15_col1, #T_b467c_row15_col2, #T_b467c_row15_col3, #T_b467c_row15_col4, #T_b467c_row15_col5, #T_b467c_row15_col6, #T_b467c_row16_col0, #T_b467c_row16_col1, #T_b467c_row16_col2, #T_b467c_row16_col3, #T_b467c_row16_col4, #T_b467c_row16_col5, #T_b467c_row16_col6, #T_b467c_row17_col0, #T_b467c_row17_col1, #T_b467c_row17_col2, #T_b467c_row17_col3, #T_b467c_row17_col4, #T_b467c_row17_col5, #T_b467c_row17_col6, #T_b467c_row18_col0, #T_b467c_row18_col1, #T_b467c_row18_col2, #T_b467c_row18_col3, #T_b467c_row18_col4, #T_b467c_row18_col5, #T_b467c_row18_col6 {
#   text-align: left;
# }
# #T_b467c_row0_col4, #T_b467c_row2_col1, #T_b467c_row2_col2, #T_b467c_row2_col3, #T_b467c_row2_col5, #T_b467c_row2_col6, #T_b467c_row3_col3, #T_b467c_row3_col5, #T_b467c_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b467c_row0_col7, #T_b467c_row1_col7, #T_b467c_row2_col7, #T_b467c_row3_col7, #T_b467c_row4_col7, #T_b467c_row5_col7, #T_b467c_row6_col7, #T_b467c_row8_col7, #T_b467c_row9_col7, #T_b467c_row10_col7, #T_b467c_row11_col7, #T_b467c_row12_col7, #T_b467c_row13_col7, #T_b467c_row14_col7, #T_b467c_row15_col7, #T_b467c_row16_col7, #T_b467c_row17_col7, #T_b467c_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b467c_row7_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b467c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b467c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b467c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b467c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b467c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b467c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b467c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b467c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_b467c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b467c_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_b467c_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_b467c_row0_col1" class="data row0 col1" >4.4733</td>
#       <td id="T_b467c_row0_col2" class="data row0 col2" >30.3575</td>
#       <td id="T_b467c_row0_col3" class="data row0 col3" >5.4316</td>
#       <td id="T_b467c_row0_col4" class="data row0 col4" >0.0058</td>
#       <td id="T_b467c_row0_col5" class="data row0 col5" >0.0772</td>
#       <td id="T_b467c_row0_col6" class="data row0 col6" >0.0652</td>
#       <td id="T_b467c_row0_col7" class="data row0 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_b467c_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_b467c_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_b467c_row1_col1" class="data row1 col1" >4.4993</td>
#       <td id="T_b467c_row1_col2" class="data row1 col2" >30.7404</td>
#       <td id="T_b467c_row1_col3" class="data row1 col3" >5.4657</td>
#       <td id="T_b467c_row1_col4" class="data row1 col4" >0.0043</td>
#       <td id="T_b467c_row1_col5" class="data row1 col5" >0.0776</td>
#       <td id="T_b467c_row1_col6" class="data row1 col6" >0.0656</td>
#       <td id="T_b467c_row1_col7" class="data row1 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_b467c_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_b467c_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_b467c_row2_col1" class="data row2 col1" >4.4603</td>
#       <td id="T_b467c_row2_col2" class="data row2 col2" >30.2602</td>
#       <td id="T_b467c_row2_col3" class="data row2 col3" >5.4298</td>
#       <td id="T_b467c_row2_col4" class="data row2 col4" >-0.0029</td>
#       <td id="T_b467c_row2_col5" class="data row2 col5" >0.0771</td>
#       <td id="T_b467c_row2_col6" class="data row2 col6" >0.0649</td>
#       <td id="T_b467c_row2_col7" class="data row2 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_b467c_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_b467c_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_b467c_row3_col1" class="data row3 col1" >4.4604</td>
#       <td id="T_b467c_row3_col2" class="data row3 col2" >30.2605</td>
#       <td id="T_b467c_row3_col3" class="data row3 col3" >5.4298</td>
#       <td id="T_b467c_row3_col4" class="data row3 col4" >-0.0030</td>
#       <td id="T_b467c_row3_col5" class="data row3 col5" >0.0771</td>
#       <td id="T_b467c_row3_col6" class="data row3 col6" >0.0649</td>
#       <td id="T_b467c_row3_col7" class="data row3 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_b467c_level0_row4" class="row_heading level0 row4" >en</th>
#       <td id="T_b467c_row4_col0" class="data row4 col0" >Elastic Net</td>
#       <td id="T_b467c_row4_col1" class="data row4 col1" >4.4824</td>
#       <td id="T_b467c_row4_col2" class="data row4 col2" >30.3026</td>
#       <td id="T_b467c_row4_col3" class="data row4 col3" >5.4356</td>
#       <td id="T_b467c_row4_col4" class="data row4 col4" >-0.0090</td>
#       <td id="T_b467c_row4_col5" class="data row4 col5" >0.0772</td>
#       <td id="T_b467c_row4_col6" class="data row4 col6" >0.0652</td>
#       <td id="T_b467c_row4_col7" class="data row4 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_b467c_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_b467c_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_b467c_row5_col1" class="data row5 col1" >4.5979</td>
#       <td id="T_b467c_row5_col2" class="data row5 col2" >31.2810</td>
#       <td id="T_b467c_row5_col3" class="data row5 col3" >5.5281</td>
#       <td id="T_b467c_row5_col4" class="data row5 col4" >-0.0518</td>
#       <td id="T_b467c_row5_col5" class="data row5 col5" >0.0787</td>
#       <td id="T_b467c_row5_col6" class="d

# %% [markdown]
# K Neighbors Regressor

# %%
# SPLIT DATA to TRAIN, VALIDATION AND TEST DATA #

# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Agriculture', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns=ignore_features)

# Filter the data based on the date range
train_end_date = '2016-12-31'
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# Select feature and target variables
X_train = train_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                      'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                      'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_train = train_data['Health care and social assistance']  
X_test = test_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_test = test_data['Health care and social assistance']  

# Further split into train and val
val_end_date = '2012-12-31'
X_val_data = X_train[X_train.index > val_end_date]
X_train_data = X_train[X_train.index <= val_end_date]

y_val_data = y_train[y_train.index > val_end_date]
y_train_data = y_train[y_train.index <= val_end_date]

# %%
# Initialize and train the KNeighborsRegressor model
model = KNeighborsRegressor(algorithm='auto',
                            leaf_size=30,
                            metric='minkowski',
                            metric_params=None,
                            n_jobs=-1,
                            n_neighbors=5,
                            p=2,
                            weights='uniform')

model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %%
# Make predictions on the train data
y_pred = model.predict(X_train_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_train_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_train_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Health care and social assistance': y_train_data, 'prediction_label': y_pred}, index=X_train_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Health care and social assistance'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Health care and social assistance\n Training dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 20.323454662755683
# Root Mean Squared Error (RMSE): 4.508154241233954
# R-squared (R2): 0.4378843757859082

# %%
# Make predictions on the validation data
y_pred = model.predict(X_val_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_val_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Health care and social assistance': y_val_data, 'prediction_label': y_pred}, index=X_val_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Health care and social assistance'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Health care and social assistance\n Validation data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 28.6004023398395
# Root Mean Squared Error (RMSE): 5.34793439935827
# R-squared (R2): -2.7331967002730697

# %%
# select feature and target variables
X = resampled_for_prediction[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y = resampled_for_prediction['Health care and social assistance']

# Make predictions on the test data
y_pred = model.predict(X)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Health care and social assistance': y, 'prediction_label': y_pred}, index=X.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Health care and social assistance'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Health care and social assistance'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Health care and social assistance\n Whole Dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Health care and social assistance',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %% [markdown]
# (4) Target Variable: Agriculture

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Health care and social assistance', 'Wholesale trade Retail trade']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
# train_data = train_data[['Mean Max Temp (°C)', 'Construction']]
test_data = resampled_con[resampled_con.index > train_end_date]
# test_data = train_data[['Mean Max Temp (°C)', 'Construction']]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Agriculture', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_8fb9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fb9a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_8fb9a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fb9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fb9a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_8fb9a_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8fb9a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_8fb9a_row1_col1" class="data row1 col1" >Agriculture</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8fb9a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_8fb9a_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8fb9a_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_8fb9a_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8fb9a_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_8fb9a_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8fb9a_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_8fb9a_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8fb9a_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_8fb9a_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_8fb9a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8fb9a_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_8fb9a_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5c114 th {
#   text-align: left;
# }
# #T_5c114_row0_col0, #T_5c114_row0_col1, #T_5c114_row0_col2, #T_5c114_row0_col3, #T_5c114_row0_col5, #T_5c114_row0_col6, #T_5c114_row1_col0, #T_5c114_row1_col1, #T_5c114_row1_col2, #T_5c114_row1_col3, #T_5c114_row1_col4, #T_5c114_row1_col5, #T_5c114_row1_col6, #T_5c114_row2_col0, #T_5c114_row2_col4, #T_5c114_row3_col0, #T_5c114_row3_col1, #T_5c114_row3_col2, #T_5c114_row3_col3, #T_5c114_row3_col4, #T_5c114_row3_col5, #T_5c114_row3_col6, #T_5c114_row4_col0, #T_5c114_row4_col1, #T_5c114_row4_col2, #T_5c114_row4_col3, #T_5c114_row4_col4, #T_5c114_row4_col5, #T_5c114_row4_col6, #T_5c114_row5_col0, #T_5c114_row5_col1, #T_5c114_row5_col2, #T_5c114_row5_col3, #T_5c114_row5_col4, #T_5c114_row5_col5, #T_5c114_row5_col6, #T_5c114_row6_col0, #T_5c114_row6_col1, #T_5c114_row6_col2, #T_5c114_row6_col3, #T_5c114_row6_col4, #T_5c114_row6_col5, #T_5c114_row6_col6, #T_5c114_row7_col0, #T_5c114_row7_col1, #T_5c114_row7_col2, #T_5c114_row7_col3, #T_5c114_row7_col4, #T_5c114_row7_col5, #T_5c114_row7_col6, #T_5c114_row8_col0, #T_5c114_row8_col1, #T_5c114_row8_col2, #T_5c114_row8_col3, #T_5c114_row8_col4, #T_5c114_row8_col5, #T_5c114_row8_col6, #T_5c114_row9_col0, #T_5c114_row9_col1, #T_5c114_row9_col2, #T_5c114_row9_col3, #T_5c114_row9_col4, #T_5c114_row9_col5, #T_5c114_row9_col6, #T_5c114_row10_col0, #T_5c114_row10_col1, #T_5c114_row10_col2, #T_5c114_row10_col3, #T_5c114_row10_col4, #T_5c114_row10_col5, #T_5c114_row10_col6, #T_5c114_row11_col0, #T_5c114_row11_col1, #T_5c114_row11_col2, #T_5c114_row11_col3, #T_5c114_row11_col4, #T_5c114_row11_col5, #T_5c114_row11_col6, #T_5c114_row12_col0, #T_5c114_row12_col1, #T_5c114_row12_col2, #T_5c114_row12_col3, #T_5c114_row12_col4, #T_5c114_row12_col5, #T_5c114_row12_col6, #T_5c114_row13_col0, #T_5c114_row13_col1, #T_5c114_row13_col2, #T_5c114_row13_col3, #T_5c114_row13_col4, #T_5c114_row13_col5, #T_5c114_row13_col6, #T_5c114_row14_col0, #T_5c114_row14_col1, #T_5c114_row14_col2, #T_5c114_row14_col3, #T_5c114_row14_col4, #T_5c114_row14_col5, #T_5c114_row14_col6, #T_5c114_row15_col0, #T_5c114_row15_col1, #T_5c114_row15_col2, #T_5c114_row15_col3, #T_5c114_row15_col4, #T_5c114_row15_col5, #T_5c114_row15_col6, #T_5c114_row16_col0, #T_5c114_row16_col1, #T_5c114_row16_col2, #T_5c114_row16_col3, #T_5c114_row16_col4, #T_5c114_row16_col5, #T_5c114_row16_col6, #T_5c114_row17_col0, #T_5c114_row17_col1, #T_5c114_row17_col2, #T_5c114_row17_col3, #T_5c114_row17_col4, #T_5c114_row17_col5, #T_5c114_row17_col6, #T_5c114_row18_col0, #T_5c114_row18_col1, #T_5c114_row18_col2, #T_5c114_row18_col3, #T_5c114_row18_col4, #T_5c114_row18_col5, #T_5c114_row18_col6 {
#   text-align: left;
# }
# #T_5c114_row0_col4, #T_5c114_row2_col1, #T_5c114_row2_col2, #T_5c114_row2_col3, #T_5c114_row2_col5, #T_5c114_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5c114_row0_col7, #T_5c114_row1_col7, #T_5c114_row2_col7, #T_5c114_row3_col7, #T_5c114_row5_col7, #T_5c114_row6_col7, #T_5c114_row7_col7, #T_5c114_row8_col7, #T_5c114_row9_col7, #T_5c114_row10_col7, #T_5c114_row11_col7, #T_5c114_row12_col7, #T_5c114_row13_col7, #T_5c114_row14_col7, #T_5c114_row15_col7, #T_5c114_row16_col7, #T_5c114_row17_col7, #T_5c114_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5c114_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5c114">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c114_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5c114_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5c114_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5c114_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5c114_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5c114_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5c114_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5c114_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c114_level0_row0" class="row_heading level0 row0" >br</th>
#       <td id="T_5c114_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_5c114_row0_col1" class="data row0 col1" >46.0295</td>
#       <td id="T_5c114_row0_col2" class="data row0 col2" >3241.5251</td>
#       <td id="T_5c114_row0_col3" class="data row0 col3" >56.2673</td>
#       <td id="T_5c114_row0_col4" class="data row0 col4" >-0.0872</td>
#       <td id="T_5c114_row0_col5" class="data row0 col5" >0.0963</td>
#       <td id="T_5c114_row0_col6" class="data row0 col6" >0.0794</td>
#       <td id="T_5c114_row0_col7" class="data row0 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_5c114_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_5c114_row1_col0" class="data row1 col0" >Dummy Regressor</td>
#       <td id="T_5c114_row1_col1" class="data row1 col1" >46.6889</td>
#       <td id="T_5c114_row1_col2" class="data row1 col2" >3323.0195</td>
#       <td id="T_5c114_row1_col3" class="data row1 col3" >56.7272</td>
#       <td id="T_5c114_row1_col4" class="data row1 col4" >-0.0886</td>
#       <td id="T_5c114_row1_col5" class="data row1 col5" >0.0971</td>
#       <td id="T_5c114_row1_col6" class="data row1 col6" >0.0807</td>
#       <td id="T_5c114_row1_col7" class="data row1 col7" >0.0080</td>
#     </tr>
#     <tr>
#       <th id="T_5c114_level0_row2" class="row_heading level0 row2" >en</th>
#       <td id="T_5c114_row2_col0" class="data row2 col0" >Elastic Net</td>
#       <td id="T_5c114_row2_col1" class="data row2 col1" >46.0221</td>
#       <td id="T_5c114_row2_col2" class="data row2 col2" >3210.0894</td>
#       <td id="T_5c114_row2_col3" class="data row2 col3" >56.1649</td>
#       <td id="T_5c114_row2_col4" class="data row2 col4" >-0.1007</td>
#       <td id="T_5c114_row2_col5" class="data row2 col5" >0.0960</td>
#       <td id="T_5c114_row2_col6" class="data row2 col6" >0.0791</td>
#       <td id="T_5c114_row2_col7" class="data row2 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_5c114_level0_row3" class="row_heading level0 row3" >llar</th>
#       <td id="T_5c114_row3_col0" class="data row3 col0" >Lasso Least Angle Regression</td>
#       <td id="T_5c114_row3_col1" class="data row3 col1" >46.0452</td>
#       <td id="T_5c114_row3_col2" class="data row3 col2" >3221.7738</td>
#       <td id="T_5c114_row3_col3" class="data row3 col3" >56.2510</td>
#       <td id="T_5c114_row3_col4" class="data row3 col4" >-0.1037</td>
#       <td id="T_5c114_row3_col5" class="data row3 col5" >0.0962</td>
#       <td id="T_5c114_row3_col6" class="data row3 col6" >0.0792</td>
#       <td id="T_5c114_row3_col7" class="data row3 col7" >0.0100</td>
#     </tr>
#     <tr>
#       <th id="T_5c114_level0_row4" class="row_heading level0 row4" >lasso</th>
#       <td id="T_5c114_row4_col0" class="data row4 col0" >Lasso Regression</td>
#       <td id="T_5c114_row4_col1" class="data row4 col1" >46.0471</td>
#       <td id="T_5c114_row4_col2" class="data row4 col2" >3222.0175</td>
#       <td id="T_5c114_row4_col3" class="data row4 col3" >56.2528</td>
#       <td id="T_5c114_row4_col4" class="data row4 col4" >-0.1038</td>
#       <td id="T_5c114_row4_col5" class="data row4 col5" >0.0962</td>
#       <td id="T_5c114_row4_col6" class="data row4 col6" >0.0792</td>
#       <td id="T_5c114_row4_col7" class="data row4 col7" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_5c114_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_5c114_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_5c114_row5_col1" class="data row5 col1" >46.1214</td>
#       <td id="T_5c114_row5_col2" class="data row5 col2" >3238.0219</td>
#       <td id="T_5c114_row5_col3" class="data row5 col3" >56.3774</td>
#       <td id="T_5c114_row5_col4" class="data row5 col4" >-0.1088</td>
#       <td id="T_5c114_row5_col5" class="data row5 col5" >0.0964</td>
#       <td id="T_5c114_r

# %% [markdown]
# Lasso Least Angle Regression

# %%
# model creation using PyCaret
model = pycr.create_model('llar', fold = 5)

params = model.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_bc9d7_row5_col0, #T_bc9d7_row5_col1, #T_bc9d7_row5_col2, #T_bc9d7_row5_col3, #T_bc9d7_row5_col4, #T_bc9d7_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bc9d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc9d7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bc9d7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bc9d7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bc9d7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bc9d7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bc9d7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc9d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc9d7_row0_col0" class="data row0 col0" >45.6468</td>
#       <td id="T_bc9d7_row0_col1" class="data row0 col1" >3305.2646</td>
#       <td id="T_bc9d7_row0_col2" class="data row0 col2" >57.4914</td>
#       <td id="T_bc9d7_row0_col3" class="data row0 col3" >-0.1055</td>
#       <td id="T_bc9d7_row0_col4" class="data row0 col4" >0.0977</td>
#       <td id="T_bc9d7_row0_col5" class="data row0 col5" >0.0771</td>
#     </tr>
#     <tr>
#       <th id="T_bc9d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc9d7_row1_col0" class="data row1 col0" >47.3716</td>
#       <td id="T_bc9d7_row1_col1" class="data row1 col1" >3396.9985</td>
#       <td id="T_bc9d7_row1_col2" class="data row1 col2" >58.2838</td>
#       <td id="T_bc9d7_row1_col3" class="data row1 col3" >-0.0932</td>
#       <td id="T_bc9d7_row1_col4" class="data row1 col4" >0.1001</td>
#       <td id="T_bc9d7_row1_col5" class="data row1 col5" >0.0815</td>
#     </tr>
#     <tr>
#       <th id="T_bc9d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc9d7_row2_col0" class="data row2 col0" >50.2502</td>
#       <td id="T_bc9d7_row2_col1" class="data row2 col1" >3749.1816</td>
#       <td id="T_bc9d7_row2_col2" class="data row2 col2" >61.2306</td>
#       <td id="T_bc9d7_row2_col3" class="data row2 col3" >0.1447</td>
#       <td id="T_bc9d7_row2_col4" class="data row2 col4" >0.1048</td>
#       <td id="T_bc9d7_row2_col5" class="data row2 col5" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_bc9d7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc9d7_row3_col0" class="data row3 col0" >42.0966</td>
#       <td id="T_bc9d7_row3_col1" class="data row3 col1" >2741.4717</td>
#       <td id="T_bc9d7_row3_col2" class="data row3 col2" >52.3591</td>
#       <td id="T_bc9d7_row3_col3" class="data row3 col3" >0.0893</td>
#       <td id="T_bc9d7_row3_col4" class="data row3 col4" >0.0902</td>
#       <td id="T_bc9d7_row3_col5" class="data row3 col5" >0.0730</td>
#     </tr>
#     <tr>
#       <th id="T_bc9d7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc9d7_row4_col0" class="data row4 col0" >43.2396</td>
#       <td id="T_bc9d7_row4_col1" class="data row4 col1" >2850.8176</td>
#       <td id="T_bc9d7_row4_col2" class="data row4 col2" >53.3930</td>
#       <td id="T_bc9d7_row4_col3" class="data row4 col3" >-0.0905</td>
#       <td id="T_bc9d7_row4_col4" class="data row4 col4" >0.0915</td>
#       <td id="T_bc9d7_row4_col5" class="data row4 col5" >0.0756</td>
#     </tr>
#     <tr>
#       <th id="T_bc9d7_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_bc9d7_row5_col0" class="data row5 col0" >45.7210</td>
#       <td id="T_bc9d7_row5_col1" class="data row5 col1" >3208.7468</td>
#       <td id="T_bc9d7_row5_col2" class="data row5 col2" >56.5516</td>
#       <td id="T_bc9d7_row5_col3" class="data row5 col3" >-0.0110</td>
#       <td id="T_bc9d7_row5_col4" class="data row5 col4" >0.0968</td>
#       <td id="T_bc9d7_row5_col5" class="data row5 col5" >0.0786</td>
#     </tr>
#     <tr>
#       <th id="T_bc9d7_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_bc9d7_row6_col0" class="data row6 col0" >2.9168</td>
#       <td id="T_bc9d7_row6_col1" class="data row6 col1" >369.6711</td>
#       <td id="T_bc9d7_row6_col2" class="data row6 col2" >3.2659</td>
#       <td id="T_bc9d7_row6_col3" class="data row6 col3" >0.1061</td>
#       <td id="T_bc9d7_row6_col4" class="data row6 col4" >0.0054</td>
#       <td id="T_bc9d7_row6_col5" class="data row6 col5" >0.0046</td>
#     </tr>
#   </tbody>
# </table>
# {'alpha': 1.0, 'copy_X': True, 'eps': 2.220446049250313e-16, 'fit_intercept': True, 'fit_path': True, 'jitter': None, 'max_iter': 500, 'positive': False, 'precompute': 'auto', 'random_state': 1234, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee80e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee80e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ee80e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ee80e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ee80e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ee80e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ee80e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ee80e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee80e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee80e_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_ee80e_row0_col1" class="data row0 col1" >44.0184</td>
#       <td id="T_ee80e_row0_col2" class="data row0 col2" >2983.3416</td>
#       <td id="T_ee80e_row0_col3" class="data row0 col3" >54.6200</td>
#       <td id="T_ee80e_row0_col4" class="data row0 col4" >0.0840</td>
#       <td id="T_ee80e_row0_col5" class="data row0 col5" >0.0935</td>
#       <td id="T_ee80e_row0_col6" class="data row0 col6" >0.0758</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.0840058946955502

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_03cc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03cc1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_03cc1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_03cc1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_03cc1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_03cc1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_03cc1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_03cc1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03cc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03cc1_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_03cc1_row0_col1" class="data row0 col1" >53.0502</td>
#       <td id="T_03cc1_row0_col2" class="data row0 col2" >4535.6772</td>
#       <td id="T_03cc1_row0_col3" class="data row0 col3" >67.3474</td>
#       <td id="T_03cc1_row0_col4" class="data row0 col4" >-0.3696</td>
#       <td id="T_03cc1_row0_col5" class="data row0 col5" >0.1082</td>
#       <td id="T_03cc1_row0_col6" class="data row0 col6" >0.0822</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -0.36964283372509943

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_c77ed_row10_col0, #T_c77ed_row10_col1, #T_c77ed_row10_col2, #T_c77ed_row10_col3, #T_c77ed_row10_col4, #T_c77ed_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c77ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c77ed_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c77ed_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c77ed_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c77ed_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c77ed_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c77ed_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c77ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c77ed_row0_col0" class="data row0 col0" >50.0269</td>
#       <td id="T_c77ed_row0_col1" class="data row0 col1" >4082.4214</td>
#       <td id="T_c77ed_row0_col2" class="data row0 col2" >63.8938</td>
#       <td id="T_c77ed_row0_col3" class="data row0 col3" >-0.0943</td>
#       <td id="T_c77ed_row0_col4" class="data row0 col4" >0.1107</td>
#       <td id="T_c77ed_row0_col5" class="data row0 col5" >0.0887</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c77ed_row1_col0" class="data row1 col0" >45.9844</td>
#       <td id="T_c77ed_row1_col1" class="data row1 col1" >3245.8872</td>
#       <td id="T_c77ed_row1_col2" class="data row1 col2" >56.9727</td>
#       <td id="T_c77ed_row1_col3" class="data row1 col3" >-0.5936</td>
#       <td id="T_c77ed_row1_col4" class="data row1 col4" >0.0949</td>
#       <td id="T_c77ed_row1_col5" class="data row1 col5" >0.0739</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c77ed_row2_col0" class="data row2 col0" >35.8950</td>
#       <td id="T_c77ed_row2_col1" class="data row2 col1" >2173.2515</td>
#       <td id="T_c77ed_row2_col2" class="data row2 col2" >46.6181</td>
#       <td id="T_c77ed_row2_col3" class="data row2 col3" >-0.2161</td>
#       <td id="T_c77ed_row2_col4" class="data row2 col4" >0.0770</td>
#       <td id="T_c77ed_row2_col5" class="data row2 col5" >0.0583</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c77ed_row3_col0" class="data row3 col0" >57.0974</td>
#       <td id="T_c77ed_row3_col1" class="data row3 col1" >4216.3223</td>
#       <td id="T_c77ed_row3_col2" class="data row3 col2" >64.9332</td>
#       <td id="T_c77ed_row3_col3" class="data row3 col3" >-0.0085</td>
#       <td id="T_c77ed_row3_col4" class="data row3 col4" >0.1140</td>
#       <td id="T_c77ed_row3_col5" class="data row3 col5" >0.1022</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c77ed_row4_col0" class="data row4 col0" >46.5088</td>
#       <td id="T_c77ed_row4_col1" class="data row4 col1" >3164.8420</td>
#       <td id="T_c77ed_row4_col2" class="data row4 col2" >56.2569</td>
#       <td id="T_c77ed_row4_col3" class="data row4 col3" >0.1383</td>
#       <td id="T_c77ed_row4_col4" class="data row4 col4" >0.0997</td>
#       <td id="T_c77ed_row4_col5" class="data row4 col5" >0.0843</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c77ed_row5_col0" class="data row5 col0" >53.5897</td>
#       <td id="T_c77ed_row5_col1" class="data row5 col1" >4237.3286</td>
#       <td id="T_c77ed_row5_col2" class="data row5 col2" >65.0948</td>
#       <td id="T_c77ed_row5_col3" class="data row5 col3" >0.0199</td>
#       <td id="T_c77ed_row5_col4" class="data row5 col4" >0.1079</td>
#       <td id="T_c77ed_row5_col5" class="data row5 col5" >0.0866</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c77ed_row6_col0" class="data row6 col0" >38.4804</td>
#       <td id="T_c77ed_row6_col1" class="data row6 col1" >2127.9062</td>
#       <td id="T_c77ed_row6_col2" class="data row6 col2" >46.1292</td>
#       <td id="T_c77ed_row6_col3" class="data row6 col3" >-0.2684</td>
#       <td id="T_c77ed_row6_col4" class="data row6 col4" >0.0753</td>
#       <td id="T_c77ed_row6_col5" class="data row6 col5" >0.0631</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c77ed_row7_col0" class="data row7 col0" >47.2661</td>
#       <td id="T_c77ed_row7_col1" class="data row7 col1" >3458.8799</td>
#       <td id="T_c77ed_row7_col2" class="data row7 col2" >58.8122</td>
#       <td id="T_c77ed_row7_col3" class="data row7 col3" >0.1465</td>
#       <td id="T_c77ed_row7_col4" class="data row7 col4" >0.1044</td>
#       <td id="T_c77ed_row7_col5" class="data row7 col5" >0.0857</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c77ed_row8_col0" class="data row8 col0" >35.8325</td>
#       <td id="T_c77ed_row8_col1" class="data row8 col1" >1924.3439</td>
#       <td id="T_c77ed_row8_col2" class="data row8 col2" >43.8673</td>
#       <td id="T_c77ed_row8_col3" class="data row8 col3" >-0.1747</td>
#       <td id="T_c77ed_row8_col4" class="data row8 col4" >0.0748</td>
#       <td id="T_c77ed_row8_col5" class="data row8 col5" >0.0621</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c77ed_row9_col0" class="data row9 col0" >50.1692</td>
#       <td id="T_c77ed_row9_col1" class="data row9 col1" >3659.7439</td>
#       <td id="T_c77ed_row9_col2" class="data row9 col2" >60.4958</td>
#       <td id="T_c77ed_row9_col3" class="data row9 col3" >-0.0076</td>
#       <td id="T_c77ed_row9_col4" class="data row9 col4" >0.1040</td>
#       <td id="T_c77ed_row9_col5" class="data row9 col5" >0.0881</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c77ed_row10_col0" class="data row10 col0" >46.0850</td>
#       <td id="T_c77ed_row10_col1" class="data row10 col1" >3229.0927</td>
#       <td id="T_c77ed_row10_col2" class="data row10 col2" >56.3074</td>
#       <td id="T_c77ed_row10_col3" class="data row10 col3" >-0.1059</td>
#       <td id="T_c77ed_row10_col4" class="data row10 col4" >0.0963</td>
#       <td id="T_c77ed_row10_col5" class="data row10 col5" >0.0793</td>
#     </tr>
#     <tr>
#       <th id="T_c77ed_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c77ed_row11_col0" class="data row11 col0" >6.9150</td>
#       <td id="T_c77ed_row11_col1" class="data row11 col1" >836.1690</td>
#       <td id="T_c77ed_row11_col2" class="data row11 col2" >7.6529</td>
#       <td id="T_c77ed_row11_col3" class="data row11 col3" >0.2097</td>
#       <td id="T_c77ed_row11_col4" class="data row11 col4" >0.0144</td>
#       <td id="T_c77ed_row11_col5" class="data row11 col5" >0.0136</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# {'alpha': 1.0, 'copy_X': True, 'eps': 2.220446049250313e-16, 'fit_intercept': True, 'fit_path': True, 'jitter': None, 'max_iter': 500, 'positive': False, 'precompute': 'auto', 'random_state': 1234, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cbff9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbff9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cbff9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_cbff9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_cbff9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_cbff9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_cbff9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_cbff9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbff9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbff9_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_cbff9_row0_col1" class="data row0 col1" >44.0184</td>
#       <td id="T_cbff9_row0_col2" class="data row0 col2" >2983.3416</td>
#       <td id="T_cbff9_row0_col3" class="data row0 col3" >54.6200</td>
#       <td id="T_cbff9_row0_col4" class="data row0 col4" >0.0840</td>
#       <td id="T_cbff9_row0_col5" class="data row0 col5" >0.0935</td>
#       <td id="T_cbff9_row0_col6" class="data row0 col6" >0.0758</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.0840058946955502

# %%
# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Agriculture'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2bb5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bb5c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2bb5c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2bb5c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2bb5c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2bb5c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2bb5c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2bb5c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bb5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bb5c_row0_col0" class="data row0 col0" >Lasso Least Angle Regression</td>
#       <td id="T_2bb5c_row0_col1" class="data row0 col1" >53.0502</td>
#       <td id="T_2bb5c_row0_col2" class="data row0 col2" >4535.6772</td>
#       <td id="T_2bb5c_row0_col3" class="data row0 col3" >67.3474</td>
#       <td id="T_2bb5c_row0_col4" class="data row0 col4" >-0.3696</td>
#       <td id="T_2bb5c_row0_col5" class="data row0 col5" >0.1082</td>
#       <td id="T_2bb5c_row0_col6" class="data row0 col6" >0.0822</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -0.36964283372509943

# %%
# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Agriculture',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# SPLIT DATA to TRAIN, VALIDATION AND TEST DATA #

# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Health care and social assistance', 'Wholesale trade Retail trade']

resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# select feature and target variables
X_train = train_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_train = train_data['Agriculture']

X_test = test_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_test = test_data['Agriculture']

# further split into train and val
train_end_date = '2012-12-31'

# Filter the data based on the date range
X_val_data = X_train[X_train.index > train_end_date]
X_train_data = X_train[X_train.index < train_end_date]


y_val_data = y_train[y_train.index > train_end_date]
y_train_data = y_train[y_train.index < train_end_date]

# %%
from sklearn.linear_model import LassoLars

# Initialize and train the KNeighborsRegressor model
model = LassoLars(alpha = 1.0,
copy_X = True,
eps = 2.220446049250313e-16,
fit_intercept = True,
fit_path = True,
jitter = None,
max_iter = 500,
positive = False,
precompute = 'auto',
random_state = 1234,
verbose = False)

model.fit(X_train, y_train)
# Out:
# LassoLars(random_state=1234)

# %%
# Make predictions on the train data
y_pred = model.predict(X_train_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_train_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_train_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Agriculture': y_train_data, 'prediction_label': y_pred}, index=X_train_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Agriculture\n Training dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 2493.993941362777
# Root Mean Squared Error (RMSE): 49.93990329749125
# R-squared (R2): 0.18717654753872126

# %%
# Make predictions on the validation data
y_pred = model.predict(X_val_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_val_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Agriculture': y_val_data, 'prediction_label': y_pred}, index=X_val_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Agriculture\n Validation data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 4560.871675486721
# Root Mean Squared Error (RMSE): 67.5342259560789
# R-squared (R2): -2.218428470809422

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Agriculture': y_test, 'prediction_label': y_pred}, index=X_test.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Agriculture\n Test Data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 6988.41540571688
# Root Mean Squared Error (RMSE): 83.59674279370506
# R-squared (R2): -1.110298393934563

# %%
# select feature and target variables
X = resampled_for_prediction[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y = resampled_for_prediction['Agriculture']

# %%
# Make predictions on the test data
y_pred = model.predict(X)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Agriculture': y, 'prediction_label': y_pred}, index=X.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Agriculture'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='KNeighbors Regressor: Actual vs Predicted Agriculture\n Whole Dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Agriculture',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %% [markdown]
# (5) Target Variable: Wholesale trade Retail trade

# %%
# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Health care and social assistance', 'Agriculture']
resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
# train_data = train_data[['Mean Max Temp (°C)', 'Construction']]
test_data = resampled_con[resampled_con.index > train_end_date]
# test_data = train_data[['Mean Max Temp (°C)', 'Construction']]

# %%
# set up the pycaret
pycaret_experiment = pycr.setup(data=train_data, target='Wholesale trade Retail trade', session_id=1234,
                                preprocess = False)
# to check which model is the best to predict the target variable
best = pycr.compare_models(sort='R2')
# Out:
# <style type="text/css">
# </style>
# <table id="T_783dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_783dd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_783dd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_783dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_783dd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_783dd_row0_col1" class="data row0 col1" >1234</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_783dd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_783dd_row1_col1" class="data row1 col1" >Wholesale trade Retail trade</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_783dd_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_783dd_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_783dd_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_783dd_row3_col1" class="data row3 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_783dd_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_783dd_row4_col1" class="data row4 col1" >(228, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_783dd_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_783dd_row5_col1" class="data row5 col1" >(159, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_783dd_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_783dd_row6_col1" class="data row6 col1" >(69, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_783dd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_783dd_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_783dd_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4a3a8 th {
#   text-align: left;
# }
# #T_4a3a8_row0_col0, #T_4a3a8_row0_col1, #T_4a3a8_row0_col6, #T_4a3a8_row1_col0, #T_4a3a8_row1_col2, #T_4a3a8_row1_col3, #T_4a3a8_row1_col4, #T_4a3a8_row1_col5, #T_4a3a8_row2_col0, #T_4a3a8_row2_col1, #T_4a3a8_row2_col2, #T_4a3a8_row2_col3, #T_4a3a8_row2_col4, #T_4a3a8_row2_col5, #T_4a3a8_row2_col6, #T_4a3a8_row3_col0, #T_4a3a8_row3_col1, #T_4a3a8_row3_col2, #T_4a3a8_row3_col3, #T_4a3a8_row3_col4, #T_4a3a8_row3_col5, #T_4a3a8_row3_col6, #T_4a3a8_row4_col0, #T_4a3a8_row4_col1, #T_4a3a8_row4_col2, #T_4a3a8_row4_col3, #T_4a3a8_row4_col4, #T_4a3a8_row4_col5, #T_4a3a8_row4_col6, #T_4a3a8_row5_col0, #T_4a3a8_row5_col1, #T_4a3a8_row5_col2, #T_4a3a8_row5_col3, #T_4a3a8_row5_col4, #T_4a3a8_row5_col5, #T_4a3a8_row5_col6, #T_4a3a8_row6_col0, #T_4a3a8_row6_col1, #T_4a3a8_row6_col2, #T_4a3a8_row6_col3, #T_4a3a8_row6_col4, #T_4a3a8_row6_col5, #T_4a3a8_row6_col6, #T_4a3a8_row7_col0, #T_4a3a8_row7_col1, #T_4a3a8_row7_col2, #T_4a3a8_row7_col3, #T_4a3a8_row7_col4, #T_4a3a8_row7_col5, #T_4a3a8_row7_col6, #T_4a3a8_row8_col0, #T_4a3a8_row8_col1, #T_4a3a8_row8_col2, #T_4a3a8_row8_col3, #T_4a3a8_row8_col4, #T_4a3a8_row8_col5, #T_4a3a8_row8_col6, #T_4a3a8_row9_col0, #T_4a3a8_row9_col1, #T_4a3a8_row9_col2, #T_4a3a8_row9_col3, #T_4a3a8_row9_col4, #T_4a3a8_row9_col5, #T_4a3a8_row9_col6, #T_4a3a8_row10_col0, #T_4a3a8_row10_col1, #T_4a3a8_row10_col2, #T_4a3a8_row10_col3, #T_4a3a8_row10_col4, #T_4a3a8_row10_col5, #T_4a3a8_row10_col6, #T_4a3a8_row11_col0, #T_4a3a8_row11_col1, #T_4a3a8_row11_col2, #T_4a3a8_row11_col3, #T_4a3a8_row11_col4, #T_4a3a8_row11_col5, #T_4a3a8_row11_col6, #T_4a3a8_row12_col0, #T_4a3a8_row12_col1, #T_4a3a8_row12_col2, #T_4a3a8_row12_col3, #T_4a3a8_row12_col4, #T_4a3a8_row12_col5, #T_4a3a8_row12_col6, #T_4a3a8_row13_col0, #T_4a3a8_row13_col1, #T_4a3a8_row13_col2, #T_4a3a8_row13_col3, #T_4a3a8_row13_col4, #T_4a3a8_row13_col5, #T_4a3a8_row13_col6, #T_4a3a8_row14_col0, #T_4a3a8_row14_col1, #T_4a3a8_row14_col2, #T_4a3a8_row14_col3, #T_4a3a8_row14_col4, #T_4a3a8_row14_col5, #T_4a3a8_row14_col6, #T_4a3a8_row15_col0, #T_4a3a8_row15_col1, #T_4a3a8_row15_col2, #T_4a3a8_row15_col3, #T_4a3a8_row15_col4, #T_4a3a8_row15_col5, #T_4a3a8_row15_col6, #T_4a3a8_row16_col0, #T_4a3a8_row16_col1, #T_4a3a8_row16_col2, #T_4a3a8_row16_col3, #T_4a3a8_row16_col4, #T_4a3a8_row16_col5, #T_4a3a8_row16_col6, #T_4a3a8_row17_col0, #T_4a3a8_row17_col1, #T_4a3a8_row17_col2, #T_4a3a8_row17_col3, #T_4a3a8_row17_col4, #T_4a3a8_row17_col5, #T_4a3a8_row17_col6, #T_4a3a8_row18_col0, #T_4a3a8_row18_col1, #T_4a3a8_row18_col2, #T_4a3a8_row18_col3, #T_4a3a8_row18_col4, #T_4a3a8_row18_col5, #T_4a3a8_row18_col6 {
#   text-align: left;
# }
# #T_4a3a8_row0_col2, #T_4a3a8_row0_col3, #T_4a3a8_row0_col4, #T_4a3a8_row0_col5, #T_4a3a8_row1_col1, #T_4a3a8_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4a3a8_row0_col7, #T_4a3a8_row1_col7, #T_4a3a8_row2_col7, #T_4a3a8_row3_col7, #T_4a3a8_row4_col7, #T_4a3a8_row5_col7, #T_4a3a8_row6_col7, #T_4a3a8_row7_col7, #T_4a3a8_row8_col7, #T_4a3a8_row9_col7, #T_4a3a8_row10_col7, #T_4a3a8_row11_col7, #T_4a3a8_row12_col7, #T_4a3a8_row13_col7, #T_4a3a8_row15_col7, #T_4a3a8_row16_col7, #T_4a3a8_row17_col7, #T_4a3a8_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4a3a8_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4a3a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a3a8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4a3a8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4a3a8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4a3a8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4a3a8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4a3a8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4a3a8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4a3a8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a3a8_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_4a3a8_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_4a3a8_row0_col1" class="data row0 col1" >11.3844</td>
#       <td id="T_4a3a8_row0_col2" class="data row0 col2" >198.8202</td>
#       <td id="T_4a3a8_row0_col3" class="data row0 col3" >13.9768</td>
#       <td id="T_4a3a8_row0_col4" class="data row0 col4" >0.4702</td>
#       <td id="T_4a3a8_row0_col5" class="data row0 col5" >0.1033</td>
#       <td id="T_4a3a8_row0_col6" class="data row0 col6" >0.0863</td>
#       <td id="T_4a3a8_row0_col7" class="data row0 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_4a3a8_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_4a3a8_row1_col0" class="data row1 col0" >AdaBoost Regressor</td>
#       <td id="T_4a3a8_row1_col1" class="data row1 col1" >11.2499</td>
#       <td id="T_4a3a8_row1_col2" class="data row1 col2" >203.6965</td>
#       <td id="T_4a3a8_row1_col3" class="data row1 col3" >14.1190</td>
#       <td id="T_4a3a8_row1_col4" class="data row1 col4" >0.4624</td>
#       <td id="T_4a3a8_row1_col5" class="data row1 col5" >0.1041</td>
#       <td id="T_4a3a8_row1_col6" class="data row1 col6" >0.0851</td>
#       <td id="T_4a3a8_row1_col7" class="data row1 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_4a3a8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_4a3a8_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_4a3a8_row2_col1" class="data row2 col1" >11.5563</td>
#       <td id="T_4a3a8_row2_col2" class="data row2 col2" >209.1531</td>
#       <td id="T_4a3a8_row2_col3" class="data row2 col3" >14.3507</td>
#       <td id="T_4a3a8_row2_col4" class="data row2 col4" >0.4321</td>
#       <td id="T_4a3a8_row2_col5" class="data row2 col5" >0.1057</td>
#       <td id="T_4a3a8_row2_col6" class="data row2 col6" >0.0875</td>
#       <td id="T_4a3a8_row2_col7" class="data row2 col7" >0.0530</td>
#     </tr>
#     <tr>
#       <th id="T_4a3a8_level0_row3" class="row_heading level0 row3" >lasso</th>
#       <td id="T_4a3a8_row3_col0" class="data row3 col0" >Lasso Regression</td>
#       <td id="T_4a3a8_row3_col1" class="data row3 col1" >12.0122</td>
#       <td id="T_4a3a8_row3_col2" class="data row3 col2" >214.3761</td>
#       <td id="T_4a3a8_row3_col3" class="data row3 col3" >14.5167</td>
#       <td id="T_4a3a8_row3_col4" class="data row3 col4" >0.4125</td>
#       <td id="T_4a3a8_row3_col5" class="data row3 col5" >0.1086</td>
#       <td id="T_4a3a8_row3_col6" class="data row3 col6" >0.0914</td>
#       <td id="T_4a3a8_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_4a3a8_level0_row4" class="row_heading level0 row4" >llar</th>
#       <td id="T_4a3a8_row4_col0" class="data row4 col0" >Lasso Least Angle Regression</td>
#       <td id="T_4a3a8_row4_col1" class="data row4 col1" >12.0121</td>
#       <td id="T_4a3a8_row4_col2" class="data row4 col2" >214.3732</td>
#       <td id="T_4a3a8_row4_col3" class="data row4 col3" >14.5166</td>
#       <td id="T_4a3a8_row4_col4" class="data row4 col4" >0.4125</td>
#       <td id="T_4a3a8_row4_col5" class="data row4 col5" >0.1086</td>
#       <td id="T_4a3a8_row4_col6" class="data row4 col6" >0.0914</td>
#       <td id="T_4a3a8_row4_col7" class="data row4 col7" >0.0120</td>
#     </tr>
#     <tr>
#       <th id="T_4a3a8_level0_row5" class="row_heading level0 row5" >en</th>
#       <td id="T_4a3a8_row5_col0" class="data row5 col0" >Elastic Net</td>
#       <td id="T_4a3a8_row5_col1" class="data row5 col1" >12.0282</td>
#       <td id="T_4a3a8_row5_col2" class="data row5 col2" >214.7875</td>
#       <td id="T_4a3a8_row5_col3" class="data row5 col3" >14.5313</td>
#       <td id="T_4a3a8_row5_col4" class="data row5 col4" >0.4119</td>
#       <td id="T_4a3a8_row5_col5" class="data row5 col5" >0.1087</td>
#       <td id="T_4a3a8_r

# %% [markdown]
# Bayesian Ridge

# %%
# model creation using PyCaret
model = pycr.create_model('br', fold = 5)

params = model.get_params()
print(params)
# Out:
# <style type="text/css">
# #T_43358_row5_col0, #T_43358_row5_col1, #T_43358_row5_col2, #T_43358_row5_col3, #T_43358_row5_col4, #T_43358_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_43358">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43358_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_43358_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_43358_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_43358_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_43358_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_43358_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43358_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43358_row0_col0" class="data row0 col0" >12.9535</td>
#       <td id="T_43358_row0_col1" class="data row0 col1" >245.5710</td>
#       <td id="T_43358_row0_col2" class="data row0 col2" >15.6707</td>
#       <td id="T_43358_row0_col3" class="data row0 col3" >0.3343</td>
#       <td id="T_43358_row0_col4" class="data row0 col4" >0.1147</td>
#       <td id="T_43358_row0_col5" class="data row0 col5" >0.0950</td>
#     </tr>
#     <tr>
#       <th id="T_43358_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43358_row1_col0" class="data row1 col0" >13.1124</td>
#       <td id="T_43358_row1_col1" class="data row1 col1" >211.0148</td>
#       <td id="T_43358_row1_col2" class="data row1 col2" >14.5263</td>
#       <td id="T_43358_row1_col3" class="data row1 col3" >0.5899</td>
#       <td id="T_43358_row1_col4" class="data row1 col4" >0.1091</td>
#       <td id="T_43358_row1_col5" class="data row1 col5" >0.1006</td>
#     </tr>
#     <tr>
#       <th id="T_43358_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43358_row2_col0" class="data row2 col0" >12.5044</td>
#       <td id="T_43358_row2_col1" class="data row2 col1" >224.7489</td>
#       <td id="T_43358_row2_col2" class="data row2 col2" >14.9916</td>
#       <td id="T_43358_row2_col3" class="data row2 col3" >0.3534</td>
#       <td id="T_43358_row2_col4" class="data row2 col4" >0.1141</td>
#       <td id="T_43358_row2_col5" class="data row2 col5" >0.0968</td>
#     </tr>
#     <tr>
#       <th id="T_43358_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43358_row3_col0" class="data row3 col0" >12.2944</td>
#       <td id="T_43358_row3_col1" class="data row3 col1" >221.9797</td>
#       <td id="T_43358_row3_col2" class="data row3 col2" >14.8990</td>
#       <td id="T_43358_row3_col3" class="data row3 col3" >0.4253</td>
#       <td id="T_43358_row3_col4" class="data row3 col4" >0.1167</td>
#       <td id="T_43358_row3_col5" class="data row3 col5" >0.0991</td>
#     </tr>
#     <tr>
#       <th id="T_43358_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43358_row4_col0" class="data row4 col0" >11.2330</td>
#       <td id="T_43358_row4_col1" class="data row4 col1" >221.3661</td>
#       <td id="T_43358_row4_col2" class="data row4 col2" >14.8784</td>
#       <td id="T_43358_row4_col3" class="data row4 col3" >0.3467</td>
#       <td id="T_43358_row4_col4" class="data row4 col4" >0.1079</td>
#       <td id="T_43358_row4_col5" class="data row4 col5" >0.0815</td>
#     </tr>
#     <tr>
#       <th id="T_43358_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_43358_row5_col0" class="data row5 col0" >12.4196</td>
#       <td id="T_43358_row5_col1" class="data row5 col1" >224.9361</td>
#       <td id="T_43358_row5_col2" class="data row5 col2" >14.9932</td>
#       <td id="T_43358_row5_col3" class="data row5 col3" >0.4099</td>
#       <td id="T_43358_row5_col4" class="data row5 col4" >0.1125</td>
#       <td id="T_43358_row5_col5" class="data row5 col5" >0.0946</td>
#     </tr>
#     <tr>
#       <th id="T_43358_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_43358_row6_col0" class="data row6 col0" >0.6627</td>
#       <td id="T_43358_row6_col1" class="data row6 col1" >11.3236</td>
#       <td id="T_43358_row6_col2" class="data row6 col2" >0.3739</td>
#       <td id="T_43358_row6_col3" class="data row6 col3" >0.0955</td>
#       <td id="T_43358_row6_col4" class="data row6 col4" >0.0034</td>
#       <td id="T_43358_row6_col5" class="data row6 col5" >0.0069</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]
# {'alpha_1': 1e-06, 'alpha_2': 1e-06, 'alpha_init': None, 'compute_score': False, 'copy_X': True, 'fit_intercept': True, 'lambda_1': 1e-06, 'lambda_2': 1e-06, 'lambda_init': None, 'max_iter': None, 'n_iter': 'deprecated', 'tol': 0.001, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = train_data)

r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# R-squared (R2) Score: 0.4760991650360916

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Wholesale trade Retail trade',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model, data = test_data)
r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3da56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3da56_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3da56_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3da56_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3da56_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3da56_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3da56_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3da56_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3da56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3da56_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_3da56_row0_col1" class="data row0 col1" >11.6077</td>
#       <td id="T_3da56_row0_col2" class="data row0 col2" >239.2153</td>
#       <td id="T_3da56_row0_col3" class="data row0 col3" >15.4666</td>
#       <td id="T_3da56_row0_col4" class="data row0 col4" >-2.4544</td>
#       <td id="T_3da56_row0_col5" class="data row0 col5" >0.0956</td>
#       <td id="T_3da56_row0_col6" class="data row0 col6" >0.0760</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -2.4544498442326366

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Wholesale trade Retail trade',
                  title_font_size=15, title_y=0.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
model_tuned = pycr.tune_model(model)
params = model_tuned.get_params()
print(params)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              21:10:36
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .        Bayesian Ridge
# <style type="text/css">
# #T_5e0ce_row10_col0, #T_5e0ce_row10_col1, #T_5e0ce_row10_col2, #T_5e0ce_row10_col3, #T_5e0ce_row10_col4, #T_5e0ce_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5e0ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e0ce_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5e0ce_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5e0ce_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5e0ce_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5e0ce_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5e0ce_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e0ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e0ce_row0_col0" class="data row0 col0" >12.5922</td>
#       <td id="T_5e0ce_row0_col1" class="data row0 col1" >220.4380</td>
#       <td id="T_5e0ce_row0_col2" class="data row0 col2" >14.8472</td>
#       <td id="T_5e0ce_row0_col3" class="data row0 col3" >0.0810</td>
#       <td id="T_5e0ce_row0_col4" class="data row0 col4" >0.1142</td>
#       <td id="T_5e0ce_row0_col5" class="data row0 col5" >0.0990</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e0ce_row1_col0" class="data row1 col0" >13.9700</td>
#       <td id="T_5e0ce_row1_col1" class="data row1 col1" >292.2906</td>
#       <td id="T_5e0ce_row1_col2" class="data row1 col2" >17.0965</td>
#       <td id="T_5e0ce_row1_col3" class="data row1 col3" >0.3263</td>
#       <td id="T_5e0ce_row1_col4" class="data row1 col4" >0.1196</td>
#       <td id="T_5e0ce_row1_col5" class="data row1 col5" >0.0960</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e0ce_row2_col0" class="data row2 col0" >11.1206</td>
#       <td id="T_5e0ce_row2_col1" class="data row2 col1" >162.5582</td>
#       <td id="T_5e0ce_row2_col2" class="data row2 col2" >12.7498</td>
#       <td id="T_5e0ce_row2_col3" class="data row2 col3" >0.6843</td>
#       <td id="T_5e0ce_row2_col4" class="data row2 col4" >0.0936</td>
#       <td id="T_5e0ce_row2_col5" class="data row2 col5" >0.0825</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e0ce_row3_col0" class="data row3 col0" >12.9881</td>
#       <td id="T_5e0ce_row3_col1" class="data row3 col1" >203.3795</td>
#       <td id="T_5e0ce_row3_col2" class="data row3 col2" >14.2611</td>
#       <td id="T_5e0ce_row3_col3" class="data row3 col3" >0.5952</td>
#       <td id="T_5e0ce_row3_col4" class="data row3 col4" >0.1091</td>
#       <td id="T_5e0ce_row3_col5" class="data row3 col5" >0.1026</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e0ce_row4_col0" class="data row4 col0" >12.0465</td>
#       <td id="T_5e0ce_row4_col1" class="data row4 col1" >216.3610</td>
#       <td id="T_5e0ce_row4_col2" class="data row4 col2" >14.7092</td>
#       <td id="T_5e0ce_row4_col3" class="data row4 col3" >0.3307</td>
#       <td id="T_5e0ce_row4_col4" class="data row4 col4" >0.1130</td>
#       <td id="T_5e0ce_row4_col5" class="data row4 col5" >0.0938</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5e0ce_row5_col0" class="data row5 col0" >12.4329</td>
#       <td id="T_5e0ce_row5_col1" class="data row5 col1" >216.1723</td>
#       <td id="T_5e0ce_row5_col2" class="data row5 col2" >14.7028</td>
#       <td id="T_5e0ce_row5_col3" class="data row5 col3" >0.4178</td>
#       <td id="T_5e0ce_row5_col4" class="data row5 col4" >0.1110</td>
#       <td id="T_5e0ce_row5_col5" class="data row5 col5" >0.0963</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5e0ce_row6_col0" class="data row6 col0" >8.9121</td>
#       <td id="T_5e0ce_row6_col1" class="data row6 col1" >140.6841</td>
#       <td id="T_5e0ce_row6_col2" class="data row6 col2" >11.8610</td>
#       <td id="T_5e0ce_row6_col3" class="data row6 col3" >0.5500</td>
#       <td id="T_5e0ce_row6_col4" class="data row6 col4" >0.0923</td>
#       <td id="T_5e0ce_row6_col5" class="data row6 col5" >0.0710</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5e0ce_row7_col0" class="data row7 col0" >15.1141</td>
#       <td id="T_5e0ce_row7_col1" class="data row7 col1" >285.0530</td>
#       <td id="T_5e0ce_row7_col2" class="data row7 col2" >16.8835</td>
#       <td id="T_5e0ce_row7_col3" class="data row7 col3" >0.3769</td>
#       <td id="T_5e0ce_row7_col4" class="data row7 col4" >0.1316</td>
#       <td id="T_5e0ce_row7_col5" class="data row7 col5" >0.1220</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5e0ce_row8_col0" class="data row8 col0" >12.6911</td>
#       <td id="T_5e0ce_row8_col1" class="data row8 col1" >281.1326</td>
#       <td id="T_5e0ce_row8_col2" class="data row8 col2" >16.7670</td>
#       <td id="T_5e0ce_row8_col3" class="data row8 col3" >0.3473</td>
#       <td id="T_5e0ce_row8_col4" class="data row8 col4" >0.1199</td>
#       <td id="T_5e0ce_row8_col5" class="data row8 col5" >0.0891</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5e0ce_row9_col0" class="data row9 col0" >9.9152</td>
#       <td id="T_5e0ce_row9_col1" class="data row9 col1" >161.3604</td>
#       <td id="T_5e0ce_row9_col2" class="data row9 col2" >12.7028</td>
#       <td id="T_5e0ce_row9_col3" class="data row9 col3" >0.3227</td>
#       <td id="T_5e0ce_row9_col4" class="data row9 col4" >0.0941</td>
#       <td id="T_5e0ce_row9_col5" class="data row9 col5" >0.0753</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5e0ce_row10_col0" class="data row10 col0" >12.1783</td>
#       <td id="T_5e0ce_row10_col1" class="data row10 col1" >217.9430</td>
#       <td id="T_5e0ce_row10_col2" class="data row10 col2" >14.6581</td>
#       <td id="T_5e0ce_row10_col3" class="data row10 col3" >0.4032</td>
#       <td id="T_5e0ce_row10_col4" class="data row10 col4" >0.1098</td>
#       <td id="T_5e0ce_row10_col5" class="data row10 col5" >0.0928</td>
#     </tr>
#     <tr>
#       <th id="T_5e0ce_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5e0ce_row11_col0" class="data row11 col0" >1.7295</td>
#       <td id="T_5e0ce_row11_col1" class="data row11 col1" >51.4648</td>
#       <td id="T_5e0ce_row11_col2" class="data row11 col2" >1.7559</td>
#       <td id="T_5e0ce_row11_col3" class="data row11 col3" >0.1622</td>
#       <td id="T_5e0ce_row11_col4" class="data row11 col4" >0.0123</td>
#       <td id="T_5e0ce_row11_col5" class="data row11 col5" >0.0138</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# {'alpha_1': 0.01, 'alpha_2': 0.1, 'alpha_init': None, 'compute_score': True, 'copy_X': True, 'fit_intercept': True, 'lambda_1': 0.3, 'lambda_2': 0.3, 'lambda_init': None, 'max_iter': None, 'n_iter': 'deprecated', 'tol': 0.001, 'verbose': False}

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = train_data)
predictions.head()

r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5cba3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5cba3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5cba3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5cba3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5cba3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5cba3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5cba3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5cba3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5cba3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5cba3_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_5cba3_row0_col1" class="data row0 col1" >11.6266</td>
#       <td id="T_5cba3_row0_col2" class="data row0 col2" >197.7266</td>
#       <td id="T_5cba3_row0_col3" class="data row0 col3" >14.0615</td>
#       <td id="T_5cba3_row0_col4" class="data row0 col4" >0.4793</td>
#       <td id="T_5cba3_row0_col5" class="data row0 col5" >0.1056</td>
#       <td id="T_5cba3_row0_col6" class="data row0 col6" >0.0894</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: 0.47925426239119995

# %%
# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Wholesale trade Retail trade',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# Make predictions on the test dataset
predictions = pycr.predict_model(model_tuned, data = test_data)

r2 = r2_score(predictions['Wholesale trade Retail trade'], predictions['prediction_label'])
print('R-squared (R2) Score:', r2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d96b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5d96b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5d96b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5d96b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5d96b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5d96b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5d96b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5d96b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5d96b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5d96b_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_5d96b_row0_col1" class="data row0 col1" >13.5042</td>
#       <td id="T_5d96b_row0_col2" class="data row0 col2" >311.2374</td>
#       <td id="T_5d96b_row0_col3" class="data row0 col3" >17.6419</td>
#       <td id="T_5d96b_row0_col4" class="data row0 col4" >-3.4945</td>
#       <td id="T_5d96b_row0_col5" class="data row0 col5" >0.1072</td>
#       <td id="T_5d96b_row0_col6" class="data row0 col6" >0.0880</td>
#     </tr>
#   </tbody>
# </table>
# R-squared (R2) Score: -3.4945032266365468

# %%
# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Extra Trees Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Lasso Least Angle Regression: Actual vs Predicted Wholesale trade Retail trade',
                  title_font_size=15, title_y=0.95,  # Adjusted title_y value
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()

# %%
# SPLIT DATA to TRAIN, VALIDATION AND TEST DATA #

# drop columns
ignore_features = ['Longitude', 'Latitude', 'Population', 'GeoUID', 
                   'Construction', 'Transportation and warehousing',
                   'Health care and social assistance', 'Agriculture']

resampled_con = resampled.drop(columns = ignore_features)
# resampled['Year'] = resampled.index.year

# Filter the data based on the date range
train_end_date = '2016-12-31'

# Filter the data based on the date range
train_data = resampled_con[resampled_con.index <= train_end_date]
test_data = resampled_con[resampled_con.index > train_end_date]

# select feature and target variables
X_train = train_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_train = train_data['Wholesale trade Retail trade']

X_test = test_data[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y_test = test_data['Wholesale trade Retail trade']

# further split into train and val
train_end_date = '2012-12-31'

# Filter the data based on the date range
X_val_data = X_train[X_train.index > train_end_date]
X_train_data = X_train[X_train.index < train_end_date]


y_val_data = y_train[y_train.index > train_end_date]
y_train_data = y_train[y_train.index < train_end_date]

# %%
from sklearn.linear_model import BayesianRidge

# Initialize and train the KNeighborsRegressor model
model = BayesianRidge(alpha_1 = 0.1,
alpha_2 = 0.15,
alpha_init = None,
compute_score = True,
copy_X = True,
fit_intercept = True,
lambda_1 = 0.3,
lambda_2 = 0.1,
lambda_init = None,
max_iter = None,
n_iter = 'deprecated',
tol = 0.001,
verbose = False)

model.fit(X_train, y_train)
# Out:
# BayesianRidge(alpha_1=0.1, alpha_2=0.15, compute_score=True, lambda_1=0.3,
#               lambda_2=0.1)

# %%
# Make predictions on the train data
y_pred = model.predict(X_train_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_train_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_train_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Wholesale trade Retail trade': y_train_data, 'prediction_label': y_pred}, index=X_train_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade\n Training dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 188.2429508442322
# Root Mean Squared Error (RMSE): 13.720165846090644
# R-squared (R2): 0.21844780826221366

# %%
# Make predictions on the validation data
y_pred = model.predict(X_val_data)

# Calculate evaluation metrics
mse = mean_squared_error(y_val_data, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_val_data, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Wholesale trade Retail trade': y_val_data, 'prediction_label': y_pred}, index=X_val_data.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('KNeighbors Regressor: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade\n Validation data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 229.64905315583238
# Root Mean Squared Error (RMSE): 15.15417609623936
# R-squared (R2): -1.881176029116134

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Print the evaluation metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('R-squared (R2):', r2)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Wholesale trade Retail trade': y_test, 'prediction_label': y_pred}, index=X_test.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Bayesian Ridgr: Actual vs Predicted Agriculture'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade\n Validation data',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
# Out:
# Mean Squared Error (MSE): 169.08518685598526
# Root Mean Squared Error (RMSE): 13.003276004760695
# R-squared (R2): -1.441717961750343

# %%
# select feature and target variables
X = resampled_for_prediction[['Mean Max Temp (°C)', 'Mean Min Temp (°C)', 'Mean Temp (°C)', 'Extr Max Temp (°C)',
                    'Extr Min Temp (°C)', 'Total Rain (mm)', 'Total Snow (cm)', 'Total Precip (mm)',
                    'Snow Grnd Last Day (cm)', 'Dir of Max Gust (10s deg)', 'Spd of Max Gust (km/h)']]
y = resampled_for_prediction['Wholesale trade Retail trade']

# %%
# Make predictions on the test data
y_pred = model.predict(X)

# Combine y_test and y_pred into a DataFrame for easier plotting
predictions = pd.DataFrame({'Wholesale trade Retail trade': y, 'prediction_label': y_pred}, index=X.index)

# Sort predictions DataFrame by index
predictions.sort_index(inplace=True)

# Create Plotly figure
fig = make_subplots(rows=1, cols=1, shared_xaxes=True, shared_yaxes=True, 
                    subplot_titles=('Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade'))

# Add scatter plot for actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'],
                         mode='markers', marker=dict(color='blue', opacity=0.5),
                         name='Actual'), row=1, col=1)

# Add scatter plot for predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'],
                         mode='markers', marker=dict(color='red'),
                         name='Predicted'), row=1, col=1)

# Add lines for sorted actual values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['Wholesale trade Retail trade'].sort_index(),
                         mode='lines', line=dict(color='blue', dash='dash'),
                         showlegend=False), row=1, col=1)

# Add lines for sorted predicted values
fig.add_trace(go.Scatter(x=predictions.index, y=predictions['prediction_label'].sort_index(),
                         mode='lines', line=dict(color='red', dash='dash'),
                         showlegend=False), row=1, col=1)

fig.update_layout(title_text='Bayesian Ridge: Actual vs Predicted Wholesale trade Retail trade\n Whole Dataset',
                  title_font_size=15, title_y=.95,
                  xaxis_title='Date/Time', yaxis_title='Wholesale trade Retail trade',
                  legend=dict(x=0.02, y=0.98),
                  grid=dict(rows=1, columns=1, ygap=0.2))

# Show interactive plot
fig.show()
